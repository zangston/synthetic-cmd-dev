# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening
from matplotlib.colors import LogNorm
import csv
from scipy.stats import chi2
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
# === Setup ===
iso_dir = 'isochrones/'
# output_dir = 'output_diagrams/'
# os.makedirs(output_dir, exist_ok=True)

# --- Static Parameters ---
star_index = 1
dist = 4500
metallicity = 0
log_age_arr = np.log10([1e6])  # 1 Myr

# Models
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)

# Filters
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']

filter_wavelengths = {
    "m_jwst_F162M": 1.62,
    "m_jwst_F182M": 1.82,
    "m_jwst_F200W": 2.00,
    "m_jwst_F356M": 3.56,
    "m_jwst_F405N": 4.05
}

# Conversion constant from SPISEA/Cardelli (1989) with Rv = 3.1
AV_to_AKs = 1.0 / 0.1179  # ≈ 8.479

# %%
# --- Load star data ---
def load_star_data(csv_path, index=0):
    sample_mags, sample_errs = [], []
    with open(csv_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)
        for line in reader:
            mags = [float(line[i]) for i in range(1, len(line), 2)]
            errs = [float(line[i]) for i in range(2, len(line), 2)]
            sample_mags.append(mags)
            sample_errs.append(errs)
    return sample_mags[index][:2], sample_errs[index][:2]

# --- Interpolate Isochrone Points ---
def interpolate_isochrone(isochrone, num_interp=10):
    masses = isochrone.points['mass']
    m1 = isochrone.points['m_jwst_F162M']
    m2 = isochrone.points['m_jwst_F182M']

    # Collect original + interpolated points
    interp_data = []

    for i in range(len(masses) - 1):
        mass1, mass2 = masses[i], masses[i+1]
        m1_1, m1_2 = m1[i], m1[i+1]
        m2_1, m2_2 = m2[i], m2[i+1]

        # Interpolate mass values
        interp_masses = np.linspace(mass1, mass2, num=num_interp+2)[1:-1]
        interp_m1 = np.linspace(m1_1, m1_2, num=num_interp+2)[1:-1]
        interp_m2 = np.linspace(m2_1, m2_2, num=num_interp+2)[1:-1]

        for m, im1, im2 in zip(interp_masses, interp_m1, interp_m2):
            interp_data.append((m, im1, im2, False))  # False = interpolated

    # Add original points
    for i in range(len(masses)):
        interp_data.append((masses[i], m1[i], m2[i], True))  # True = original

    # Convert to structured array
    interp_data = sorted(interp_data, key=lambda x: x[0])
    dtype = [('mass', float), ('m_jwst_F162M', float), ('m_jwst_F182M', float), ('is_original', bool)]
    interp_array = np.array(interp_data, dtype=dtype)
    return interp_array

# --- Apply Dereddening ---
def apply_dereddening(mags, AKs, wavelengths):
    return [
        m - red_law.Cardelli89(wavelengths[filters[i]], AKs)
        for i, m in enumerate(mags)
    ]

# --- Compute Errors ---
def calculate_errors(errs):
    color_err = np.sqrt(errs[0]**2 + errs[1]**2)
    mag_err = errs[1]
    return color_err, mag_err

# --- Plotting Function ---
def plot_cmd_and_mmd(interp_table, dered_mags, errors, title):
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    ax_cmd, ax_mmd = axes
    m162_d, m182_d = dered_mags
    color_err, mag_err = errors

    # Split by origin
    original = interp_table[interp_table['is_original']]
    interp = interp_table[~interp_table['is_original']]

    # === Color-Magnitude Diagram (CMD) ===
    colors_orig = original['m_jwst_F162M'] - original['m_jwst_F182M']
    mags_orig = original['m_jwst_F182M']
    colors_interp = interp['m_jwst_F162M'] - interp['m_jwst_F182M']
    mags_interp = interp['m_jwst_F182M']

    ax_cmd.plot(colors_orig, mags_orig, 'ro', markersize=3, label='Original')
    ax_cmd.plot(colors_interp, mags_interp, 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_cmd.errorbar(m162_d - m182_d, m182_d, xerr=color_err, yerr=mag_err,
                    fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_cmd.set_xlabel("F162M - F182M")
    ax_cmd.set_ylabel("F182M")
    ax_cmd.invert_yaxis()
    ax_cmd.set_title("Color-Magnitude Diagram")
    ax_cmd.grid(True)
    ax_cmd.legend()

    # === Magnitude-Magnitude Diagram (MMD) ===
    ax_mmd.plot(original['m_jwst_F162M'], original['m_jwst_F182M'], 'ro', markersize=3, label='Original')
    ax_mmd.plot(interp['m_jwst_F162M'], interp['m_jwst_F182M'], 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_mmd.errorbar(m162_d, m182_d, xerr=errs[0], yerr=errs[1],
                    fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_mmd.set_xlabel("F162M")
    ax_mmd.set_ylabel("F182M")
    ax_mmd.invert_yaxis()
    ax_mmd.invert_xaxis()
    ax_mmd.set_title("Magnitude–Magnitude Diagram")
    ax_mmd.grid(True)
    ax_mmd.legend()

    fig.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()
    
    # --- Load star data from .dat file ---
def load_dat_star_data(dat_path, index=0):
    """
    Load photometry, errors, AV, and mass from a space-delimited .dat file.
    Skips the first two columns (assumed to be positional data).
    Returns:
        mags: list of observed magnitudes [F162M, F182M]
        errs: list of associated uncertainties
        av: extinction A(V)
        mass: estimated stellar mass
    """
    with open(dat_path, 'r') as f:
        lines = f.readlines()

    line = lines[index].strip().split()
    line = [float(x) for x in line]

    # Extract photometry and errors
    f162m, err_f162m = line[2], line[3]
    f182m, err_f182m = line[4], line[5]
    # f200m, err_f200m = line[6], line[7]  # Not used here, but available

    av = line[8]
    mass = line[9]

    mags = [f162m, f182m]
    errs = [err_f162m, err_f182m]
    return mags, errs, av, mass

# %%
# === Read data ===
dat_path = '/scratch/wyz5rge/synthetic-hr/notebooks/2025/01-28_chi-square-reverse-modeling/winstonlist.dat'
mags, errs, av_true, mass_true = load_dat_star_data(dat_path, star_index)

# === Automate AKs selection ===
import scipy.optimize

# --- Compute sum of squared differences between dereddened point and isochrone ---
def compute_total_squared_distance(dered_mags, interp_table):
    # Color-magnitude of observed star
    color_obs = dered_mags[0] - dered_mags[1]  # F162M - F182M
    mag_obs = dered_mags[1]                   # F182M

    # Isochrone in CMD space using correct column names
    color_iso = interp_table['m_jwst_F162M'] - interp_table['m_jwst_F182M']
    mag_iso = interp_table['m_jwst_F182M']

    d_color = color_iso - color_obs
    d_mag = mag_iso - mag_obs
    distances_squared = d_color**2 + d_mag**2

    return np.min(distances_squared)

# --- Objective function to minimize ---
def objective(aks_trial, mags):
    aks_trial = float(np.squeeze(aks_trial))  # ensures scalar
    dered = apply_dereddening(mags, aks_trial, filter_wavelengths)
    # Return squared distance in color–magnitude space
    return compute_total_squared_distance(dered, interp_table)

# === Main execution (automated AKs) ===
from scipy.optimize import minimize_scalar

# Step 1: Generate unreddened isochrone and interpolate
iso_unredd = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                                     metallicity=metallicity,
                                     evo_model=evo_model, atm_func=atm_func,
                                     red_law=red_law, filters=filt_list,
                                     iso_dir=iso_dir)
interp_table = interpolate_isochrone(iso_unredd, num_interp=10)

# Step 2: Minimize AKs
aks_result = minimize_scalar(objective, bounds=(0.0, 3.0), args=(mags,), method='bounded')
print("aks_result.x type:", type(aks_result.x), "value:", aks_result.x)
AKs_val = float(np.squeeze(aks_result.x))
AV_val = AKs_val * AV_to_AKs
print(f"Best-fit AKs: {AKs_val:.3f}, AV: {AV_val:.3f}")

# Step 3: Plot sum of squares vs AKs (for visualization)
ak_grid = np.linspace(0.0, 3.0, 100)
sq_vals = [objective(ak, mags) for ak in ak_grid]
plt.figure(figsize=(8,5))
plt.plot(ak_grid, sq_vals, label='Sum of Squared Distances')
plt.axvline(AKs_val, color='r', linestyle='--', label=f'Best AKs = {AKs_val:.3f}')
plt.xlabel("AKs")
plt.ylabel("Min Squared Distance to Isochrone")
plt.title("AKs Optimization")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Step 4: Deredden mags and replot CMD/MMD with optimal AKs
dered_mags = apply_dereddening(mags, AKs_val, filter_wavelengths)
errors = calculate_errors(errs)
plot_cmd_and_mmd(interp_table, dered_mags, errors, f"Automated AV Fit: AV={AV_val:.2f}")

# Generate isochrone and interpolate
iso = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                               metallicity=metallicity,
                               evo_model=evo_model, atm_func=atm_func,
                               red_law=red_law, filters=filt_list,
                               iso_dir=iso_dir)

interp_table = interpolate_isochrone(iso, num_interp=10)
# Out:
# aks_result.x type: <class 'numpy.float64'> value: 0.8360467217689439
# Best-fit AKs: 0.836, AV: 7.091

# %%
delta_AV = 5.0
AKs_margin = delta_AV / AV_to_AKs  # ≈ 0.59
AKs_low = max(0.0, AKs_val - AKs_margin)
AKs_high = AKs_val + AKs_margin
AKs_grid = np.arange(AKs_low, AKs_high + 0.001, 0.1 / AV_to_AKs)  # ≈ 0.012 steps

print(f"AKs grid: from {AKs_low:.3f} to {AKs_high:.3f} with {len(AKs_grid)} steps")

def chi_squared_grid(AKs_grid, mags, errs):
    results = []

    for aks in AKs_grid:
        iso = synthetic.IsochronePhot(log_age_arr[0], AKs=aks, distance=dist,
                                      metallicity=metallicity,
                                      evo_model=evo_model, atm_func=atm_func,
                                      red_law=red_law, filters=filt_list,
                                      iso_dir=iso_dir)
        interp = interpolate_isochrone(iso, num_interp=10)
        for entry in interp:
            model_mags = [entry[f] for f in filters]
            chi_sq = sum(
                ((mags[i] - model_mags[i]) ** 2) / max(errs[i] ** 2, 1e-3)
                for i in range(len(mags))
            ) / (len(mags) - 1)
            results.append({
                "AKs": aks,
                "AV": aks * AV_to_AKs,
                "mass": entry['mass'],
                "chi2": chi_sq
            })
    return results

grid_results = chi_squared_grid(AKs_grid, mags, errs)
grid_results_sorted = sorted(grid_results, key=lambda x: x["chi2"])

best_fit = grid_results_sorted[0]
print("\n=== Best Fit from Grid Search ===")
print(f"AV: {best_fit['AV']:.3f}")
print(f"AKs: {best_fit['AKs']:.3f}")
print(f"Mass: {best_fit['mass']:.4f} M☉")
print(f"Reduced χ²: {best_fit['chi2']:.4f}")

# Optional: top 5
print("\nTop 5 Fits:")
for r in grid_results_sorted[:5]:
    print(f"AV={r['AV']:.3f}, Mass={r['mass']:.4f}, χ²={r['chi2']:.4f}")
# Out:
# AKs grid: from 0.247 to 1.426 with 101 steps
# Isochrone generation took 1.251147 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.25  dist = 4500
#      Starting at:  2025-07-27 23:45:48.340273   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.39
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.50
#       Time taken: 1.33 seconds
# Isochrone generation took 1.212901 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.26  dist = 4500
#      Starting at:  2025-07-27 23:45:50.899326   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.40
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.52
#       Time taken: 1.33 seconds
# Isochrone generation took 1.221931 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.27  dist = 4500
#      Starting at:  2025-07-27 23:45:53.466315   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.42
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.53
#       Time taken: 1.35 seconds
# Isochrone generation took 1.227423 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.28  dist = 4500
#      Starting at:  2025-07-27 23:45:56.068515   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.44
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.55
#       Time taken: 1.32 seconds
# Isochrone generation took 1.218111 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.29  dist = 4500
#      Starting at:  2025-07-27 23:45:58.628943   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.46
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.56
#       Time taken: 1.32 seconds
# Isochrone generation took 1.211183 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.31  dist = 4500
#      Starting at:  2025-07-27 23:46:01.179119   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.48
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.58
#       Time taken: 1.31 seconds
# Isochrone generation took 1.284401 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.32  dist = 4500
#      Starting at:  2025-07-27 23:46:03.793968   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.50
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.60
#       Time taken: 1.32 seconds
# Isochrone generation took 1.219029 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.33  dist = 4500
#      Starting at:  2025-07-27 23:46:06.353905   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.52
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.61
#       Time taken: 1.34 seconds
# Isochrone generation took 1.244285 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.34  dist = 4500
#      Starting at:  2025-07-27 23:46:08.962158   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.54
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.63
#       Time taken: 1.32 seconds
# Isochrone generation took 1.233153 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.35  dist = 4500
#      Starting at:  2025-07-27 23:46:11.533979   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.55
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.64
#       Time taken: 1.35 seconds
# Isochrone generation took 1.222498 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.36  dist = 4500
#      Starting at:  2025-07-27 23:46:14.122392   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.57
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.66
#       Time taken: 1.32 seconds
# Isochrone generation took 1.226268 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.38  dist = 4500
#      Starting at:  2025-07-27 23:46:16.685965   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.59
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.67
#       Time taken: 1.31 seconds
# Isochrone generation took 1.220298 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.39  dist = 4500
#      Starting at:  2025-07-27 23:46:19.238348   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.69
#       Time taken: 1.32 seconds
# Isochrone generation took 1.220372 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.40  dist = 4500
#      Starting at:  2025-07-27 23:46:21.799719   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.63
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.71
#       Time taken: 1.32 seconds
# Isochrone generation took 1.223380 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.41  dist = 4500
#      Starting at:  2025-07-27 23:46:24.359438   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.65
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.72
#       Time taken: 1.32 seconds
# Isochrone generation took 1.220473 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.42  dist = 4500
#      Starting at:  2025-07-27 23:46:26.921991   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.67
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.74
#       Time taken: 1.34 seconds
# Isochrone generation took 1.267534 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.44  dist = 4500
#      Starting at:  2025-07-27 23:46:29.547353   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.69
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.75
#       Time taken: 1.33 seconds
# Isochrone generation took 1.221762 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.45  dist = 4500
#      Starting at:  2025-07-27 23:46:32.118108   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.70
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.77
#       Time taken: 1.32 seconds
# Isochrone generation took 1.222098 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.46  dist = 4500
#      Starting at:  2025-07-27 23:46:34.682695   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.72
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.78
#       Time taken: 1.32 seconds
# Isochrone generation took 1.221914 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.47  dist = 4500
#      Starting at:  2025-07-27 23:46:37.241997   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.74
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.80
#       Time taken: 1.33 seconds
# Isochrone generation took 1.225977 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.48  dist = 4500
#      Starting at:  2025-07-27 23:46:39.813874   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.76
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.81
#       Time taken: 1.34 seconds
# Isochrone generation took 1.223682 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.49  dist = 4500
#      Starting at:  2025-07-27 23:46:42.396732   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.78
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.83
#       Time taken: 1.31 seconds
# Isochrone generation took 1.221323 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.51  dist = 4500
#      Starting at:  2025-07-27 23:46:44.945823   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.80
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.85
#       Time taken: 1.33 seconds
# Isochrone generation took 1.223652 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.52  dist = 4500
#      Starting at:  2025-07-27 23:46:47.515245   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.82
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.86
#       Time taken: 1.32 seconds
# Isochrone generation took 1.218497 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.53  dist = 4500
#      Starting at:  2025-07-27 23:46:50.068391   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.88
#       Time taken: 1.31 seconds
# Isochrone generation took 1.221253 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.54  dist = 4500
#      Starting at:  2025-07-27 23:46:52.619439   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.85
# Starting filter: jwst,F182M   Elapsed time: 0.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.89
#       Time taken: 1.40 seconds
# Isochrone generation took 1.227712 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.55  dist = 4500
#      Starting at:  2025-07-27 23:46:55.270214   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.87
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.91
#       Time taken: 1.32 seconds
# Isochrone generation took 1.226555 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.56  dist = 4500
#      Starting at:  2025-07-27 23:46:57.834410   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.89
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.92
#       Time taken: 1.31 seconds
# Isochrone generation took 1.229718 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.58  dist = 4500
#      Starting at:  2025-07-27 23:47:00.397467   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.91
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.94
#       Time taken: 1.32 seconds
# Isochrone generation took 1.228583 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.59  dist = 4500
#      Starting at:  2025-07-27 23:47:02.962839   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.93
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.95
#       Time taken: 1.34 seconds
# Isochrone generation took 1.185141 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.60  dist = 4500
#      Starting at:  2025-07-27 23:47:05.509868   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.95
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.97
#       Time taken: 1.32 seconds
# Isochrone generation took 1.223057 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.61  dist = 4500
#      Starting at:  2025-07-27 23:47:08.075147   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.97
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.99
#       Time taken: 1.32 seconds
# Isochrone generation took 1.239394 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.62  dist = 4500
#      Starting at:  2025-07-27 23:47:10.657410   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.00
#       Time taken: 1.32 seconds
# Isochrone generation took 1.231793 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.64  dist = 4500
#      Starting at:  2025-07-27 23:47:13.231430   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.00
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.02
#       Time taken: 1.32 seconds
# Isochrone generation took 1.228781 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.65  dist = 4500
#      Starting at:  2025-07-27 23:47:15.795004   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.02
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.03
#       Time taken: 1.32 seconds
# Isochrone generation took 1.300296 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.66  dist = 4500
#      Starting at:  2025-07-27 23:47:18.437555   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.04
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.05
#       Time taken: 1.34 seconds
# Isochrone generation took 1.221516 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.67  dist = 4500
#      Starting at:  2025-07-27 23:47:21.018896   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.06
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.06
#       Time taken: 1.31 seconds
# Isochrone generation took 1.222284 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.68  dist = 4500
#      Starting at:  2025-07-27 23:47:23.571919   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.08
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.08
#       Time taken: 1.31 seconds
# Isochrone generation took 1.225015 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.69  dist = 4500
#      Starting at:  2025-07-27 23:47:26.129250   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.10
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.09
#       Time taken: 1.32 seconds
# Isochrone generation took 1.237651 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.71  dist = 4500
#      Starting at:  2025-07-27 23:47:28.705356   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.12
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.11
#       Time taken: 1.32 seconds
# Isochrone generation took 1.225272 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.72  dist = 4500
#      Starting at:  2025-07-27 23:47:31.272917   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.13
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.13
#       Time taken: 1.33 seconds
# Isochrone generation took 1.228480 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.73  dist = 4500
#      Starting at:  2025-07-27 23:47:33.847622   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.15
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.14
#       Time taken: 1.31 seconds
# Isochrone generation took 1.220167 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.74  dist = 4500
#      Starting at:  2025-07-27 23:47:36.402429   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.16
#       Time taken: 1.34 seconds
# Isochrone generation took 1.224854 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.75  dist = 4500
#      Starting at:  2025-07-27 23:47:38.982455   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.19
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.17
#       Time taken: 1.32 seconds
# Isochrone generation took 1.219758 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.77  dist = 4500
#      Starting at:  2025-07-27 23:47:41.537252   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.21
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.19
#       Time taken: 1.31 seconds
# Isochrone generation took 1.218758 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.78  dist = 4500
#      Starting at:  2025-07-27 23:47:44.083946   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.23
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.20
#       Time taken: 1.37 seconds
# Isochrone generation took 1.223161 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.79  dist = 4500
#      Starting at:  2025-07-27 23:47:46.695452   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.25
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.22
#       Time taken: 1.32 seconds
# Isochrone generation took 1.231229 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.80  dist = 4500
#      Starting at:  2025-07-27 23:47:49.266944   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.26
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.23
#       Time taken: 1.33 seconds
# Isochrone generation took 1.226545 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.81  dist = 4500
#      Starting at:  2025-07-27 23:47:51.842873   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.28
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.25
#       Time taken: 1.31 seconds
# Isochrone generation took 1.227866 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.84  dist = 4500
#      Starting at:  2025-07-27 23:47:54.424832   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.28
#       Time taken: 1.32 seconds
# Isochrone generation took 1.229645 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.91  dist = 4500
#      Starting at:  2025-07-27 23:47:57.097832   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.43
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.37
#       Time taken: 1.32 seconds
# Isochrone generation took 1.226727 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.97  dist = 4500
#      Starting at:  2025-07-27 23:47:59.749830   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.53
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.45
#       Time taken: 1.32 seconds
# Isochrone generation took 1.226891 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.04  dist = 4500
#      Starting at:  2025-07-27 23:48:02.425899   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.64
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.54
#       Time taken: 1.32 seconds
# Isochrone generation took 1.223710 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.10  dist = 4500
#      Starting at:  2025-07-27 23:48:05.074391   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.73
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.62
#       Time taken: 1.32 seconds
# Isochrone generation took 1.234122 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.17  dist = 4500
#      Starting at:  2025-07-27 23:48:07.756667   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.84
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.72
#       Time taken: 1.35 seconds
# Isochrone generation took 1.236998 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.24  dist = 4500
#      Starting at:  2025-07-27 23:48:10.471069   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.96
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.81
#       Time taken: 1.33 seconds
# Isochrone generation took 1.305683 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.30  dist = 4500
#      Starting at:  2025-07-27 23:48:13.213194   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.05
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.89
#       Time taken: 1.33 seconds
# Isochrone generation took 1.225403 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.37  dist = 4500
#      Starting at:  2025-07-27 23:48:15.900115   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.16
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.98
#       Time taken: 1.32 seconds
# Isochrone generation took 1.222771 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.43  dist = 4500
#      Starting at:  2025-07-27 23:48:18.545306   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.06
#       Time taken: 1.32 seconds
#
# === Best Fit from Grid Search ===
# AV: 6.991
# AKs: 0.824
# Mass: 0.3091 M☉
# Reduced χ²: 0.0077
#
# Top 5 Fits:
# AV=6.991, Mass=0.3091, χ²=0.0077
# AV=7.191, Mass=0.3182, χ²=0.0485
# AV=6.791, Mass=0.3000, χ²=0.0791
# AV=7.391, Mass=0.3273, χ²=0.1745
# AV=7.091, Mass=0.3182, χ²=0.2308

# %%
print(f"Estimated AV:    {best_fit['AV']:.3f}, Estimated Mass:  {best_fit['mass']:.4f} M☉")
print(f"Ground-truth AV: {av_true:.3f}, Ground-truth Mass: {mass_true:.4f} M☉")
# Out:
# Estimated AV:    6.991, Estimated Mass:  0.3091 M☉
# Ground-truth AV: 7.162, Ground-truth Mass: 0.2915 M☉

# %%
top = grid_results_sorted[:100]
avs = [r['AV'] for r in top]
masses = [r['mass'] for r in top]
chis = [r['chi2'] for r in top]

plt.figure(figsize=(8,6))
sc = plt.scatter(avs, masses, c=chis, cmap='viridis', norm=LogNorm())
plt.colorbar(sc, label="Reduced χ²")
plt.xlabel("AV")
plt.ylabel("Mass (M☉)")
plt.title("Top 100 Fits: AV vs Mass")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# --- Plot A_V ---
plt.figure(figsize=(4, 4))
labels = ['Ground Truth', 'Estimated']
av_values = [av_true, best_fit['AV']]
x = range(len(labels))

plt.bar(x, av_values, color=['gray', 'skyblue'])
plt.xticks(x, labels)
plt.ylabel('A_V')
plt.title('Estimated vs Ground Truth A_V')

# Annotate bars
for i, val in enumerate(av_values):
    plt.text(i, val + 0.05, f'{val:.3f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# --- Plot Mass ---
plt.figure(figsize=(4, 4))
mass_values = [mass_true, best_fit['mass']]

plt.bar(x, mass_values, color=['gray', 'skyblue'])
plt.xticks(x, labels)
plt.ylabel('Mass (M☉)')
plt.title('Estimated vs Ground Truth Mass')

# Annotate bars
for i, val in enumerate(mass_values):
    plt.text(i, val + 0.01, f'{val:.4f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()
