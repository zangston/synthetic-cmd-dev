# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening
from matplotlib.colors import LogNorm
import csv
from scipy.stats import chi2
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
# === Setup ===
iso_dir = 'isochrones/'
# output_dir = 'output_diagrams/'
# os.makedirs(output_dir, exist_ok=True)

# --- Static Parameters ---
star_index = 4
dist = 4500
metallicity = 0
log_age_arr = np.log10([1e6])  # 1 Myr

# Models
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)

# Filters
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']

filter_wavelengths = {
    "m_jwst_F162M": 1.62,
    "m_jwst_F182M": 1.82,
    "m_jwst_F200W": 2.00,
    "m_jwst_F356M": 3.56,
    "m_jwst_F405N": 4.05
}

# Conversion constant from SPISEA/Cardelli (1989) with Rv = 3.1
AV_to_AKs = 1.0 / 0.1179  # ≈ 8.479

# %%
# --- Load star data ---
def load_star_data(csv_path, index=0):
    sample_mags, sample_errs = [], []
    with open(csv_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)
        for line in reader:
            mags = [float(line[i]) for i in range(1, len(line), 2)]
            errs = [float(line[i]) for i in range(2, len(line), 2)]
            sample_mags.append(mags)
            sample_errs.append(errs)
    return sample_mags[index][:2], sample_errs[index][:2]

# --- Interpolate Isochrone Points ---
def interpolate_isochrone(isochrone, num_interp=10):
    masses = isochrone.points['mass']
    m1 = isochrone.points['m_jwst_F162M']
    m2 = isochrone.points['m_jwst_F182M']

    # Collect original + interpolated points
    interp_data = []

    for i in range(len(masses) - 1):
        mass1, mass2 = masses[i], masses[i+1]
        m1_1, m1_2 = m1[i], m1[i+1]
        m2_1, m2_2 = m2[i], m2[i+1]

        # Interpolate mass values
        interp_masses = np.linspace(mass1, mass2, num=num_interp+2)[1:-1]
        interp_m1 = np.linspace(m1_1, m1_2, num=num_interp+2)[1:-1]
        interp_m2 = np.linspace(m2_1, m2_2, num=num_interp+2)[1:-1]

        for m, im1, im2 in zip(interp_masses, interp_m1, interp_m2):
            interp_data.append((m, im1, im2, False))  # False = interpolated

    # Add original points
    for i in range(len(masses)):
        interp_data.append((masses[i], m1[i], m2[i], True))  # True = original

    # Convert to structured array
    interp_data = sorted(interp_data, key=lambda x: x[0])
    dtype = [('mass', float), ('m_jwst_F162M', float), ('m_jwst_F182M', float), ('is_original', bool)]
    interp_array = np.array(interp_data, dtype=dtype)
    return interp_array

# --- Apply Dereddening ---
def apply_dereddening(mags, AKs, wavelengths):
    return [
        m - red_law.Cardelli89(wavelengths[filters[i]], AKs)
        for i, m in enumerate(mags)
    ]

# --- Compute Errors ---
def calculate_errors(errs):
    color_err = np.sqrt(errs[0]**2 + errs[1]**2)
    mag_err = errs[1]
    return color_err, mag_err

# --- Plotting Function ---
def plot_cmd_and_mmd(interp_table, dered_mags, errors, title):
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    ax_cmd, ax_mmd = axes
    m162_d, m182_d = dered_mags
    color_err, mag_err = errors

    # Split by origin
    original = interp_table[interp_table['is_original']]
    interp = interp_table[~interp_table['is_original']]

    # === Color-Magnitude Diagram (CMD) ===
    colors_orig = original['m_jwst_F162M'] - original['m_jwst_F182M']
    mags_orig = original['m_jwst_F182M']
    colors_interp = interp['m_jwst_F162M'] - interp['m_jwst_F182M']
    mags_interp = interp['m_jwst_F182M']

    ax_cmd.plot(colors_orig, mags_orig, 'ro', markersize=3, label='Original')
    ax_cmd.plot(colors_interp, mags_interp, 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_cmd.errorbar(m162_d - m182_d, m182_d, xerr=color_err, yerr=mag_err,
                    fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_cmd.set_xlabel("F162M - F182M")
    ax_cmd.set_ylabel("F182M")
    ax_cmd.invert_yaxis()
    ax_cmd.set_title("Color-Magnitude Diagram")
    ax_cmd.grid(True)
    ax_cmd.legend()

    # === Magnitude-Magnitude Diagram (MMD) ===
    ax_mmd.plot(original['m_jwst_F162M'], original['m_jwst_F182M'], 'ro', markersize=3, label='Original')
    ax_mmd.plot(interp['m_jwst_F162M'], interp['m_jwst_F182M'], 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_mmd.errorbar(m162_d, m182_d, xerr=errs[0], yerr=errs[1],
                    fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_mmd.set_xlabel("F162M")
    ax_mmd.set_ylabel("F182M")
    ax_mmd.invert_yaxis()
    ax_mmd.invert_xaxis()
    ax_mmd.set_title("Magnitude–Magnitude Diagram")
    ax_mmd.grid(True)
    ax_mmd.legend()

    fig.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()
    
    # --- Load star data from .dat file ---
def load_dat_star_data(dat_path, index=0):
    """
    Load photometry, errors, AV, and mass from a space-delimited .dat file.
    Skips the first two columns (assumed to be positional data).
    Returns:
        mags: list of observed magnitudes [F162M, F182M]
        errs: list of associated uncertainties
        av: extinction A(V)
        mass: estimated stellar mass
    """
    with open(dat_path, 'r') as f:
        lines = f.readlines()

    line = lines[index].strip().split()
    line = [float(x) for x in line]

    # Extract photometry and errors
    f162m, err_f162m = line[2], line[3]
    f182m, err_f182m = line[4], line[5]
    # f200m, err_f200m = line[6], line[7]  # Not used here, but available

    av = line[8]
    mass = line[9]

    mags = [f162m, f182m]
    errs = [err_f162m, err_f182m]
    return mags, errs, av, mass

# %%
# === Read data ===
dat_path = '/scratch/wyz5rge/synthetic-hr/notebooks/2025/01-28_chi-square-reverse-modeling/winstonlist.dat'
mags, errs, av_true, mass_true = load_dat_star_data(dat_path, star_index)

# === Automate AKs selection ===
import scipy.optimize

# --- Compute sum of squared differences between dereddened point and isochrone ---
def compute_total_squared_distance(dered_mags, interp_table):
    # Color-magnitude of observed star
    color_obs = dered_mags[0] - dered_mags[1]  # F162M - F182M
    mag_obs = dered_mags[1]                   # F182M

    # Isochrone in CMD space using correct column names
    color_iso = interp_table['m_jwst_F162M'] - interp_table['m_jwst_F182M']
    mag_iso = interp_table['m_jwst_F182M']

    d_color = color_iso - color_obs
    d_mag = mag_iso - mag_obs
    distances_squared = d_color**2 + d_mag**2

    return np.min(distances_squared)

# --- Objective function to minimize ---
def objective(aks_trial, mags):
    aks_trial = float(np.squeeze(aks_trial))  # ensures scalar
    dered = apply_dereddening(mags, aks_trial, filter_wavelengths)
    # Return squared distance in color–magnitude space
    return compute_total_squared_distance(dered, interp_table)

# === Main execution (automated AKs) ===
from scipy.optimize import minimize_scalar

# Step 1: Generate unreddened isochrone and interpolate
iso_unredd = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                                     metallicity=metallicity,
                                     evo_model=evo_model, atm_func=atm_func,
                                     red_law=red_law, filters=filt_list,
                                     iso_dir=iso_dir)
interp_table = interpolate_isochrone(iso_unredd, num_interp=10)

# Step 2: Minimize AKs
aks_result = minimize_scalar(objective, bounds=(0.0, 3.0), args=(mags,), method='bounded')
print("aks_result.x type:", type(aks_result.x), "value:", aks_result.x)
AKs_val = float(np.squeeze(aks_result.x))
AV_val = AKs_val * AV_to_AKs
print(f"Best-fit AKs: {AKs_val:.3f}, AV: {AV_val:.3f}")

# Step 3: Plot sum of squares vs AKs (for visualization)
ak_grid = np.linspace(0.0, 3.0, 100)
sq_vals = [objective(ak, mags) for ak in ak_grid]
plt.figure(figsize=(8,5))
plt.plot(ak_grid, sq_vals, label='Sum of Squared Distances')
plt.axvline(AKs_val, color='r', linestyle='--', label=f'Best AKs = {AKs_val:.3f}')
plt.xlabel("AKs")
plt.ylabel("Min Squared Distance to Isochrone")
plt.title("AKs Optimization")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Step 4: Deredden mags and replot CMD/MMD with optimal AKs
dered_mags = apply_dereddening(mags, AKs_val, filter_wavelengths)
errors = calculate_errors(errs)
plot_cmd_and_mmd(interp_table, dered_mags, errors, f"Automated AV Fit: AV={AV_val:.2f}")

# Generate isochrone and interpolate
iso = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                               metallicity=metallicity,
                               evo_model=evo_model, atm_func=atm_func,
                               red_law=red_law, filters=filt_list,
                               iso_dir=iso_dir)

interp_table = interpolate_isochrone(iso, num_interp=10)
# Out:
# Isochrone generation took 1.210047 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2025-07-27 23:35:25.538533   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
#       Time taken: 1.30 seconds
# aks_result.x type: <class 'numpy.float64'> value: 1.4116410109273518
# Best-fit AKs: 1.412, AV: 11.973

# %%
delta_AV = 5.0
AKs_margin = delta_AV / AV_to_AKs  # ≈ 0.59
AKs_low = max(0.0, AKs_val - AKs_margin)
AKs_high = AKs_val + AKs_margin
AKs_grid = np.arange(AKs_low, AKs_high + 0.001, 0.1 / AV_to_AKs)  # ≈ 0.012 steps

print(f"AKs grid: from {AKs_low:.3f} to {AKs_high:.3f} with {len(AKs_grid)} steps")

def chi_squared_grid(AKs_grid, mags, errs):
    results = []

    for aks in AKs_grid:
        iso = synthetic.IsochronePhot(log_age_arr[0], AKs=aks, distance=dist,
                                      metallicity=metallicity,
                                      evo_model=evo_model, atm_func=atm_func,
                                      red_law=red_law, filters=filt_list,
                                      iso_dir=iso_dir)
        interp = interpolate_isochrone(iso, num_interp=10)
        for entry in interp:
            model_mags = [entry[f] for f in filters]
            chi_sq = sum(
                ((mags[i] - model_mags[i]) ** 2) / max(errs[i] ** 2, 1e-3)
                for i in range(len(mags))
            ) / (len(mags) - 1)
            results.append({
                "AKs": aks,
                "AV": aks * AV_to_AKs,
                "mass": entry['mass'],
                "chi2": chi_sq
            })
    return results

grid_results = chi_squared_grid(AKs_grid, mags, errs)
grid_results_sorted = sorted(grid_results, key=lambda x: x["chi2"])

best_fit = grid_results_sorted[0]
print("\n=== Best Fit from Grid Search ===")
print(f"AV: {best_fit['AV']:.3f}")
print(f"AKs: {best_fit['AKs']:.3f}")
print(f"Mass: {best_fit['mass']:.4f} M☉")
print(f"Reduced χ²: {best_fit['chi2']:.4f}")

# Optional: top 5
print("\nTop 5 Fits:")
for r in grid_results_sorted[:5]:
    print(f"AV={r['AV']:.3f}, Mass={r['mass']:.4f}, χ²={r['chi2']:.4f}")
# Out:
# AKs grid: from 0.822 to 2.001 with 101 steps
# Isochrone generation took 1.200702 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.82  dist = 4500
#      Starting at:  2025-07-27 23:35:28.950155   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.30
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.26
#       Time taken: 1.30 seconds
# Isochrone generation took 1.197911 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.83  dist = 4500
#      Starting at:  2025-07-27 23:35:31.471752   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.28
#       Time taken: 1.32 seconds
# Isochrone generation took 1.197135 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.85  dist = 4500
#      Starting at:  2025-07-27 23:35:34.004831   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.34
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.29
#       Time taken: 1.31 seconds
# Isochrone generation took 1.197032 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.86  dist = 4500
#      Starting at:  2025-07-27 23:35:36.533355   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.35
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.31
#       Time taken: 1.31 seconds
# Isochrone generation took 1.161958 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.87  dist = 4500
#      Starting at:  2025-07-27 23:35:39.023970   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.37
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.32
#       Time taken: 1.31 seconds
# Isochrone generation took 1.277808 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.88  dist = 4500
#      Starting at:  2025-07-27 23:35:41.631493   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.39
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.34
#       Time taken: 1.31 seconds
# Isochrone generation took 1.198874 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.89  dist = 4500
#      Starting at:  2025-07-27 23:35:44.155397   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.41
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.36
#       Time taken: 1.31 seconds
# Isochrone generation took 1.197583 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.90  dist = 4500
#      Starting at:  2025-07-27 23:35:46.684192   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.43
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.37
#       Time taken: 1.32 seconds
# Isochrone generation took 1.167407 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.92  dist = 4500
#      Starting at:  2025-07-27 23:35:49.194781   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.39
#       Time taken: 1.31 seconds
# Isochrone generation took 1.198512 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.93  dist = 4500
#      Starting at:  2025-07-27 23:35:51.719101   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.47
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.40
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200164 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.94  dist = 4500
#      Starting at:  2025-07-27 23:35:54.252088   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.49
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.42
#       Time taken: 1.30 seconds
# Isochrone generation took 1.199258 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.95  dist = 4500
#      Starting at:  2025-07-27 23:35:56.770266   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.50
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.43
#       Time taken: 1.30 seconds
# Isochrone generation took 1.199475 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.96  dist = 4500
#      Starting at:  2025-07-27 23:35:59.288304   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.52
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.45
#       Time taken: 1.30 seconds
# Isochrone generation took 1.201350 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.98  dist = 4500
#      Starting at:  2025-07-27 23:36:01.811839   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.54
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.46
#       Time taken: 1.31 seconds
# Isochrone generation took 1.201550 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.99  dist = 4500
#      Starting at:  2025-07-27 23:36:04.341869   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.56
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.48
#       Time taken: 1.30 seconds
# Isochrone generation took 1.196293 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.00  dist = 4500
#      Starting at:  2025-07-27 23:36:06.862373   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.58
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.50
#       Time taken: 1.32 seconds
# Isochrone generation took 1.286014 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.01  dist = 4500
#      Starting at:  2025-07-27 23:36:09.487229   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.60
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.51
#       Time taken: 1.31 seconds
# Isochrone generation took 1.207116 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.02  dist = 4500
#      Starting at:  2025-07-27 23:36:12.027960   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.62
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.53
#       Time taken: 1.30 seconds
# Isochrone generation took 1.205392 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.03  dist = 4500
#      Starting at:  2025-07-27 23:36:14.552280   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.63
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.54
#       Time taken: 1.31 seconds
# Isochrone generation took 1.201214 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.05  dist = 4500
#      Starting at:  2025-07-27 23:36:17.078408   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.65
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.56
#       Time taken: 1.30 seconds
# Isochrone generation took 1.204086 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.06  dist = 4500
#      Starting at:  2025-07-27 23:36:19.605706   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.67
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.57
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202128 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.07  dist = 4500
#      Starting at:  2025-07-27 23:36:22.133438   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.69
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.59
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202637 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.08  dist = 4500
#      Starting at:  2025-07-27 23:36:24.665297   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.71
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.60
#       Time taken: 1.31 seconds
# Isochrone generation took 1.199347 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.09  dist = 4500
#      Starting at:  2025-07-27 23:36:27.193990   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.73
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.62
#       Time taken: 1.30 seconds
# Isochrone generation took 1.198139 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.11  dist = 4500
#      Starting at:  2025-07-27 23:36:29.706082   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.75
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.63
#       Time taken: 1.31 seconds
# Isochrone generation took 1.199574 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.12  dist = 4500
#      Starting at:  2025-07-27 23:36:32.233199   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.65
#       Time taken: 1.30 seconds
# Isochrone generation took 1.199082 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.13  dist = 4500
#      Starting at:  2025-07-27 23:36:34.749133   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.78
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.67
#       Time taken: 1.31 seconds
# Isochrone generation took 1.194994 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.14  dist = 4500
#      Starting at:  2025-07-27 23:36:37.268907   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.80
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.68
#       Time taken: 1.30 seconds
# Isochrone generation took 1.240189 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.15  dist = 4500
#      Starting at:  2025-07-27 23:36:39.830027   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.82
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.70
#       Time taken: 1.31 seconds
# Isochrone generation took 1.187516 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.16  dist = 4500
#      Starting at:  2025-07-27 23:36:42.342612   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.84
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.71
#       Time taken: 1.31 seconds
# Isochrone generation took 1.204267 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.18  dist = 4500
#      Starting at:  2025-07-27 23:36:44.877032   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.86
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.73
#       Time taken: 1.31 seconds
# Isochrone generation took 1.204762 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.19  dist = 4500
#      Starting at:  2025-07-27 23:36:47.410072   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.88
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.74
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202600 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.20  dist = 4500
#      Starting at:  2025-07-27 23:36:49.937311   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.90
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.76
#       Time taken: 1.30 seconds
# Isochrone generation took 1.207097 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.21  dist = 4500
#      Starting at:  2025-07-27 23:36:52.467642   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.91
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.77
#       Time taken: 1.31 seconds
# Isochrone generation took 1.201940 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.22  dist = 4500
#      Starting at:  2025-07-27 23:36:54.995518   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.79
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200027 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.23  dist = 4500
#      Starting at:  2025-07-27 23:36:57.523950   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.95
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.81
#       Time taken: 1.30 seconds
# Isochrone generation took 1.205279 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.25  dist = 4500
#      Starting at:  2025-07-27 23:37:00.048371   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.97
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.82
#       Time taken: 1.31 seconds
# Isochrone generation took 1.198607 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.26  dist = 4500
#      Starting at:  2025-07-27 23:37:02.572911   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.99
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.84
#       Time taken: 1.31 seconds
# Isochrone generation took 1.197290 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.27  dist = 4500
#      Starting at:  2025-07-27 23:37:05.094972   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.01
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.85
#       Time taken: 1.32 seconds
# Isochrone generation took 1.279102 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.28  dist = 4500
#      Starting at:  2025-07-27 23:37:07.711243   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.03
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.87
#       Time taken: 1.31 seconds
# Isochrone generation took 1.169543 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.29  dist = 4500
#      Starting at:  2025-07-27 23:37:10.209903   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.05
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.88
#       Time taken: 1.32 seconds
# Isochrone generation took 1.205408 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.31  dist = 4500
#      Starting at:  2025-07-27 23:37:12.756094   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.90
#       Time taken: 1.30 seconds
# Isochrone generation took 1.204181 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.32  dist = 4500
#      Starting at:  2025-07-27 23:37:15.278053   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.08
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.91
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200957 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.33  dist = 4500
#      Starting at:  2025-07-27 23:37:17.805879   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.10
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.93
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200754 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.34  dist = 4500
#      Starting at:  2025-07-27 23:37:20.337610   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.12
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.94
#       Time taken: 1.30 seconds
# Isochrone generation took 1.200545 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.35  dist = 4500
#      Starting at:  2025-07-27 23:37:22.859472   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.14
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.96
#       Time taken: 1.32 seconds
# Isochrone generation took 1.201576 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.36  dist = 4500
#      Starting at:  2025-07-27 23:37:25.400107   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.16
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.98
#       Time taken: 1.32 seconds
# Isochrone generation took 1.198458 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.38  dist = 4500
#      Starting at:  2025-07-27 23:37:27.941363   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.18
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.99
#       Time taken: 1.31 seconds
# Isochrone generation took 1.198264 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.39  dist = 4500
#      Starting at:  2025-07-27 23:37:30.464598   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.19
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.01
#       Time taken: 1.31 seconds
# Isochrone generation took 1.194036 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.40  dist = 4500
#      Starting at:  2025-07-27 23:37:32.990067   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.21
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.02
#       Time taken: 1.31 seconds
# Isochrone generation took 1.196481 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.41  dist = 4500
#      Starting at:  2025-07-27 23:37:35.511122   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.23
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.04
#       Time taken: 1.31 seconds
# Isochrone generation took 1.207638 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.42  dist = 4500
#      Starting at:  2025-07-27 23:37:38.050642   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.05
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200423 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.44  dist = 4500
#      Starting at:  2025-07-27 23:37:40.580913   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.27
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.07
#       Time taken: 1.30 seconds
# Isochrone generation took 1.197659 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.45  dist = 4500
#      Starting at:  2025-07-27 23:37:43.098849   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.08
#       Time taken: 1.31 seconds
# Isochrone generation took 1.210320 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.46  dist = 4500
#      Starting at:  2025-07-27 23:37:45.636993   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.31
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.10
#       Time taken: 1.31 seconds
# Isochrone generation took 1.201824 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.47  dist = 4500
#      Starting at:  2025-07-27 23:37:48.169190   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.33
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.12
#       Time taken: 1.31 seconds
# Isochrone generation took 1.210934 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.48  dist = 4500
#      Starting at:  2025-07-27 23:37:50.708643   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.34
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.13
#       Time taken: 1.31 seconds
# Isochrone generation took 1.199411 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.49  dist = 4500
#      Starting at:  2025-07-27 23:37:53.232758   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.36
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.15
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202652 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.51  dist = 4500
#      Starting at:  2025-07-27 23:37:55.767674   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.38
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.16
#       Time taken: 1.31 seconds
# Isochrone generation took 1.193962 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.52  dist = 4500
#      Starting at:  2025-07-27 23:37:58.294753   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.40
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.18
#       Time taken: 1.30 seconds
# Isochrone generation took 1.186954 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.53  dist = 4500
#      Starting at:  2025-07-27 23:38:00.799892   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.42
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.19
#       Time taken: 1.30 seconds
# Isochrone generation took 1.195923 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.54  dist = 4500
#      Starting at:  2025-07-27 23:38:03.319137   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.44
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.21
#       Time taken: 1.31 seconds
# Isochrone generation took 1.270543 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.55  dist = 4500
#      Starting at:  2025-07-27 23:38:05.914987   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.46
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.22
#       Time taken: 1.32 seconds
# Isochrone generation took 1.202926 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.56  dist = 4500
#      Starting at:  2025-07-27 23:38:08.456958   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.47
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.24
#       Time taken: 1.31 seconds
# Isochrone generation took 1.216386 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.58  dist = 4500
#      Starting at:  2025-07-27 23:38:11.002207   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.49
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.25
#       Time taken: 1.31 seconds
# Isochrone generation took 1.204891 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.59  dist = 4500
#      Starting at:  2025-07-27 23:38:13.533851   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.51
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.27
#       Time taken: 1.31 seconds
# Isochrone generation took 1.203363 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.60  dist = 4500
#      Starting at:  2025-07-27 23:38:16.062447   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.53
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.29
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202070 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.61  dist = 4500
#      Starting at:  2025-07-27 23:38:18.597916   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.55
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.30
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200320 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.62  dist = 4500
#      Starting at:  2025-07-27 23:38:21.124247   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.57
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.32
#       Time taken: 1.31 seconds
# Isochrone generation took 1.205155 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.64  dist = 4500
#      Starting at:  2025-07-27 23:38:23.654524   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.59
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.33
#       Time taken: 1.31 seconds
# Isochrone generation took 1.199713 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.65  dist = 4500
#      Starting at:  2025-07-27 23:38:26.187964   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.35
#       Time taken: 1.30 seconds
# Isochrone generation took 1.193049 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.66  dist = 4500
#      Starting at:  2025-07-27 23:38:28.703770   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.62
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.36
#       Time taken: 1.31 seconds
# Isochrone generation took 1.192417 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.67  dist = 4500
#      Starting at:  2025-07-27 23:38:31.223287   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.64
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.38
#       Time taken: 1.30 seconds
# Isochrone generation took 1.255584 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.68  dist = 4500
#      Starting at:  2025-07-27 23:38:33.797196   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.66
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.39
#       Time taken: 1.32 seconds
# Isochrone generation took 1.208162 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.69  dist = 4500
#      Starting at:  2025-07-27 23:38:36.344803   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.68
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.41
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202563 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.71  dist = 4500
#      Starting at:  2025-07-27 23:38:38.873086   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.70
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.42
#       Time taken: 1.30 seconds
# Isochrone generation took 1.205421 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.72  dist = 4500
#      Starting at:  2025-07-27 23:38:41.399749   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.72
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.44
#       Time taken: 1.30 seconds
# Isochrone generation took 1.204613 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.73  dist = 4500
#      Starting at:  2025-07-27 23:38:43.926093   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.74
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.46
#       Time taken: 1.31 seconds
# Isochrone generation took 1.210789 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.74  dist = 4500
#      Starting at:  2025-07-27 23:38:46.469217   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.75
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.47
#       Time taken: 1.31 seconds
# Isochrone generation took 1.200711 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.75  dist = 4500
#      Starting at:  2025-07-27 23:38:49.000448   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.77
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.49
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202583 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.77  dist = 4500
#      Starting at:  2025-07-27 23:38:51.527515   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.79
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.50
#       Time taken: 1.30 seconds
# Isochrone generation took 1.199755 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.78  dist = 4500
#      Starting at:  2025-07-27 23:38:54.045176   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.81
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.52
#       Time taken: 1.31 seconds
# Isochrone generation took 1.196928 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.79  dist = 4500
#      Starting at:  2025-07-27 23:38:56.573093   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.83
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.53
#       Time taken: 1.30 seconds
# Isochrone generation took 1.200516 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.80  dist = 4500
#      Starting at:  2025-07-27 23:38:59.094648   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.85
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.55
#       Time taken: 1.31 seconds
# Isochrone generation took 1.281764 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.81  dist = 4500
#      Starting at:  2025-07-27 23:39:01.707371   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.87
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.56
#       Time taken: 1.31 seconds
# Isochrone generation took 1.206252 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.82  dist = 4500
#      Starting at:  2025-07-27 23:39:04.240738   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.88
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.58
#       Time taken: 1.31 seconds
# Isochrone generation took 1.207936 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.84  dist = 4500
#      Starting at:  2025-07-27 23:39:06.774460   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.90
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.59
#       Time taken: 1.31 seconds
# Isochrone generation took 1.204832 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.85  dist = 4500
#      Starting at:  2025-07-27 23:39:09.310866   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.92
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.61
#       Time taken: 1.33 seconds
# Isochrone generation took 1.207036 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.86  dist = 4500
#      Starting at:  2025-07-27 23:39:11.866860   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.94
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.63
#       Time taken: 1.31 seconds
# Isochrone generation took 1.202420 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.87  dist = 4500
#      Starting at:  2025-07-27 23:39:14.398255   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.96
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.64
#       Time taken: 1.30 seconds
# Isochrone generation took 1.206256 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.88  dist = 4500
#      Starting at:  2025-07-27 23:39:16.926658   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.98
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.66
#       Time taken: 1.31 seconds
# Isochrone generation took 1.203365 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.90  dist = 4500
#      Starting at:  2025-07-27 23:39:19.462328   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.67
#       Time taken: 1.30 seconds
# Isochrone generation took 1.201564 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.91  dist = 4500
#      Starting at:  2025-07-27 23:39:21.983665   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.01
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.69
#       Time taken: 1.31 seconds
# Isochrone generation took 1.197757 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.92  dist = 4500
#      Starting at:  2025-07-27 23:39:24.509111   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.03
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.70
#       Time taken: 1.30 seconds
# Isochrone generation took 1.196609 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.93  dist = 4500
#      Starting at:  2025-07-27 23:39:27.024975   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.05
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.72
#       Time taken: 1.30 seconds
# Isochrone generation took 1.195867 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.94  dist = 4500
#      Starting at:  2025-07-27 23:39:29.542719   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.07
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.73
#       Time taken: 1.29 seconds
# Isochrone generation took 1.251149 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.95  dist = 4500
#      Starting at:  2025-07-27 23:39:32.105925   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.09
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.75
#       Time taken: 1.31 seconds
# Isochrone generation took 1.205028 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.97  dist = 4500
#      Starting at:  2025-07-27 23:39:34.636169   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.11
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.76
#       Time taken: 1.30 seconds
# Isochrone generation took 1.203042 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.98  dist = 4500
#      Starting at:  2025-07-27 23:39:37.156795   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.13
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.78
#       Time taken: 1.30 seconds
# Isochrone generation took 1.201335 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.99  dist = 4500
#      Starting at:  2025-07-27 23:39:39.675854   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.14
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.80
#       Time taken: 1.30 seconds
# Isochrone generation took 1.205350 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.00  dist = 4500
#      Starting at:  2025-07-27 23:39:42.205148   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.16
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.81
#       Time taken: 1.31 seconds
#
# === Best Fit from Grid Search ===
# AV: 12.073
# AKs: 1.423
# Mass: 0.0728 M☉
# Reduced χ²: 0.0032
#
# Top 5 Fits:
# AV=12.073, Mass=0.0728, χ²=0.0032
# AV=12.273, Mass=0.0742, χ²=0.0056
# AV=12.173, Mass=0.0736, χ²=0.0087
# AV=11.973, Mass=0.0723, χ²=0.0088
# AV=11.873, Mass=0.0716, χ²=0.0154

# %%
print(f"Estimated AV:    {best_fit['AV']:.3f}, Estimated Mass:  {best_fit['mass']:.4f} M☉")
print(f"Ground-truth AV: {av_true:.3f}, Ground-truth Mass: {mass_true:.4f} M☉")
# Out:
# Estimated AV:    12.073, Estimated Mass:  0.0728 M☉
# Ground-truth AV: 10.538, Ground-truth Mass: 0.0562 M☉

# %%
top = grid_results_sorted[:100]
avs = [r['AV'] for r in top]
masses = [r['mass'] for r in top]
chis = [r['chi2'] for r in top]

plt.figure(figsize=(8,6))
sc = plt.scatter(avs, masses, c=chis, cmap='viridis', norm=LogNorm())
plt.colorbar(sc, label="Reduced χ²")
plt.xlabel("AV")
plt.ylabel("Mass (M☉)")
plt.title("Top 100 Fits: AV vs Mass")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# --- Plot A_V ---
plt.figure(figsize=(4, 4))
labels = ['Ground Truth', 'Estimated']
av_values = [av_true, best_fit['AV']]
x = range(len(labels))

plt.bar(x, av_values, color=['gray', 'skyblue'])
plt.xticks(x, labels)
plt.ylabel('A_V')
plt.title('Estimated vs Ground Truth A_V')

# Annotate bars
for i, val in enumerate(av_values):
    plt.text(i, val + 0.05, f'{val:.3f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# --- Plot Mass ---
plt.figure(figsize=(4, 4))
mass_values = [mass_true, best_fit['mass']]

plt.bar(x, mass_values, color=['gray', 'skyblue'])
plt.xticks(x, labels)
plt.ylabel('Mass (M☉)')
plt.title('Estimated vs Ground Truth Mass')

# Annotate bars
for i, val in enumerate(mass_values):
    plt.text(i, val + 0.01, f'{val:.4f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()
