# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening
from matplotlib.colors import LogNorm
import csv
from scipy.stats import chi2
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
# === Setup ===
iso_dir = 'isochrones/'
# output_dir = 'output_diagrams/'
# os.makedirs(output_dir, exist_ok=True)

# --- Static Parameters ---
star_index = 2
dist = 4500
metallicity = 0
log_age_arr = np.log10([1e6])  # 1 Myr

# Models
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)

# Filters
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W']
filters = ['m_jwst_F162M', 'm_jwst_F182M', 'm_jwst_F200W']

filter_wavelengths = {
    "m_jwst_F162M": 1.62,
    "m_jwst_F182M": 1.82,
    "m_jwst_F200W": 2.00,
    "m_jwst_F356M": 3.56,
    "m_jwst_F405N": 4.05
}

# Conversion constant from SPISEA/Cardelli (1989) with Rv = 3.1
AV_to_AKs = 1.0 / 0.1179  # ≈ 8.479

# %%
# --- Load star data ---
def load_star_data(csv_path, index=0):
    sample_mags, sample_errs = [], []
    with open(csv_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)
        for line in reader:
            mags = [float(line[i]) for i in range(1, len(line), 2)]
            errs = [float(line[i]) for i in range(2, len(line), 2)]
            sample_mags.append(mags)
            sample_errs.append(errs)
    return sample_mags[index][:2], sample_errs[index][:2]

# --- Interpolate Isochrone Points ---
# --- Interpolate Isochrone Points ---
def interpolate_isochrone(isochrone, num_interp=10):
    masses = isochrone.points['mass']
    m1 = isochrone.points['m_jwst_F162M']
    m2 = isochrone.points['m_jwst_F182M']
    m3 = isochrone.points['m_jwst_F200W']  # New filter

    # Collect original + interpolated points
    interp_data = []

    for i in range(len(masses) - 1):
        mass1, mass2 = masses[i], masses[i+1]
        m1_1, m1_2 = m1[i], m1[i+1]
        m2_1, m2_2 = m2[i], m2[i+1]
        m3_1, m3_2 = m3[i], m3[i+1]

        # Interpolate values
        interp_masses = np.linspace(mass1, mass2, num=num_interp+2)[1:-1]
        interp_m1 = np.linspace(m1_1, m1_2, num=num_interp+2)[1:-1]
        interp_m2 = np.linspace(m2_1, m2_2, num=num_interp+2)[1:-1]
        interp_m3 = np.linspace(m3_1, m3_2, num=num_interp+2)[1:-1]

        for m, im1, im2, im3 in zip(interp_masses, interp_m1, interp_m2, interp_m3):
            interp_data.append((m, im1, im2, im3, False))  # False = interpolated

    # Add original points
    for i in range(len(masses)):
        interp_data.append((masses[i], m1[i], m2[i], m3[i], True))  # True = original

    # Convert to structured array
    interp_data = sorted(interp_data, key=lambda x: x[0])
    dtype = [
        ('mass', float),
        ('m_jwst_F162M', float),
        ('m_jwst_F182M', float),
        ('m_jwst_F200W', float),
        ('is_original', bool)
    ]
    interp_array = np.array(interp_data, dtype=dtype)
    return interp_array

# --- Apply Dereddening ---
def apply_dereddening(mags, AKs, wavelengths):
    return [
        m - red_law.Cardelli89(wavelengths[filters[i]], AKs)
        for i, m in enumerate(mags)
    ]

# --- Compute Errors ---
def calculate_errors(errs):
    color_err = np.sqrt(errs[0]**2 + errs[1]**2)
    mag_err = errs[1]
    return color_err, mag_err

# --- Plotting Function ---
def plot_cmd_and_mmd(interp_table, dered_mags, errors, title):
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    ax_cmd, ax_magmag = axes
    m162_d, m182_d, *_ = dered_mags
    err162, err182, *_ = errors
    color_err = np.sqrt(err162**2 + err182**2)
    mag_err = err182

    # Split by origin
    original = interp_table[interp_table['is_original']]
    interp = interp_table[~interp_table['is_original']]

    # === Color-Magnitude Diagram (CMD) ===
    colors_orig = original['m_jwst_F162M'] - original['m_jwst_F182M']
    mags_orig = original['m_jwst_F182M']
    colors_interp = interp['m_jwst_F162M'] - interp['m_jwst_F182M']
    mags_interp = interp['m_jwst_F182M']

    ax_cmd.plot(colors_orig, mags_orig, 'ro', markersize=3, label='Original')
    ax_cmd.plot(colors_interp, mags_interp, 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_cmd.errorbar(m162_d - m182_d, m182_d, xerr=color_err, yerr=mag_err,
                    fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_cmd.set_xlabel("F162M - F182M")
    ax_cmd.set_ylabel("F182M")
    ax_cmd.invert_yaxis()
    ax_cmd.set_title("Color-Magnitude Diagram")
    ax_cmd.grid(True)
    ax_cmd.legend()

    # === Magnitude-Magnitude Diagram ===
    ax_magmag.plot(original['m_jwst_F162M'], original['m_jwst_F182M'], 'ro', markersize=3, label='Original')
    ax_magmag.plot(interp['m_jwst_F162M'], interp['m_jwst_F182M'], 'k.', markersize=2, alpha=0.5, label='Interpolated')
    ax_magmag.errorbar(m162_d, m182_d, xerr=err162, yerr=err182,
                       fmt='o', color='gold', alpha=0.9, label='Observed')

    ax_magmag.set_xlabel("F162M")
    ax_magmag.set_ylabel("F182M")
    ax_magmag.invert_yaxis()
    ax_magmag.invert_xaxis()
    ax_magmag.set_title("Magnitude–Magnitude Diagram")
    ax_magmag.grid(True)
    ax_magmag.legend()

    fig.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()
    
    # --- Load star data from .dat file ---
def load_dat_star_data(dat_path, index=0):
    """
    Load photometry, errors, AV, and mass from a space-delimited .dat file.
    Skips the first two columns (assumed to be positional data).
    Returns:
        mags: list of observed magnitudes [F162M, F182M]
        errs: list of associated uncertainties
        av: extinction A(V)
        mass: estimated stellar mass
    """
    with open(dat_path, 'r') as f:
        lines = f.readlines()

    line = lines[index].strip().split()
    line = [float(x) for x in line]

    # Extract photometry and errors
    f162m, err_f162m = line[2], line[3]
    f182m, err_f182m = line[4], line[5]
    f200w, err_f200w = line[6], line[7]

    av = line[8]
    mass = line[9]

    mags = [f162m, f182m, f200w]
    errs = [err_f162m, err_f182m, err_f200w]
    return mags, errs, av, mass

# %%
# === Read data ===
dat_path = '/scratch/wyz5rge/synthetic-hr/notebooks/2025/01-28_chi-square-reverse-modeling/winstonlist.dat'
mags, errs, av_true, mass_true = load_dat_star_data(dat_path, star_index)

# === Automate AKs selection ===
import scipy.optimize

# --- Compute sum of squared differences between dereddened point and isochrone ---
def compute_total_squared_distance(dered_mags, interp_table):
    # Color-magnitude of observed star
    color_obs = dered_mags[0] - dered_mags[1]  # F162M - F182M
    mag_obs = dered_mags[1]                   # F182M

    # Isochrone in CMD space using correct column names
    color_iso = interp_table['m_jwst_F162M'] - interp_table['m_jwst_F182M']
    mag_iso = interp_table['m_jwst_F182M']

    d_color = color_iso - color_obs
    d_mag = mag_iso - mag_obs
    distances_squared = d_color**2 + d_mag**2

    return np.min(distances_squared)

# --- Objective function to minimize ---
def objective(aks_trial, mags):
    aks_trial = float(np.squeeze(aks_trial))  # ensures scalar
    dered = apply_dereddening(mags, aks_trial, filter_wavelengths)
    # Return squared distance in color–magnitude space
    return compute_total_squared_distance(dered, interp_table)

# === Main execution (automated AKs) ===
from scipy.optimize import minimize_scalar

# Step 1: Generate unreddened isochrone and interpolate
iso_unredd = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                                     metallicity=metallicity,
                                     evo_model=evo_model, atm_func=atm_func,
                                     red_law=red_law, filters=filt_list,
                                     iso_dir=iso_dir)
interp_table = interpolate_isochrone(iso_unredd, num_interp=10)

# Step 2: Minimize AKs
aks_result = minimize_scalar(objective, bounds=(0.0, 3.0), args=(mags,), method='bounded')
print("aks_result.x type:", type(aks_result.x), "value:", aks_result.x)
AKs_val = float(np.squeeze(aks_result.x))
AV_val = AKs_val * AV_to_AKs
print(f"Best-fit AKs: {AKs_val:.3f}, AV: {AV_val:.3f}")

# Step 3: Plot sum of squares vs AKs (for visualization)
ak_grid = np.linspace(0.0, 3.0, 100)
sq_vals = [objective(ak, mags) for ak in ak_grid]
plt.figure(figsize=(8,5))
plt.plot(ak_grid, sq_vals, label='Sum of Squared Distances')
plt.axvline(AKs_val, color='r', linestyle='--', label=f'Best AKs = {AKs_val:.3f}')
plt.xlabel("AKs")
plt.ylabel("Min Squared Distance to Isochrone")
plt.title("AKs Optimization")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Step 4: Deredden mags and replot CMD/MMD with optimal AKs
dered_mags = apply_dereddening(mags, AKs_val, filter_wavelengths)
errors = calculate_errors(errs)
plot_cmd_and_mmd(interp_table, dered_mags, errors,
                 f"Automated AV Fit: AV={AV_val:.2f}")

# Generate isochrone and interpolate
iso = synthetic.IsochronePhot(log_age_arr[0], AKs=0.0, distance=dist,
                               metallicity=metallicity,
                               evo_model=evo_model, atm_func=atm_func,
                               red_law=red_law, filters=filt_list,
                               iso_dir=iso_dir)

interp_table = interpolate_isochrone(iso, num_interp=10)
# Out:
# aks_result.x type: <class 'numpy.float64'> value: 1.688917189123073
# Best-fit AKs: 1.689, AV: 14.325

# %%
delta_AV = 5.0
AV_low = max(0.0, AKs_val * AV_to_AKs - delta_AV)
AV_high = AKs_val * AV_to_AKs + delta_AV
AV_grid = np.arange(AV_low, AV_high + 0.001, 0.1)  # 0.1 mag steps in AV
AKs_per_AV = 0.118

print(f"A_V grid: from {AV_low:.2f} to {AV_high:.2f} with {len(AV_grid)} steps")

def chi_squared_grid_av(AV_grid, mags, errs):
    results = []

    for av in AV_grid:
        aks = av * AKs_per_AV  # Convert to AKs

        iso = synthetic.IsochronePhot(log_age_arr[0], AKs=aks, distance=dist,
                                      metallicity=metallicity,
                                      evo_model=evo_model, atm_func=atm_func,
                                      red_law=red_law, filters=filt_list,
                                      iso_dir=iso_dir)
        interp = interpolate_isochrone(iso, num_interp=10)
        for entry in interp:
            model_mags = [entry[f] for f in filters]
            chi_sq = sum(
                ((mags[i] - model_mags[i]) ** 2) / max(errs[i] ** 2, 1e-3)
                for i in range(len(mags))
            ) / (len(mags) - 1)
            results.append({
                "AV": av,
                "AKs": aks,
                "mass": entry['mass'],
                "chi2": chi_sq
            })
    return results

# Run updated grid search
grid_results = chi_squared_grid_av(AV_grid, mags, errs)
grid_results_sorted = sorted(grid_results, key=lambda x: x["chi2"])

# Output
best_fit = grid_results_sorted[0]
print("\n=== Best Fit from Grid Search ===")
print(f"AV: {best_fit['AV']:.3f}")
print(f"AKs: {best_fit['AKs']:.3f}")
print(f"Mass: {best_fit['mass']:.4f} M☉")
print(f"Reduced χ²: {best_fit['chi2']:.4f}")

print("\nTop 5 Fits:")
for r in grid_results_sorted[:5]:
    print(f"AV={r['AV']:.3f}, Mass={r['mass']:.4f}, χ²={r['chi2']:.4f}")
# Out:
# A_V grid: from 9.32 to 19.32 with 101 steps
# Isochrone generation took 1.876155 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.49  dist = 4500
#      Starting at:  2025-08-04 22:52:38.023725   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.36
# Starting filter: jwst,F182M   Elapsed time: 1.51 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.14
# Starting filter: jwst,F200W   Elapsed time: 2.49 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 23.76
#       Time taken: 3.25 seconds
# Isochrone generation took 1.497397 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.56  dist = 4500
#      Starting at:  2025-08-04 22:52:42.922710   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.47
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.23
# Starting filter: jwst,F200W   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 23.84
#       Time taken: 3.22 seconds
# Isochrone generation took 2.479806 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.62  dist = 4500
#      Starting at:  2025-08-04 22:52:48.909995   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.56
# Starting filter: jwst,F182M   Elapsed time: 1.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.31
# Starting filter: jwst,F200W   Elapsed time: 3.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 23.91
#       Time taken: 5.20 seconds
# Isochrone generation took 2.499867 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.69  dist = 4500
#      Starting at:  2025-08-04 22:52:56.941507   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.67
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.40
# Starting filter: jwst,F200W   Elapsed time: 3.48 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 23.99
#       Time taken: 5.22 seconds
# Isochrone generation took 2.518385 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.75  dist = 4500
#      Starting at:  2025-08-04 22:53:04.956831   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.77
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.48
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.05
#       Time taken: 5.18 seconds
# Isochrone generation took 2.632512 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.82  dist = 4500
#      Starting at:  2025-08-04 22:53:13.107064   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.88
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.57
# Starting filter: jwst,F200W   Elapsed time: 3.48 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.14
#       Time taken: 5.21 seconds
# Isochrone generation took 2.466752 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.89  dist = 4500
#      Starting at:  2025-08-04 22:53:21.122532   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 24.99
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.22
#       Time taken: 5.20 seconds
# Isochrone generation took 2.495001 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 1.95  dist = 4500
#      Starting at:  2025-08-04 22:53:29.091964   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.08
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.74
# Starting filter: jwst,F200W   Elapsed time: 3.48 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.28
#       Time taken: 5.22 seconds
# Isochrone generation took 2.470488 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.01  dist = 4500
#      Starting at:  2025-08-04 22:53:37.057875   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.18
# Starting filter: jwst,F182M   Elapsed time: 1.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.82
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.35
#       Time taken: 5.18 seconds
# Isochrone generation took 2.485502 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.02  dist = 4500
#      Starting at:  2025-08-04 22:53:44.773198   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.84
# Starting filter: jwst,F200W   Elapsed time: 3.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.36
#       Time taken: 5.21 seconds
# Isochrone generation took 2.516207 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.03  dist = 4500
#      Starting at:  2025-08-04 22:53:52.549169   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.21
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.85
# Starting filter: jwst,F200W   Elapsed time: 3.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.38
#       Time taken: 4.40 seconds
# Isochrone generation took 1.265203 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.04  dist = 4500
#      Starting at:  2025-08-04 22:53:58.240866   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.23
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.87
# Starting filter: jwst,F200W   Elapsed time: 1.49 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.39
#       Time taken: 2.22 seconds
# Isochrone generation took 1.309425 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.06  dist = 4500
#      Starting at:  2025-08-04 22:54:01.789628   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.25
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.88
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.40
#       Time taken: 2.16 seconds
# Isochrone generation took 1.306095 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.07  dist = 4500
#      Starting at:  2025-08-04 22:54:05.275929   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.27
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.90
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.42
#       Time taken: 2.16 seconds
# Isochrone generation took 1.311506 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.08  dist = 4500
#      Starting at:  2025-08-04 22:54:08.769940   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.29
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.91
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.43
#       Time taken: 2.17 seconds
# Isochrone generation took 1.309983 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.09  dist = 4500
#      Starting at:  2025-08-04 22:54:12.272191   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.31
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.93
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.44
#       Time taken: 2.17 seconds
# Isochrone generation took 1.349753 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.10  dist = 4500
#      Starting at:  2025-08-04 22:54:15.818114   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.32
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.94
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.46
#       Time taken: 2.18 seconds
# Isochrone generation took 1.309263 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.12  dist = 4500
#      Starting at:  2025-08-04 22:54:19.330051   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.34
# Starting filter: jwst,F182M   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.96
# Starting filter: jwst,F200W   Elapsed time: 3.16 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.47
#       Time taken: 4.89 seconds
# Isochrone generation took 2.505558 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.13  dist = 4500
#      Starting at:  2025-08-04 22:54:26.777864   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.36
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.98
# Starting filter: jwst,F200W   Elapsed time: 3.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.48
#       Time taken: 5.20 seconds
# Isochrone generation took 2.482449 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.14  dist = 4500
#      Starting at:  2025-08-04 22:54:34.506333   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.38
# Starting filter: jwst,F182M   Elapsed time: 1.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.99
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.50
#       Time taken: 5.20 seconds
# Isochrone generation took 2.467035 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.15  dist = 4500
#      Starting at:  2025-08-04 22:54:42.226319   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.40
# Starting filter: jwst,F182M   Elapsed time: 1.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.01
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.51
#       Time taken: 5.19 seconds
# Isochrone generation took 2.478963 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.16  dist = 4500
#      Starting at:  2025-08-04 22:54:49.943747   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.42
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.02
# Starting filter: jwst,F200W   Elapsed time: 3.51 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.52
#       Time taken: 5.25 seconds
# Isochrone generation took 2.497095 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.17  dist = 4500
#      Starting at:  2025-08-04 22:54:57.738807   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.44
# Starting filter: jwst,F182M   Elapsed time: 1.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.04
# Starting filter: jwst,F200W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.54
#       Time taken: 5.18 seconds
# Isochrone generation took 2.488316 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.19  dist = 4500
#      Starting at:  2025-08-04 22:55:05.461727   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.45
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.05
# Starting filter: jwst,F200W   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.55
#       Time taken: 2.18 seconds
# Isochrone generation took 1.309634 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.20  dist = 4500
#      Starting at:  2025-08-04 22:55:08.976554   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.47
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.07
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.56
#       Time taken: 2.17 seconds
# Isochrone generation took 1.306577 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.21  dist = 4500
#      Starting at:  2025-08-04 22:55:12.474212   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.49
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.08
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.58
#       Time taken: 2.17 seconds
# Isochrone generation took 1.392865 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.22  dist = 4500
#      Starting at:  2025-08-04 22:55:16.064517   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.51
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.10
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.59
#       Time taken: 2.15 seconds
# Isochrone generation took 1.310320 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.23  dist = 4500
#      Starting at:  2025-08-04 22:55:19.548937   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.53
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.11
# Starting filter: jwst,F200W   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.60
#       Time taken: 2.20 seconds
# Isochrone generation took 1.306234 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.24  dist = 4500
#      Starting at:  2025-08-04 22:55:23.077623   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.55
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.13
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.62
#       Time taken: 2.15 seconds
# Isochrone generation took 1.313680 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.26  dist = 4500
#      Starting at:  2025-08-04 22:55:26.566634   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.57
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.15
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.63
#       Time taken: 2.17 seconds
# Isochrone generation took 1.308275 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.27  dist = 4500
#      Starting at:  2025-08-04 22:55:30.062732   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.59
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.16
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.64
#       Time taken: 2.18 seconds
# Isochrone generation took 1.311139 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.28  dist = 4500
#      Starting at:  2025-08-04 22:55:33.581111   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.60
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 25.18
# Starting filter: jwst,F200W   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.66
#       Time taken: 2.19 seconds
#
# === Best Fit from Grid Search ===
# AV: 11.025
# AKs: 1.301
# Mass: 0.0273 M☉
# Reduced χ²: 5.9860
#
# Top 5 Fits:
# AV=11.025, Mass=0.0273, χ²=5.9860
# AV=10.925, Mass=0.0273, χ²=6.0180
# AV=10.625, Mass=0.0264, χ²=6.1001
# AV=11.125, Mass=0.0273, χ²=6.1190
# AV=11.325, Mass=0.0282, χ²=6.1368

# %%
print(f"Estimated AV:    {best_fit['AV']:.3f}, Estimated Mass:  {best_fit['mass']:.4f} M☉")
print(f"Ground-truth AV: {av_true:.3f}, Ground-truth Mass: {mass_true:.4f} M☉")
# Out:
# Estimated AV:    11.025, Estimated Mass:  0.0273 M☉
# Ground-truth AV: 14.110, Ground-truth Mass: 0.0322 M☉

# %%
import matplotlib.lines as mlines

# Extract unique AV and mass values
AV_vals = sorted(set(r['AV'] for r in grid_results))
mass_vals = sorted(set(r['mass'] for r in grid_results))

# Initialize chi2 grid
chi2_grid = np.full((len(mass_vals), len(AV_vals)), np.nan)

# Fill chi2 grid
AV_index = {av: i for i, av in enumerate(AV_vals)}
mass_index = {mass: i for i, mass in enumerate(mass_vals)}

for r in grid_results:
    i = mass_index[r['mass']]
    j = AV_index[r['AV']]
    chi2_grid[i, j] = r['chi2']

# Create meshgrid for plotting
AVs_grid_2d, mass_grid_2d = np.meshgrid(AV_vals, mass_vals)

# Degrees of freedom = number of filters - 1
dof = len(mags) - 1
confidence = 0.997  # 3σ rejection level
crit_val = chi2.ppf(confidence, df=dof)
print(f"Chi² rejection threshold (3σ, dof={dof}): {crit_val:.2f}")

# Mask for acceptable points (χ² < crit) — your "rejectable" region
rejected_mask = chi2_grid < crit_val
rejected_AVs = AVs_grid_2d[rejected_mask]
rejected_masses = mass_grid_2d[rejected_mask]
rejected_chi2 = chi2_grid[rejected_mask]

# Plot rejected points colored by χ²
plt.figure(figsize=(10, 7))
sc = plt.scatter(rejected_AVs, rejected_masses, c=rejected_chi2, cmap='seismic', s=10)
cbar = plt.colorbar(sc)
cbar.set_label('Reduced χ²')

# Overlay best-fit and ground truth
best_result = grid_results_sorted[0]
best_AV = best_result["AV"]
best_mass = best_result["mass"]
true_AV = av_true
true_mass = mass_true

plt.scatter([best_AV], [best_mass], color='lime', marker='x', s=100, label='Best fit')
plt.scatter([true_AV], [true_mass], color='gold', marker='*', s=150, label='Ground truth')

# Create dummy handle for critical value
crit_label = f'χ² < {crit_val:.2f}'
crit_handle = mlines.Line2D([], [], color='none', label=crit_label)

plt.xlabel('AV (Visual Extinction)')
plt.ylabel('Mass (M☉)')
plt.title('Acceptable Region (χ² < Critical Value)')

# Add handles to legend
plt.legend(handles=[crit_handle,
                    plt.Line2D([], [], color='lime', marker='x', linestyle='None', markersize=10, label='Best fit'),
                    plt.Line2D([], [], color='gold', marker='*', linestyle='None', markersize=12, label='Ground truth')])

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Chi² rejection threshold (3σ, dof=2): 11.62

# %%
# Sort results by chi-squared (key name is 'chi2' in your data)
grid_results_sorted = sorted(grid_results, key=lambda x: x["chi2"])

# Best fit
best_result = grid_results_sorted[0]
best_mass = best_result["mass"]
best_AV = best_result["AV"]
min_chi2 = best_result["chi2"]

# Acceptable threshold (e.g., 68% confidence region for 2 params: Δχ² ≈ 2.3)
chi2_threshold = min_chi2 + 2.3

# Find all (mass, AV) combinations within acceptable chi-squared
acceptable_results = [r for r in grid_results_sorted if r["chi2"] <= chi2_threshold]

acceptable_masses = [r["mass"] for r in acceptable_results]
acceptable_AVs = [r["AV"] for r in acceptable_results]

# Compute min/max bounds for error bars
mass_min, mass_max = min(acceptable_masses), max(acceptable_masses)
AV_min, AV_max = min(acceptable_AVs), max(acceptable_AVs)

# Print summary
print(f"Best-fit Mass: {best_mass:.4f} M☉")
print(f"Best-fit AV: {best_AV:.3f}")
print(f"Acceptable Mass Range: [{mass_min:.4f}, {mass_max:.4f}] M☉")
print(f"Acceptable AV Range: [{AV_min:.3f}, {AV_max:.3f}]")
# Out:
# Best-fit Mass: 0.0273 M☉
# Best-fit AV: 11.025
# Acceptable Mass Range: [0.0236, 0.0318] M☉
# Acceptable AV Range: [9.425, 12.725]
