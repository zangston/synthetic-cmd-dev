# %%
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 0  # Set which star in the CSV to analyze

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes and errors, skipping the header row
sample_mags = []
sample_errs = []
with open('./s284.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(lines[i]) for i in range(1, 10, 2)])
        sample_errs.append([float(lines[i]) for i in range(2, 11, 2)])

# Function to generate isochrone grid
def generate_isochrones(AKs):
    return np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

# Generate isochrone grids
isochrone_AKs_07 = generate_isochrones(0.7)
isochrone_AKs_00 = generate_isochrones(0.0)

# Deredden the observed flux
filter_wavelengths = {
    "m_jwst_F162M": 1.62,
    "m_jwst_F182M": 1.82,
}

# Convert filter names to wavelengths
wavelengths = [filter_wavelengths[f] for f in filters]
AKs_ref = 0.7

def propagate_errors(mags, errs, wavelengths, AKs):
    dereddened_mags = []
    dereddened_errs = []
    for m, err, wavelength in zip(mags, errs, wavelengths):
        A_lambda = red_law.Cardelli89(wavelength, AKs)
        sigma_A_lambda = 0.1 * A_lambda  # Approximate 10% uncertainty in extinction
        total_err = np.sqrt(err**2 + sigma_A_lambda**2)
        dereddened_mags.append(m - A_lambda)
        dereddened_errs.append(total_err)
    return dereddened_mags, dereddened_errs

sample_mags_dereddened, sample_errs_dereddened = propagate_errors(sample_mags[star_index], sample_errs[star_index], wavelengths, AKs_ref)

# Plot function
def plot_diagram(isochrone_grid, ref_mags, ref_errs, title, filename):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    cmap = plt.get_cmap('coolwarm')
    
    # CMD
    for i, instance in enumerate(isochrone_grid):
        color = cmap(i / (len(isochrone_grid) - 1))
        ax1.plot(instance.points[filters[0]] - instance.points[filters[1]],
                 instance.points[filters[1]], color=color)
    ax1.set_xlabel('F162M - F182M')
    ax1.set_ylabel('F182M')
    ax1.invert_yaxis()
    ax1.grid(True)
    
    # MMD
    for i, instance in enumerate(isochrone_grid):
        color = cmap(i / (len(isochrone_grid) - 1))
        ax2.plot(instance.points[filters[0]], instance.points[filters[1]], color=color)
    ax2.set_xlabel('F162M')
    ax2.set_ylabel('F182M')
    ax2.invert_xaxis()
    ax2.invert_yaxis()
    ax2.grid(True)
    
    # Reference star with error bars
    color = 'gold'
    ax1.errorbar(ref_mags[0] - ref_mags[1], ref_mags[1], xerr=np.sqrt(ref_errs[0]**2 + ref_errs[1]**2), yerr=ref_errs[1], fmt='*', markersize=10, color=color, label="Reference Star")
    ax2.errorbar(ref_mags[0], ref_mags[1], xerr=ref_errs[0], yerr=ref_errs[1], fmt='*', markersize=10, color=color, label="Reference Star")
    
    ax1.legend()
    ax2.legend()
    fig.suptitle(title)
    plt.savefig(os.path.join(output_dir, filename))
    plt.close()

# Plot both cases
plot_diagram(isochrone_AKs_07, sample_mags[star_index], sample_errs[star_index], "Isochrone Grid with AKs = 0.7", "CMD_MMD_AKs_07.png")
plot_diagram(isochrone_AKs_00, sample_mags_dereddened, sample_errs_dereddened, "Isochrone Grid with AKs = 0 and Dereddened Flux", "CMD_MMD_AKs_00_Dereddened.png")
