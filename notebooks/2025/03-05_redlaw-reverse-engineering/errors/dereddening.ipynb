# %%
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 0  # Set which star in the CSV to analyze

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes and errors, skipping the header row
sample_mags = []
sample_errors = []
with open('./s284.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(lines[1]), float(lines[3])])  # F162M, F182M
        sample_errors.append([float(lines[2]), float(lines[4])])  # ERR162M, ERR182M

# Function to generate isochrone grid
def generate_isochrones(AKs):
    return np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

# Generate isochrone grids
isochrone_AKs_07 = generate_isochrones(0.7)
isochrone_AKs_00 = generate_isochrones(0.0)

# Deredden the observed flux
filter_wavelengths = {
    "m_jwst_F162M": 1.62,
    "m_jwst_F182M": 1.82
}

# Convert filter names to wavelengths
wavelengths = [filter_wavelengths[f] for f in filters]
AKs_ref = 0.7

# Compute dereddened magnitudes and their uncertainties
sample_mags_dereddened = []
sample_errors_dereddened = []

for (m, sigma_m, wavelength) in zip(sample_mags[star_index], sample_errors[star_index], wavelengths):
    A_lambda = red_law.Cardelli89(wavelength, AKs_ref)
    sigma_A = 0.05 * A_lambda / AKs_ref  # Example uncertainty in AKs
    sigma_dereddened = np.sqrt(sigma_m**2 + sigma_A**2)
    
    sample_mags_dereddened.append(m - A_lambda)
    sample_errors_dereddened.append(sigma_dereddened)

# Plot function
def plot_diagram(isochrone_grid, ref_mags, ref_errors, title, filename):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    cmap = plt.get_cmap('coolwarm')
    
    # CMD
    for i, instance in enumerate(isochrone_grid):
        color = cmap(i / (len(isochrone_grid) - 1))
        ax1.plot(instance.points[filters[0]] - instance.points[filters[1]],
                 instance.points[filters[1]], color=color)
    ax1.set_xlabel('F162M - F182M')
    ax1.set_ylabel('F182M')
    ax1.invert_yaxis()
    ax1.grid(True)
    
    # MMD
    for i, instance in enumerate(isochrone_grid):
        color = cmap(i / (len(isochrone_grid) - 1))
        ax2.plot(instance.points[filters[0]], instance.points[filters[1]], color=color)
    ax2.set_xlabel('F162M')
    ax2.set_ylabel('F182M')
    ax2.invert_xaxis()
    ax2.invert_yaxis()
    ax2.grid(True)
    
    # Reference star with error bars
    ax1.errorbar(ref_mags[0] - ref_mags[1], ref_mags[1],
                 xerr=np.sqrt(ref_errors[0]**2 + ref_errors[1]**2),
                 yerr=ref_errors[1], fmt='*', markersize=10, color='gold', label="Reference Star")
    ax2.errorbar(ref_mags[0], ref_mags[1], xerr=ref_errors[0],
                 yerr=ref_errors[1], fmt='*', markersize=10, color='gold', label="Reference Star")
    
    ax1.legend()
    ax2.legend()
    fig.suptitle(title)
    plt.savefig(os.path.join(output_dir, filename))
    plt.close()

# Plot both cases
plot_diagram(isochrone_AKs_07, sample_mags[star_index], sample_errors[star_index],
             "Isochrone Grid with AKs = 0.7", "CMD_MMD_AKs_07.png")
plot_diagram(isochrone_AKs_00, sample_mags_dereddened, sample_errors_dereddened,
             "Isochrone Grid with AKs = 0 and Dereddened Flux", "CMD_MMD_AKs_00_Dereddened.png")
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# Isochrone generation took 1.343040 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:17.701777   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.11
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.10
#       Time taken: 1.46 seconds
# Isochrone generation took 1.205161 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:20.383540   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.47
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.49
#       Time taken: 1.44 seconds
# Isochrone generation took 1.269456 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:23.108859   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.72
# Starting filter: jwst,F182M   Elapsed time: 0.97 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.77
#       Time taken: 1.77 seconds
# Isochrone generation took 1.170071 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:26.068741   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.01
#       Time taken: 1.42 seconds
# Isochrone generation took 1.189753 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:28.696643   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.18
#       Time taken: 1.40 seconds
# Isochrone generation took 1.159979 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:31.268295   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.28
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.40
#       Time taken: 1.39 seconds
# Isochrone generation took 1.166067 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:33.843188   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.43
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.54
#       Time taken: 1.38 seconds
# Isochrone generation took 1.134123 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:36.376219   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.56
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.67
#       Time taken: 1.41 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.174096 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:38.973735   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.62
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.80
#       Time taken: 1.48 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.173761 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:41.645179   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.77
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.98
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.179399 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:44.236328   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.88
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.05
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.170292 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:46.811787   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.05
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.13
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.171837 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:49.386219   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.17
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.19
#       Time taken: 1.38 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.171039 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:51.953084   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.40
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.31
#       Time taken: 1.38 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.127764 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:54.478952   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.71
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.48
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.135805 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:57.033903   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.88
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.59
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.128803 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:43:59.568532   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.11
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.75
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.126426 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:44:02.107363   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.26
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.87
#       Time taken: 1.43 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.132109 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-06 00:44:04.686303   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.30
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.95
#       Time taken: 1.40 seconds
# Isochrone generation took 1.209305 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:07.310320   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
#       Time taken: 1.40 seconds
# Isochrone generation took 1.249129 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:09.969771   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
#       Time taken: 1.40 seconds
# Isochrone generation took 1.177051 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:12.559410   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
#       Time taken: 1.40 seconds
# Isochrone generation took 1.135274 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:15.112753   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
#       Time taken: 1.39 seconds
# Isochrone generation took 1.166634 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:17.680399   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
#       Time taken: 1.40 seconds
# Isochrone generation took 1.167372 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:20.258551   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
#       Time taken: 1.38 seconds
# Isochrone generation took 1.159435 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:22.817608   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
#       Time taken: 1.38 seconds
# Isochrone generation took 1.157666 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:25.374262   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.172063 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:27.965890   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
#       Time taken: 1.38 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.192542 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:30.557508   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
#       Time taken: 1.43 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.204216 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:33.204876   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
#       Time taken: 1.43 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.207403 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:35.853832   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
#       Time taken: 1.42 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.216972 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:38.509811   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.156599 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:41.070004   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.192268 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:43.664567   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.155393 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:46.223465   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.139209 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:48.766947   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.128366 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:51.296244   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.107460 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2025-03-06 00:44:53.811262   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
#       Time taken: 1.40 seconds
