# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening
from spisea.imf import imf, multiplicity
from matplotlib.colors import LogNorm
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'

# Define isochrone parameters
dist = 4500  # Distance in parsecs
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W']
filters = ['m_jwst_F162M', 'm_jwst_F182M', 'm_jwst_F200W']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array in years
log_age_arr = np.log10(level_ages)
AKs = 0.7  # Extinction value

# Load sample magnitudes and errors
sample_mags, sample_errors = [], []

with open('../../s284.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for line in csvFile:
        sample_mags.append([float(line[1]), float(line[3]), float(line[5])])  # Extract F162M, F182M, F200W
        sample_errors.append([float(line[2]), float(line[4]), float(line[6])])  # Extract corresponding errors

sample_mags = np.array(sample_mags)
sample_errors = np.array(sample_errors)

# Chi-square function accounting for errors
def chi_square_with_errors(iso_grid, obs_mags, obs_errors):
    DOF = len(obs_mags) - 1  # Degrees of freedom: num filters - 1
    chi_square_grid = np.zeros((len(iso_grid), len(iso_grid[0].points)))
    
    for i, iso in enumerate(iso_grid):
        for j, star in enumerate(iso.points):
            chi_sq = sum(
                ((obs_mags[k] - star[filters[k]]) ** 2) / max(obs_errors[k] ** 2, 1e-3)  # Avoid zero division
                for k in range(len(obs_mags))
            )
            chi_square_grid[i, j] = chi_sq / DOF  # Compute reduced chi-square
    
    return chi_square_grid

# Ensure directories exist
os.makedirs(iso_dir, exist_ok=True)

# Clear previous isochrones
for file in os.listdir(iso_dir):
    os.remove(os.path.join(iso_dir, file))

# Generate isochrone grid
instances = np.array([
    synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                            iso_dir=iso_dir)
    for log_age in log_age_arr
])

# Compute chi-square values for each point, accounting for errors
chi_square_values = chi_square_with_errors(instances, sample_mags[0], sample_errors[0])

# Extract mass values for each isochrone
masses = np.array([[star['mass'] for star in iso.points] for iso in instances])

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
norm = LogNorm(vmin=max(np.min(chi_square_values), 1e-3), vmax=np.max(chi_square_values))
cmap = plt.get_cmap('coolwarm')

# Scatter plot with chi-square gradient
sc = ax.scatter(
    np.repeat(level_ages, chi_square_values.shape[1]), 
    masses.flatten(), c=chi_square_values.flatten(), cmap=cmap, norm=norm, s=50, edgecolor='k', linewidth=0.5
)
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Chi-Squared Value')

# Apply logarithmic scale to y-axis
ax.set_yscale('log')

# Contour plot for chi-square threshold
contour = plt.contour(level_ages, masses[0], chi_square_values.T, levels=[5.991], colors=['black'], linewidths=2.5)
ax.clabel(contour, inline=True, fontsize=12)

# Labels and styling
ax.set_xlabel('Age (years)')
ax.set_ylabel('Mass (M☉)')
ax.set_title(f'Age-Mass Diagram with Chi-Squared Contouring (AKs = {AKs})')
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Axis padding
x_padding = 0.1 * (level_ages[-1] - level_ages[0])
y_padding_factor = 0.1
ax.set_xlim(level_ages[0] - x_padding, level_ages[-1] + x_padding)
ax.set_ylim(np.min(masses) * (1 - y_padding_factor), np.max(masses) * (1 + y_padding_factor))

plt.show()
# Out:
# /home/wyz5rge/.local/lib/python3.9/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# Isochrone generation took 1.276652 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:05.855186   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.11
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.10
# Starting filter: jwst,F200W   Elapsed time: 1.22 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.85
#       Time taken: 1.84 seconds
# Isochrone generation took 1.154175 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:08.863095   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.47
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.49
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 23.22
#       Time taken: 1.90 seconds
# Isochrone generation took 1.156426 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:11.932697   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.72
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.77
# Starting filter: jwst,F200W   Elapsed time: 1.29 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 23.50
#       Time taken: 1.93 seconds
# Isochrone generation took 1.149383 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:15.033655   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.01
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 23.72
#       Time taken: 1.90 seconds
# Isochrone generation took 1.146134 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:18.093083   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.18
# Starting filter: jwst,F200W   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 23.89
#       Time taken: 1.94 seconds
# Isochrone generation took 1.139318 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:21.184131   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.28
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.40
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 24.09
#       Time taken: 1.93 seconds
# Isochrone generation took 1.150869 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:24.277403   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.43
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.54
# Starting filter: jwst,F200W   Elapsed time: 1.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 24.21
#       Time taken: 2.16 seconds
# Isochrone generation took 1.295326 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:27.751441   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.56
# Starting filter: jwst,F182M   Elapsed time: 0.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 24.33
#       Time taken: 2.08 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.121248 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:30.963582   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.62
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.80
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 24.44
#       Time taken: 1.86 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.148195 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:33.990708   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.77
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.98
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 24.60
#       Time taken: 1.89 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.263130 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:37.158123   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.88
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.05
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 24.66
#       Time taken: 1.90 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.158352 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:40.234909   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.05
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.13
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 24.73
#       Time taken: 1.89 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.149353 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:43.290774   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.17
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.19
# Starting filter: jwst,F200W   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 24.78
#       Time taken: 1.88 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.161574 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:46.351609   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.40
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.31
# Starting filter: jwst,F200W   Elapsed time: 1.30 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 24.89
#       Time taken: 1.93 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.104561 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:49.405080   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.71
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.48
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 25.04
#       Time taken: 2.01 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.241542 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:52.672904   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.88
# Starting filter: jwst,F182M   Elapsed time: 0.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.59
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 25.14
#       Time taken: 2.02 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.089334 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:55.794115   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.11
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.75
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 25.31
#       Time taken: 1.90 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.097858 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:58:58.808893   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.26
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.87
# Starting filter: jwst,F200W   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 25.44
#       Time taken: 1.88 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.133132 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.70  dist = 4500
#      Starting at:  2025-03-11 01:59:01.836572   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.30
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.95
# Starting filter: jwst,F200W   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 25.52
#       Time taken: 1.81 seconds

# %%
# find minimum chi-squared
# table of critical values for a = 0.05, df = 2: 5.991
m = min(chi_square_values[0])
for i in range(len(chi_square_values)):
    for j in range(len(chi_square_values[0])):
        if chi_square_values[i][j] < m:
            m = chi_square_values[i][j]
print(m)
# Out:
# 1.6879725826023737

# %%
AKs = 0.6  # Extinction value

# Clear previous isochrones
for file in os.listdir(iso_dir):
    os.remove(os.path.join(iso_dir, file))

# Generate isochrone grid
instances = np.array([
    synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                            iso_dir=iso_dir)
    for log_age in log_age_arr
])

# Compute chi-square values for each point, accounting for errors
chi_square_values = chi_square_with_errors(instances, sample_mags[0], sample_errors[0])

# Extract mass values for each isochrone
masses = np.array([[star['mass'] for star in iso.points] for iso in instances])

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
norm = LogNorm(vmin=max(np.min(chi_square_values), 1e-3), vmax=np.max(chi_square_values))
cmap = plt.get_cmap('coolwarm')

# Scatter plot with chi-square gradient
sc = ax.scatter(
    np.repeat(level_ages, chi_square_values.shape[1]), 
    masses.flatten(), c=chi_square_values.flatten(), cmap=cmap, norm=norm, s=50, edgecolor='k', linewidth=0.5
)
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Chi-Squared Value')

# Apply logarithmic scale to y-axis
ax.set_yscale('log')

# Contour plot for chi-square threshold
contour = plt.contour(level_ages, masses[0], chi_square_values.T, levels=[5.991], colors=['black'], linewidths=2.5)
ax.clabel(contour, inline=True, fontsize=12)

# Labels and styling
ax.set_xlabel('Age (years)')
ax.set_ylabel('Mass (M☉)')
ax.set_title(f'Age-Mass Diagram with Chi-Squared Contouring (AKs = {AKs})')
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Axis padding
x_padding = 0.1 * (level_ages[-1] - level_ages[0])
y_padding_factor = 0.1
ax.set_xlim(level_ages[0] - x_padding, level_ages[-1] + x_padding)
ax.set_ylim(np.min(masses) * (1 - y_padding_factor), np.max(masses) * (1 + y_padding_factor))

plt.show()
# Out:
# Isochrone generation took 1.187599 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:05.713306   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.95
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.97
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.74
#       Time taken: 1.91 seconds
# Isochrone generation took 1.157385 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:08.795997   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.31
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.35
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 23.11
#       Time taken: 1.89 seconds
# Isochrone generation took 1.130633 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:11.830458   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.56
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.64
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 23.38
#       Time taken: 1.89 seconds
# Isochrone generation took 1.120370 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:14.855489   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.78
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.88
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 23.60
#       Time taken: 1.90 seconds
# Isochrone generation took 1.157941 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:17.932242   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.05
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 23.77
#       Time taken: 1.89 seconds
# Isochrone generation took 1.135564 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:20.972506   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.12
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.27
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 23.97
#       Time taken: 1.86 seconds
# Isochrone generation took 1.131578 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:23.980682   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.27
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.41
# Starting filter: jwst,F200W   Elapsed time: 1.33 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 24.10
#       Time taken: 1.99 seconds
# Isochrone generation took 1.118503 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:27.106163   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.40
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.54
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 24.22
#       Time taken: 1.85 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.116683 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:30.090906   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.46
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 1.22 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 24.32
#       Time taken: 1.83 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.164505 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:33.097817   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.61
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.84
# Starting filter: jwst,F200W   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 24.48
#       Time taken: 1.93 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.162693 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:36.206792   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.72
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.91
# Starting filter: jwst,F200W   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 24.54
#       Time taken: 1.83 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.129432 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:39.183328   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.89
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.00
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 24.62
#       Time taken: 1.83 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.128041 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:42.158703   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.02
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.06
# Starting filter: jwst,F200W   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 24.66
#       Time taken: 1.96 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.158992 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:45.295701   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.25
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.18
# Starting filter: jwst,F200W   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 24.77
#       Time taken: 1.92 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.076668 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:48.305070   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.56
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.35
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 24.93
#       Time taken: 1.85 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.077641 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:51.243172   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.72
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.46
# Starting filter: jwst,F200W   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 25.02
#       Time taken: 1.82 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.101805 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:54.176951   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.95
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.62
# Starting filter: jwst,F200W   Elapsed time: 1.30 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 25.20
#       Time taken: 1.93 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.101706 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 01:59:57.217820   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.10
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.74
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 25.33
#       Time taken: 1.91 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.113769 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.60  dist = 4500
#      Starting at:  2025-03-11 02:00:00.263562   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.14
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.82
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 25.40
#       Time taken: 1.92 seconds

# %%
m = min(chi_square_values[0])
for i in range(len(chi_square_values)):
    for j in range(len(chi_square_values[0])):
        if chi_square_values[i][j] < m:
            m = chi_square_values[i][j]
print(m)
# Out:
# 2.581168444392999

# %%
AKs = 0.8  # Extinction value

# Clear previous isochrones
for file in os.listdir(iso_dir):
    os.remove(os.path.join(iso_dir, file))

# Generate isochrone grid
instances = np.array([
    synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                            iso_dir=iso_dir)
    for log_age in log_age_arr
])

# Compute chi-square values for each point, accounting for errors
chi_square_values = chi_square_with_errors(instances, sample_mags[0], sample_errors[0])

# Extract mass values for each isochrone
masses = np.array([[star['mass'] for star in iso.points] for iso in instances])

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
norm = LogNorm(vmin=max(np.min(chi_square_values), 1e-3), vmax=np.max(chi_square_values))
cmap = plt.get_cmap('coolwarm')

# Scatter plot with chi-square gradient
sc = ax.scatter(
    np.repeat(level_ages, chi_square_values.shape[1]), 
    masses.flatten(), c=chi_square_values.flatten(), cmap=cmap, norm=norm, s=50, edgecolor='k', linewidth=0.5
)
cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Chi-Squared Value')

# Apply logarithmic scale to y-axis
ax.set_yscale('log')

# Contour plot for chi-square threshold
contour = plt.contour(level_ages, masses[0], chi_square_values.T, levels=[5.991], colors=['black'], linewidths=2.5)
ax.clabel(contour, inline=True, fontsize=12)

# Labels and styling
ax.set_xlabel('Age (years)')
ax.set_ylabel('Mass (M☉)')
ax.set_title(f'Age-Mass Diagram with Chi-Squared Contouring (AKs = {AKs})')
ax.grid(True, which='both', linestyle='--', linewidth=0.5)

# Axis padding
x_padding = 0.1 * (level_ages[-1] - level_ages[0])
y_padding_factor = 0.1
ax.set_xlim(level_ages[0] - x_padding, level_ages[-1] + x_padding)
ax.set_ylim(np.min(masses) * (1 - y_padding_factor), np.max(masses) * (1 + y_padding_factor))

plt.show()
# Out:
# Isochrone generation took 1.195871 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:03.988104   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.26
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.23
# Starting filter: jwst,F200W   Elapsed time: 1.29 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.97
#       Time taken: 1.96 seconds
# Isochrone generation took 1.156160 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:07.121113   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.62
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.62
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 23.34
#       Time taken: 1.89 seconds
# Isochrone generation took 1.135420 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:10.156078   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.88
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.91
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 23.61
#       Time taken: 1.93 seconds
# Isochrone generation took 1.153445 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:13.258155   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.14
# Starting filter: jwst,F200W   Elapsed time: 1.30 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 23.83
#       Time taken: 1.94 seconds
# Isochrone generation took 1.151974 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:16.366048   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.32
# Starting filter: jwst,F200W   Elapsed time: 1.33 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 24.00
#       Time taken: 1.95 seconds
# Isochrone generation took 1.281621 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:19.612152   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.44
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.53
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 24.20
#       Time taken: 1.86 seconds
# Isochrone generation took 1.138733 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:22.631797   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.58
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 24.33
#       Time taken: 1.86 seconds
# Isochrone generation took 1.141547 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:25.650473   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.72
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.80
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 24.45
#       Time taken: 1.90 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.136618 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:28.696842   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.78
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.94
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 24.55
#       Time taken: 1.86 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.133933 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:31.700205   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.92
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 25.11
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 24.71
#       Time taken: 1.85 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.131534 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:34.696066   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 25.04
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.18
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 24.77
#       Time taken: 1.85 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.133745 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:37.694519   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.20
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.26
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 24.84
#       Time taken: 1.87 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.144506 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:40.718624   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.33
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.32
# Starting filter: jwst,F200W   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 24.89
#       Time taken: 1.89 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.149973 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:43.774577   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.56
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.44
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 25.00
#       Time taken: 1.93 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.114151 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:46.831772   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.87
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.61
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 25.15
#       Time taken: 1.91 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.128203 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:49.889944   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 26.04
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.72
# Starting filter: jwst,F200W   Elapsed time: 1.32 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 25.25
#       Time taken: 1.99 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.140886 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:53.036560   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.27
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.88
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 25.42
#       Time taken: 1.91 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.110862 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:56.076698   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.42
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 26.00
# Starting filter: jwst,F200W   Elapsed time: 1.35 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 25.56
#       Time taken: 1.98 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.077075 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.80  dist = 4500
#      Starting at:  2025-03-11 02:00:59.143948   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.46
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 26.08
# Starting filter: jwst,F200W   Elapsed time: 1.29 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 25.63
#       Time taken: 1.93 seconds

# %%
m = min(chi_square_values[0])
for i in range(len(chi_square_values)):
    for j in range(len(chi_square_values[0])):
        if chi_square_values[i][j] < min:
            m = chi_square_values[i][j]
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       2 for i in range(len(chi_square_values)):
#       3     for j in range(len(chi_square_values[0])):
# ----> 4         if chi_square_values[i][j] < min:
#       5             m = chi_square_values[i][j]
#       6 print(m)
#
# TypeError: '<' not supported between instances of 'float' and 'builtin_function_or_method'
