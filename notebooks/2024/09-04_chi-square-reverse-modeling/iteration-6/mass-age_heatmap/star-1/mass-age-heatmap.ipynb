# %%
# Import necessary packages
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening
from spisea.imf import imf, multiplicity
from matplotlib.colors import LogNorm
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 0      # Set which star in the CSV to analyze
num_top_predictions = 10  # Control how many top predictions to plot

# AKs values from 0 to 1 in increments of 0.1
extinction_values = np.arange(0, 1, 0.1)

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawCardelli(3.1)
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes, skipping the header row
sample_mags = []
with open('../../../s284-162-182.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(x) for x in lines])

# Chi-square minimization function
def chi_square_reverse_model(iso_grid, sample_mags):
    chi_square_grid = np.zeros((len(iso_grid), len(iso_grid[0].points)))
    for i, iso in enumerate(iso_grid):
        for j, star in enumerate(iso.points):
            chi_square_grid[i, j] = sum(((sample_mags[k] - star[filters[k]]) ** 2) / star[filters[k]] for k in range(len(sample_mags)))
    return chi_square_grid

# Ensure directories exist
os.makedirs(iso_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# Loop through each extinction value
for AKs in extinction_values:
    # Clear previous isochrones
    for file in os.listdir(iso_dir):
        os.remove(os.path.join(iso_dir, file))

    # Generate isochrone grid
    instances = np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

    # Compute chi-square for each point
    chi_square_values = chi_square_reverse_model(instances, sample_mags[star_index])

    # Plot single diagram
    fig, ax = plt.subplots(figsize=(10, 8))
    norm = LogNorm(vmin=max(np.min(chi_square_values), 1e-3), vmax=np.max(chi_square_values))
    cmap = plt.get_cmap('coolwarm')

    # Scatter plot with larger point size
    sc = ax.scatter(
        np.repeat(level_ages, chi_square_values.shape[1]), 
        np.tile([star['mass'] for star in instances[0].points], chi_square_values.shape[0]),
        c=chi_square_values.flatten(), cmap=cmap, norm=norm, s=50, edgecolor='k', linewidth=0.5
    )
    cbar = plt.colorbar(sc, ax=ax)
    cbar.set_label('Chi-Squared Value')

    # Apply logarithmic scale to y-axis
    ax.set_yscale('log')

    # Add labels, grid, and legend
    ax.set_xlabel('Age (years)')
    ax.set_ylabel('Mass (M☉)')
    ax.set_title(f'Age-Mass Diagram with Chi-Squared Coloring (AKs = {AKs})')
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)  # Adjust grid for log scale

    # Save the figure
    plt.savefig(os.path.join(output_dir, f'Age_Mass_AKs_{AKs}.png'))
    plt.close()
# Out:
# /home/wyz5rge/.local/lib/python3.9/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# Isochrone generation took 1.386821 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:37.627877   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
#       Time taken: 1.29 seconds
# Isochrone generation took 1.146506 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:40.076291   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
#       Time taken: 1.26 seconds
# Isochrone generation took 1.148854 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:42.501273   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
#       Time taken: 1.23 seconds
# Isochrone generation took 1.109599 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:44.856623   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
#       Time taken: 1.21 seconds
# Isochrone generation took 1.151552 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:47.229960   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
#       Time taken: 1.23 seconds
# Isochrone generation took 1.124854 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:49.601099   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
#       Time taken: 1.25 seconds
# Isochrone generation took 1.149568 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:52.012221   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
#       Time taken: 1.31 seconds
# Isochrone generation took 1.134325 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:54.477776   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.158224 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:56.905213   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.108716 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:20:59.305203   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
#       Time taken: 1.18 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.273844 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:01.777509   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.153929 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:04.203064   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.145889 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:06.612325   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.117366 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:09.000549   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
#       Time taken: 1.19 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.150125 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:11.355953   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
#       Time taken: 1.22 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.090160 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:13.682466   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
#       Time taken: 1.22 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.074215 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:15.990562   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
#       Time taken: 1.19 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.070920 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:18.267810   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
#       Time taken: 1.23 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.105624 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2025-01-29 06:21:20.615384   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
#       Time taken: 1.27 seconds
# Isochrone generation took 1.355236 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:23.792499   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.15
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.31
#       Time taken: 1.30 seconds
# Isochrone generation took 1.181394 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:26.290137   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.51
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.69
#       Time taken: 1.31 seconds
# Isochrone generation took 1.173862 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:28.785426   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.77
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.98
#       Time taken: 1.30 seconds
# Isochrone generation took 1.174051 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:31.275098   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.21
#       Time taken: 1.30 seconds
# Isochrone generation took 1.314286 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:33.903007   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.14
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.39
#       Time taken: 1.30 seconds
# Isochrone generation took 1.163464 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:36.381682   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.33
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.61
#       Time taken: 1.30 seconds
# Isochrone generation took 1.162453 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:38.854105   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.48
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.75
#       Time taken: 1.30 seconds
# Isochrone generation took 1.164516 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:41.328212   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.61
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.88
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.165853 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:43.803320   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.67
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.01
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.170653 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:46.294552   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.81
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.18
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.164791 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:48.777580   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.25
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.148303 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:51.230337   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.34
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.168462 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:53.700378   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.22
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.40
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.155660 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:56.150648   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.45
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.52
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.274979 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:21:58.733538   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.70
#       Time taken: 1.32 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.220000 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:22:01.288192   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.92
# Starting filter: jwst,F182M   Elapsed time: 0.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.80
#       Time taken: 1.54 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.140994 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:22:03.987172   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.16
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.97
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.134067 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:22:06.431860   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.31
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.09
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.117129 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.10  dist = 4500
#      Starting at:  2025-01-29 06:22:08.851175   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.35
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.16
#       Time taken: 1.28 seconds
# Isochrone generation took 1.212760 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:11.775846   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.31
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.44
#       Time taken: 1.31 seconds
# Isochrone generation took 1.166978 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:14.271613   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.67
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.83
#       Time taken: 1.30 seconds
# Isochrone generation took 1.167830 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:16.752566   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.93
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.11
#       Time taken: 1.40 seconds
# Isochrone generation took 1.307026 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:19.480408   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.14
# Starting filter: jwst,F182M   Elapsed time: 0.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.35
#       Time taken: 1.51 seconds
# Isochrone generation took 1.267880 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:22.270426   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.30
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.52
#       Time taken: 1.37 seconds
# Isochrone generation took 1.104667 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:24.756409   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.49
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.74
#       Time taken: 1.26 seconds
# Isochrone generation took 1.158981 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:27.190604   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.63
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.88
#       Time taken: 1.26 seconds
# Isochrone generation took 1.210979 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:29.674700   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.01
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.305284 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:32.277514   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.82
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.14
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.184896 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:34.768091   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.97
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.32
#       Time taken: 1.35 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.177123 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:37.306575   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.39
#       Time taken: 1.31 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.173987 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:39.806094   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.47
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.169617 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:42.252147   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.38
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.53
#       Time taken: 1.32 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.161619 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:44.744882   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.61
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.65
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.118981 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:47.135340   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.92
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.83
#       Time taken: 1.35 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.140387 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:49.635816   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.08
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.93
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.138693 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:52.080274   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.32
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.10
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.152058 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:54.524186   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.47
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.22
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.145524 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.20  dist = 4500
#      Starting at:  2025-01-29 06:22:57.024995   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.51
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.29
#       Time taken: 1.36 seconds
# Isochrone generation took 1.215693 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:00.023226   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.47
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.57
#       Time taken: 1.30 seconds
# Isochrone generation took 1.173648 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:02.513680   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.96
#       Time taken: 1.28 seconds
# Isochrone generation took 1.165735 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:04.972120   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.09
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.25
#       Time taken: 1.28 seconds
# Isochrone generation took 1.289571 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:07.551954   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.30
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.48
#       Time taken: 1.28 seconds
# Isochrone generation took 1.166597 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:10.012658   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.46
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.65
#       Time taken: 1.31 seconds
# Isochrone generation took 1.176649 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:12.512691   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.64
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.87
#       Time taken: 1.27 seconds
# Isochrone generation took 1.177913 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:14.977682   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.79
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.01
#       Time taken: 1.30 seconds
# Isochrone generation took 1.145296 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:17.436689   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.93
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.14
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.163221 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:19.907522   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.98
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.28
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.164089 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:22.373750   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.13
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.45
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.162174 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:24.829734   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.52
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.165697 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:27.286865   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.41
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.60
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.162700 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:29.739752   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.54
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.66
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.149865 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:32.189955   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.77
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.78
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.118316 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:34.580490   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.08
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.96
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.117864 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:36.995415   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.24
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.06
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.121908 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:39.418948   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.47
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.23
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.103840 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:41.789868   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.63
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.35
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.103075 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.30  dist = 4500
#      Starting at:  2025-01-29 06:23:44.157981   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.67
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.42
#       Time taken: 1.30 seconds
# Isochrone generation took 1.198676 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:47.188980   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.63
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.71
#       Time taken: 1.28 seconds
# Isochrone generation took 1.170515 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:49.655849   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.99
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.09
#       Time taken: 1.27 seconds
# Isochrone generation took 1.168543 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:52.104900   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.25
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.38
#       Time taken: 1.29 seconds
# Isochrone generation took 1.165476 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:54.571270   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.46
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.61
#       Time taken: 1.28 seconds
# Isochrone generation took 1.161164 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:57.028025   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.62
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.79
#       Time taken: 1.27 seconds
# Isochrone generation took 1.153336 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:23:59.460698   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.80
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.01
#       Time taken: 1.28 seconds
# Isochrone generation took 1.155944 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:01.910532   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.95
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.14
#       Time taken: 1.28 seconds
# Isochrone generation took 1.182880 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:04.391173   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.09
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.27
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.155869 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:06.820811   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.14
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.41
#       Time taken: 1.27 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.143360 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:09.243914   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.58
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.143767 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:11.659451   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.41
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.65
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.130677 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:14.061793   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.57
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.74
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.155390 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:16.490387   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.70
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.79
#       Time taken: 1.27 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.144850 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:18.920532   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.93
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.92
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.079572 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:21.265667   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.24
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.09
#       Time taken: 1.23 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.110737 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.40  dist = 4500
#      Starting at:  2025-01-29 06:24:23.616846   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.40
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.19
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.122091 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.40  dist = 4500
# ...
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.72
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.80
#       Time taken: 1.31 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.187124 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:16.226161   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.78
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.94
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.187937 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:18.724051   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.92
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 25.11
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.189033 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:21.220791   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 25.04
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.18
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.185548 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:23.713645   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.20
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.26
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.175858 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:26.200081   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.33
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.32
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.166005 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:28.665741   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.56
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.44
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.130408 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:31.100597   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.87
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.61
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.140791 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:33.547335   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 26.04
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.72
#       Time taken: 1.27 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.108528 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:35.934247   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.27
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.88
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.131094 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:38.378727   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.42
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 26.00
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.117910 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.80  dist = 4500
#      Starting at:  2025-01-29 06:27:40.796139   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.46
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 26.08
#       Time taken: 1.28 seconds
# Isochrone generation took 1.193134 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:43.671502   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.42
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.36
#       Time taken: 1.26 seconds
# Isochrone generation took 1.165786 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:46.107635   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.78
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.75
#       Time taken: 1.28 seconds
# Isochrone generation took 1.166629 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:48.566724   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 24.04
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 24.04
#       Time taken: 1.28 seconds
# Isochrone generation took 1.327453 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:51.183451   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.27
#       Time taken: 1.27 seconds
# Isochrone generation took 1.169117 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:53.635760   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.41
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.45
#       Time taken: 1.26 seconds
# Isochrone generation took 1.167523 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:56.077772   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.59
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.67
#       Time taken: 1.25 seconds
# Isochrone generation took 1.156742 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:27:58.499420   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.74
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.80
#       Time taken: 1.26 seconds
# Isochrone generation took 1.158784 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:00.929192   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.88
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.93
#       Time taken: 1.32 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.162245 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:03.429723   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.93
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 25.07
#       Time taken: 1.26 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.194694 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:05.896265   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 25.08
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 25.24
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.166957 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:08.381052   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 25.20
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.31
#       Time taken: 1.29 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.164607 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:10.849871   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.36
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.39
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.128458 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:13.317904   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.49
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.45
#       Time taken: 1.24 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.126390 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:15.698863   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.72
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.57
#       Time taken: 1.22 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.083857 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:18.013154   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 26.03
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.75
#       Time taken: 1.21 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.134120 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:20.367732   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 26.19
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.85
#       Time taken: 1.25 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.101455 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:22.733130   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.43
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 26.02
#       Time taken: 1.30 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.120968 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:25.164134   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.58
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 26.13
#       Time taken: 1.27 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.106968 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.90  dist = 4500
#      Starting at:  2025-01-29 06:28:27.553910   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.62
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 26.21
#       Time taken: 1.28 seconds
