# %%
# Import necessary packages
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 0      # Set which star in the CSV to analyze
num_top_predictions = 10  # Control how many top predictions to plot

# AKs values from 0 to 20 in increments of 2
extinction_values = np.arange(0, 22, 2)

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes, skipping the header row
sample_mags = []
with open('../../../s284-162-182.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(x) for x in lines])

# Chi-square minimization function
def chi_square_reverse_model(iso_grid, sample_mags):
    results = []
    for i, iso in enumerate(iso_grid):
        for star in iso.points:
            chi_square = sum(((sample_mags[k] - star[filters[k]]) ** 2) / star[filters[k]] for k in range(len(sample_mags)))
            results.append([chi_square, star['mass'], 10 ** log_age_arr[i]])
    
    return sorted(results, key=lambda x: x[0])

# Ensure both isochrone and output directories exist before the loop
os.makedirs(iso_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)


# Loop through each extinction value, delete old isochrones, and generate diagrams
for AKs in extinction_values:
    # Clear previous isochrones
    for file in os.listdir(iso_dir):
        os.remove(os.path.join(iso_dir, file))
    
    # Generate isochrone grid
    instances = np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

    # Run chi-square minimization and get top results
    sorted_results = chi_square_reverse_model(instances, sample_mags[star_index])
    top_results = sorted_results[:num_top_predictions]

    # Create figure with two subplots side-by-side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    cmap = plt.get_cmap('coolwarm')

    # Color-magnitude diagram (CMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax1.plot(instance.points[filters[0]] - instance.points[filters[1]], 
                 instance.points[filters[1]], color=color)
    ax1.set_xlabel('F162M - F182M')
    ax1.set_ylabel('F182M')
    ax1.invert_yaxis()
    ax1.grid(True)  # Add grid lines to CMD

    # Magnitude-magnitude diagram (MMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax2.plot(instance.points[filters[0]], instance.points[filters[1]], color=color)
    ax2.set_xlabel('F162M')
    ax2.set_ylabel('F182M')
    ax2.invert_xaxis()
    ax2.invert_yaxis()
    ax2.grid(True)  # Add grid lines to MMD

    # Create colorbar for both diagrams
    norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
    sm = ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=[ax1, ax2])
    cbar.set_label('Age (millions of years)')
    cbar.set_ticks(level_ages)
    cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

    # Plot top results on CMD with color gradient and labels
    for j, (chi_square, mass, age) in enumerate(top_results):
        closest_age_idx = np.argmin(abs(level_ages - age))
        iso_instance = instances[closest_age_idx]
        mass_idx = np.argmin(abs(iso_instance.points['mass'] - mass))
        color = cmap(j / (num_top_predictions - 1))
        ax1.plot(iso_instance.points[mass_idx][filters[0]] - iso_instance.points[mass_idx][filters[1]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")
        ax2.plot(iso_instance.points[mass_idx][filters[0]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")

    # Plot reference star in both diagrams
    ref_star_color = 'gold'  # Optional: distinguish reference star color
    ref_star_marker = '*'  # Optional: distinguish reference star marker

    ax1.plot(sample_mags[star_index][0] - sample_mags[star_index][1], sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

    ax2.plot(sample_mags[star_index][0], 
         sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

    # Legends and saving
    ax1.legend()
    ax2.legend()
    fig.suptitle(f"AKs = {AKs}")
    plt.savefig(os.path.join(output_dir, f'CMD_MMD_AKs_{AKs}.png'))
    plt.close()
# Out:
# Isochrone generation took 2.530566 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:57:57.715938   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
#       Time taken: 3.49 seconds
# Isochrone generation took 2.422412 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:03.659588   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 1.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
#       Time taken: 3.51 seconds
# Isochrone generation took 2.433338 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:09.632804   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
#       Time taken: 3.48 seconds
# Isochrone generation took 1.282291 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:14.416526   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
#       Time taken: 2.49 seconds
# Isochrone generation took 2.421071 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:19.365443   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
#       Time taken: 3.48 seconds
# Isochrone generation took 2.400325 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:25.282444   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
#       Time taken: 3.52 seconds
# Isochrone generation took 2.412762 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:31.249346   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
#       Time taken: 3.48 seconds
# Isochrone generation took 2.404742 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:37.162798   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 2.447137 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:43.125525   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 2.420709 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:49.054308   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 1.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
#       Time taken: 3.51 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 2.415109 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:58:55.010849   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
#       Time taken: 3.47 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 2.449330 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:00.966322   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 1.94 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
#       Time taken: 3.73 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 2.424367 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:07.155735   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 2.394734 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:13.067108   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
#       Time taken: 3.49 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 2.299246 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:18.893646   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
#       Time taken: 3.49 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 2.293768 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:24.711058   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 2.289867 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:30.517675   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
#       Time taken: 3.49 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 2.311969 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:36.355439   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
#       Time taken: 3.49 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 2.259496 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:59:42.141149   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
#       Time taken: 3.49 seconds
# Isochrone generation took 2.514401 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:59:49.254385   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.55
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.95
#       Time taken: 3.49 seconds
# Isochrone generation took 2.414378 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:59:55.193064   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 25.91
# Starting filter: jwst,F182M   Elapsed time: 1.76 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 25.33
#       Time taken: 3.50 seconds
# Isochrone generation took 2.408180 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:01.130164   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 26.16
# Starting filter: jwst,F182M   Elapsed time: 1.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 25.62
#       Time taken: 3.55 seconds
# Isochrone generation took 2.443056 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:07.154526   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 26.37
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 25.86
#       Time taken: 3.49 seconds
# Isochrone generation took 2.418276 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:13.092123   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 26.53
# Starting filter: jwst,F182M   Elapsed time: 1.78 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 26.03
#       Time taken: 3.53 seconds
# Isochrone generation took 2.587011 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:19.247015   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 26.71
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 26.25
#       Time taken: 3.49 seconds
# Isochrone generation took 2.422972 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:25.191969   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 26.86
# Starting filter: jwst,F182M   Elapsed time: 1.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 26.39
#       Time taken: 3.52 seconds
# Isochrone generation took 2.426939 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:31.168965   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 26.99
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 26.52
#       Time taken: 3.50 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 2.448207 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:37.154363   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 27.06
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 26.65
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 2.435473 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:43.103793   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 27.21
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 26.82
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 2.431953 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:49.045511   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 27.32
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 26.89
#       Time taken: 3.51 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 2.443882 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:00:55.035307   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 27.49
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 26.97
#       Time taken: 3.49 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 2.431009 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:00.986646   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 27.62
# Starting filter: jwst,F182M   Elapsed time: 1.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 27.02
#       Time taken: 3.47 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 2.419528 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:06.908995   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 27.85
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 27.14
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 2.336182 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:12.754510   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 28.16
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 27.31
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 2.306657 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:18.571345   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 28.32
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 27.41
#       Time taken: 3.48 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 2.333573 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:24.419741   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 28.56
# Starting filter: jwst,F182M   Elapsed time: 1.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 27.58
#       Time taken: 3.57 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 2.305061 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:30.324378   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 28.72
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 27.69
#       Time taken: 3.47 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 2.273354 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 04:01:36.103495   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 28.76
# Starting filter: jwst,F182M   Elapsed time: 1.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 27.77
#       Time taken: 3.48 seconds
# Isochrone generation took 2.819337 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:01:43.541298   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 29.05
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 27.66
#       Time taken: 3.49 seconds
# Isochrone generation took 2.449934 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:01:49.509781   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 29.41
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 28.05
#       Time taken: 3.50 seconds
# Isochrone generation took 2.426720 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:01:55.464956   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 29.66
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 28.34
#       Time taken: 3.50 seconds
# Isochrone generation took 2.427350 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:01.420587   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 29.87
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 28.57
#       Time taken: 3.50 seconds
# Isochrone generation took 2.428820 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:07.383157   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 30.03
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 28.75
#       Time taken: 3.50 seconds
# Isochrone generation took 2.217806 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:13.130129   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 30.21
# Starting filter: jwst,F182M   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 28.97
#       Time taken: 2.42 seconds
# Isochrone generation took 1.744879 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:17.322196   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 30.36
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 29.11
#       Time taken: 2.41 seconds
# Isochrone generation took 1.741825 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:21.498647   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 30.49
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 29.23
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.747908 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:25.666763   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 30.57
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 29.36
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.740552 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:29.833420   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 30.71
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 29.53
#       Time taken: 2.38 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.734433 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:33.975590   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 30.83
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 29.60
#       Time taken: 2.41 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.732188 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:38.139329   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 30.99
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 29.67
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.734870 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:42.292265   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 31.12
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 29.72
#       Time taken: 2.39 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.714638 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:46.423777   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 31.36
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 29.84
#       Time taken: 2.39 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.656991 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:50.494125   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 31.67
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 30.00
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.655674 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:54.576515   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 31.84
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 30.10
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.659576 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:02:58.656495   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 32.08
# Starting filter: jwst,F182M   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 30.26
#       Time taken: 2.41 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.654145 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:03:02.747722   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 32.24
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 30.38
#       Time taken: 2.40 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.822971 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 04:03:06.995067   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 32.28
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 30.46
#       Time taken: 2.39 seconds
# Isochrone generation took 1.816783 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:12.072828   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 32.52
# Starting filter: jwst,F182M   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 30.32
#       Time taken: 2.42 seconds
# Isochrone generation took 1.761714 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:16.276296   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 32.88
# Starting filter: jwst,F182M   Elapsed time: 1.22 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 30.71
#       Time taken: 2.43 seconds
# Isochrone generation took 1.759278 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:20.483700   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 33.13
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 31.00
#       Time taken: 2.39 seconds
# Isochrone generation took 1.742511 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:24.643810   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 33.34
# Starting filter: jwst,F182M   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 31.24
#       Time taken: 2.39 seconds
# Isochrone generation took 1.732914 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:28.793634   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 33.49
# Starting filter: jwst,F182M   Elapsed time: 1.21 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 31.41
#       Time taken: 2.61 seconds
# Isochrone generation took 2.304343 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:33.735609   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 33.67
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 31.64
#       Time taken: 2.93 seconds
# Isochrone generation took 2.286440 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:38.979379   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 33.82
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 31.77
#       Time taken: 2.91 seconds
# Isochrone generation took 2.306311 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:44.221416   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 33.95
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 31.90
#       Time taken: 2.88 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 2.295037 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:49.429963   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 34.03
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 32.02
#       Time taken: 2.89 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 2.295737 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:54.643431   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 34.18
# Starting filter: jwst,F182M   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 32.19
#       Time taken: 2.91 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 2.287198 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:03:59.871055   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 34.30
# Starting filter: jwst,F182M   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 32.25
#       Time taken: 2.88 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 2.295038 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:05.086624   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 34.46
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 32.33
#       Time taken: 2.93 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 2.293249 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:10.340312   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 34.59
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 32.37
#       Time taken: 2.88 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 2.271332 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:15.522454   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 34.82
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 32.48
#       Time taken: 2.88 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 2.410445 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:20.845299   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 35.14
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 32.64
#       Time taken: 2.89 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 2.203757 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:25.965553   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 35.31
# Starting filter: jwst,F182M   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 32.74
#       Time taken: 2.89 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 2.203270 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:31.090906   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 35.55
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 32.90
#       Time taken: 2.93 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 2.211904 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:36.260370   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 35.71
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 33.02
#       Time taken: 2.91 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 2.177116 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 6.00  dist = 4500
#      Starting at:  2024-10-29 04:04:41.372908   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 35.75
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 33.10
#       Time taken: 2.88 seconds
# Isochrone generation took 2.425124 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:04:47.785055   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 35.95
# Starting filter: jwst,F182M   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 32.94
#       Time taken: 2.92 seconds
# Isochrone generation took 2.324397 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:04:53.057637   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 36.30
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 33.32
#       Time taken: 2.92 seconds
# Isochrone generation took 2.322408 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:04:58.328727   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 36.55
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 33.62
#       Time taken: 2.95 seconds
# Isochrone generation took 2.318791 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:03.630684   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 36.76
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 33.85
#       Time taken: 2.93 seconds
# Isochrone generation took 2.318627 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:08.911631   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 36.92
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 34.03
#       Time taken: 2.91 seconds
# Isochrone generation took 2.305182 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:14.151342   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 37.09
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 34.25
#       Time taken: 2.95 seconds
# Isochrone generation took 2.314641 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:19.449690   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 37.24
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 34.39
#       Time taken: 2.90 seconds
# Isochrone generation took 2.302122 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:24.676680   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 37.37
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 34.51
#       Time taken: 3.00 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 2.297972 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:30.006484   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 37.46
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 34.63
#       Time taken: 2.93 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 2.312248 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:35.279443   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 37.61
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 34.80
#       Time taken: 2.89 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 2.527575 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:40.724653   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 37.73
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 34.87
#       Time taken: 2.92 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 2.347499 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:46.023814   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 37.89
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 34.94
#       Time taken: 2.88 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 2.309241 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:51.242291   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 38.02
# Starting filter: jwst,F182M   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 34.98
#       Time taken: 2.90 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 2.293766 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:05:56.469673   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 38.25
# Starting filter: jwst,F182M   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 35.09
#       Time taken: 2.90 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 2.202455 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:06:01.602164   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 38.57
# Starting filter: jwst,F182M   Elapsed time: 1.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 35.24
#       Time taken: 2.91 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 2.204692 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:06:06.746874   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 38.74
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 35.34
#       Time taken: 2.91 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.948575 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 04:06:11.645459   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 38.98
# ...
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69
#      70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 71     passkwargs = {k: v for k, v in kwargs.items()
#      72                   if v is not np._NoValue}
#      73
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in <dictcomp>(.0)
#      70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      71     passkwargs = {k: v for k, v in kwargs.items()
# ---> 72                   if v is not np._NoValue}
#      73
#      74     if type(obj) is not mu.ndarray:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f0964dffa60> (for post_execute):
# ------------------------------------------------------------------------
# KeyboardInterrupt                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2554                     # this happens for an empty bb
#    2555                     y = 1
# -> 2556             if title.get_window_extent(renderer).ymin < top:
#    2557                 y = self.transAxes.inverted().transform(
#    2558                         (0., top))[1]
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     878             self.figure.dpi = dpi
#     879         if self.get_text() == '':
# --> 880             tx, ty = self._get_xy_display()
#     881             return Bbox.from_bounds(tx, ty, 0, 0)
#     882
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in _get_xy_display(self)
#     222         """
#     223         x, y = self.get_unitless_position()
# --> 224         return self.get_transform().transform_point((x, y))
#     225
#     226     def _get_multialignment(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in transform_point(self, point)
#    1479         if len(point) != self.input_dims:
#    1480             raise ValueError("The length of 'point' must be 'self.input_dims'")
# -> 1481         return self.transform(np.asarray([point]))[0]
#    1482
#    1483     def transform_path(self, path):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in transform(self, values)
#    1392
#    1393         # Transform the values
# -> 1394         res = self.transform_affine(self.transform_non_affine(values))
#    1395
#    1396         # Convert the result back to the shape of the input values.
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2371     def transform_affine(self, points):
#    2372         # docstring inherited
# -> 2373         return self.get_affine().transform(points)
#    2374
#    2375     def transform_non_affine(self, points):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in get_affine(self)
#    2398             return self._b.get_affine()
#    2399         else:
# -> 2400             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2401                                 self._a.get_affine().get_matrix()))
#    2402
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f07ae5e7ae8> (for post_execute):
# ------------------------------------------------------------------------
# KeyboardInterrupt                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _setattr_cm(obj, **kwargs)
#    2020             setattr(obj, attr, val)
# -> 2021         yield
#    2022     finally:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     531                 _png.write_png(renderer._renderer, fh,
# --> 532                                self.figure.dpi, metadata=metadata)
#     533
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     118         # ignore the tracking, just draw and close all figures
#     119         try:
# --> 120             return show(True)
#     121         except Exception as e:
#     122             # safely show traceback if in IPython, else raise
#
# ~/.local/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      40             display(
#      41                 figure_manager.canvas.figure,
# ---> 42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      43             )
#      44     finally:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2088                 self.figure.set_edgecolor(origedgecolor)
#    2089                 self.figure.set_canvas(self)
# -> 2090             return result
#    2091
#    2092     @classmethod
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _setattr_cm(obj, **kwargs)
#    2025                 delattr(obj, attr)
#    2026             else:
# -> 2027                 setattr(obj, attr, orig)
#    2028
#    2029
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in _set_dpi(self, dpi, forward)
#     473         """
#     474         self._dpi = dpi
# --> 475         self.dpi_scale_trans.clear().scale(dpi, dpi)
#     476         w, h = self.get_size_inches()
#     477         self.set_size_inches(w, h, forward=forward)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in clear(self)
#    1909         # A bit faster than np.identity(3).
#    1910         self._mtx = IdentityTransform._mtx.copy()
# -> 1911         self.invalidate()
#    1912         return self
#    1913
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in invalidate(self)
#     133         if self.is_affine:
#     134             value = self.INVALID_AFFINE
# --> 135         return self._invalidate_internal(value, invalidating_node=self)
#     136
#     137     def _invalidate_internal(self, value, invalidating_node):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#    2339
#    2340         Transform._invalidate_internal(self, value=value,
# -> 2341                                        invalidating_node=invalidating_node)
#    2342
#    2343     def __eq__(self, other):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#    2339
#    2340         Transform._invalidate_internal(self, value=value,
# -> 2341                                        invalidating_node=invalidating_node)
#    2342
#    2343     def __eq__(self, other):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     160                 if parent is not None:
#     161                     parent._invalidate_internal(
# --> 162                         value=value, invalidating_node=self)
#     163
#     164     def set_children(self, *children):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     155             self._invalid = value
#     156
# --> 157             for parent in list(self._parents.values()):
#     158                 # Dereference the weak reference
#     159                 parent = parent()
#
# KeyboardInterrupt:
