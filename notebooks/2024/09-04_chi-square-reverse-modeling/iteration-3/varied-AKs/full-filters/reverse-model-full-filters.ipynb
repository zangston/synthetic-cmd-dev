# %%
# Import necessary packages
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 0      # Set which star in the CSV to analyze
num_top_predictions = 10  # Control how many top predictions to plot

# AKs values from 0 to 20 in increments of 2
extinction_values = np.arange(0, 22, 2)

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W', 'jwst,F356W', 'jwst,F405N']
filters = ['m_jwst_F162M', 'm_jwst_F182M', 'm_jwst_F200W', 'm_jwst_F356W', 'm_jwst_F405N']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes, skipping the header row
sample_mags = []
with open('../../../s284-no-errors.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(x) for x in lines])

# Chi-square minimization function
def chi_square_reverse_model(iso_grid, sample_mags):
    results = []
    for i, iso in enumerate(iso_grid):
        for star in iso.points:
            chi_square = sum(((sample_mags[k] - star[filters[k]]) ** 2) / star[filters[k]] for k in range(len(sample_mags)))
            results.append([chi_square, star['mass'], 10 ** log_age_arr[i]])
    
    return sorted(results, key=lambda x: x[0])

# Ensure both isochrone and output directories exist before the loop
os.makedirs(iso_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)


# Loop through each extinction value, delete old isochrones, and generate diagrams
for AKs in extinction_values:
    # Clear previous isochrones
    for file in os.listdir(iso_dir):
        os.remove(os.path.join(iso_dir, file))
    
    # Generate isochrone grid
    instances = np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

    # Run chi-square minimization and get top results
    sorted_results = chi_square_reverse_model(instances, sample_mags[star_index])
    top_results = sorted_results[:num_top_predictions]

    # Create figure with two subplots side-by-side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    cmap = plt.get_cmap('coolwarm')

    # Color-magnitude diagram (CMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax1.plot(instance.points[filters[0]] - instance.points[filters[1]], 
                 instance.points[filters[1]], color=color)
    ax1.set_xlabel('F162M - F182M')
    ax1.set_ylabel('F182M')
    ax1.invert_yaxis()
    ax1.set_xlim(ax1.get_xlim()[::-1])  # Reverse horizontal axis for CMD
    ax1.grid(True)  # Add grid lines to CMD

    # Magnitude-magnitude diagram (MMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax2.plot(instance.points[filters[0]], instance.points[filters[1]], color=color)
    ax2.set_xlabel('F162M')
    ax2.set_ylabel('F182M')
    ax2.invert_yaxis()
    ax2.grid(True)  # Add grid lines to MMD

    # Create colorbar for both diagrams
    norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
    sm = ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=[ax1, ax2])
    cbar.set_label('Age (millions of years)')
    cbar.set_ticks(level_ages)
    cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

    # Plot top results on CMD with color gradient and labels
    for j, (chi_square, mass, age) in enumerate(top_results):
        closest_age_idx = np.argmin(abs(level_ages - age))
        iso_instance = instances[closest_age_idx]
        mass_idx = np.argmin(abs(iso_instance.points['mass'] - mass))
        color = cmap(j / (num_top_predictions - 1))
        ax1.plot(iso_instance.points[mass_idx][filters[0]] - iso_instance.points[mass_idx][filters[1]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")
        ax2.plot(iso_instance.points[mass_idx][filters[0]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")

    # Plot reference star in both diagrams
    ref_star_color = 'gold'  # Optional: distinguish reference star color
    ref_star_marker = '*'  # Optional: distinguish reference star marker

    ax1.plot(sample_mags[star_index][0] - sample_mags[star_index][1], 
         sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

ax2.plot(sample_mags[star_index][0], 
         sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

    # Legends and saving
    ax1.legend()
    ax2.legend()
    fig.suptitle(f"AKs = {AKs}")
    plt.savefig(os.path.join(output_dir, f'CMD_MMD_AKs_{AKs}.png'))
    plt.close()
# Out:
# Isochrone generation took 2.551865 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:32:49.969368   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 1.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
# Starting filter: jwst,F200W   Elapsed time: 3.49 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.04
# Starting filter: jwst,F356W   Elapsed time: 5.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 21.17
# Starting filter: jwst,F405N   Elapsed time: 7.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 20.84
#       Time taken: 7.88 seconds
# Isochrone generation took 1.227464 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:32:59.099833   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 22.41
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 21.50
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 21.16
#       Time taken: 3.57 seconds
# Isochrone generation took 1.569860 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:04.262814   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 1.25 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
# Starting filter: jwst,F200W   Elapsed time: 2.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 22.69
# Starting filter: jwst,F356W   Elapsed time: 3.97 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 21.74
# Starting filter: jwst,F405N   Elapsed time: 5.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 21.39
#       Time taken: 6.68 seconds
# Isochrone generation took 1.397676 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:12.356629   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 22.91
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 21.92
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 21.56
#       Time taken: 3.58 seconds
# Isochrone generation took 1.214441 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:17.181044   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
# Starting filter: jwst,F200W   Elapsed time: 1.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 23.08
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 22.06
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 21.70
#       Time taken: 3.56 seconds
# Isochrone generation took 1.325627 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:22.086014   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 23.28
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 22.21
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 21.85
#       Time taken: 3.60 seconds
# Isochrone generation took 1.288119 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:26.997832   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 23.41
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 22.31
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 21.94
#       Time taken: 3.58 seconds
# Isochrone generation took 1.290668 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:31.889963   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 23.53
# Starting filter: jwst,F356W   Elapsed time: 2.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 22.39
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 22.02
#       Time taken: 3.63 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.320979 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:36.861788   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 23.64
# Starting filter: jwst,F356W   Elapsed time: 2.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 22.43
# Starting filter: jwst,F405N   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 22.08
#       Time taken: 3.61 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.300695 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:41.793118   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
# Starting filter: jwst,F200W   Elapsed time: 1.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 23.79
# Starting filter: jwst,F356W   Elapsed time: 2.07 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 22.54
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 22.18
#       Time taken: 3.55 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.281776 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:46.645547   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 23.85
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 22.58
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 22.22
#       Time taken: 3.65 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.223441 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:51.541877   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 23.93
# Starting filter: jwst,F356W   Elapsed time: 2.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 22.62
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 22.26
#       Time taken: 4.01 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.705356 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:33:57.288536   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
# Starting filter: jwst,F200W   Elapsed time: 2.36 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 23.98
# Starting filter: jwst,F356W   Elapsed time: 3.54 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 22.64
# Starting filter: jwst,F405N   Elapsed time: 4.79 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 22.29
#       Time taken: 6.07 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.690791 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:05.079141   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
# Starting filter: jwst,F200W   Elapsed time: 2.36 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 24.08
# Starting filter: jwst,F356W   Elapsed time: 3.54 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F356W = 22.68
# Starting filter: jwst,F405N   Elapsed time: 4.78 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F405N = 22.32
#       Time taken: 6.05 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.622593 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:12.782811   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
# Starting filter: jwst,F200W   Elapsed time: 2.36 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 24.24
# Starting filter: jwst,F356W   Elapsed time: 3.54 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F356W = 22.74
# Starting filter: jwst,F405N   Elapsed time: 4.78 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F405N = 22.36
#       Time taken: 6.06 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.630118 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:20.499518   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 2.35 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 24.34
# Starting filter: jwst,F356W   Elapsed time: 3.53 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F356W = 22.77
# Starting filter: jwst,F405N   Elapsed time: 4.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F405N = 22.38
#       Time taken: 6.05 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.623059 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:28.199806   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 1.19 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
# Starting filter: jwst,F200W   Elapsed time: 2.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 24.51
# Starting filter: jwst,F356W   Elapsed time: 3.56 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F356W = 22.90
# Starting filter: jwst,F405N   Elapsed time: 4.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F405N = 22.49
#       Time taken: 6.10 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.773389 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:36.097916   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
# Starting filter: jwst,F200W   Elapsed time: 2.35 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 24.64
# Starting filter: jwst,F356W   Elapsed time: 3.53 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F356W = 23.04
# Starting filter: jwst,F405N   Elapsed time: 4.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F405N = 22.62
#       Time taken: 6.05 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.626320 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-29 03:34:43.805525   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 1.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
# Starting filter: jwst,F200W   Elapsed time: 2.36 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 24.71
# Starting filter: jwst,F356W   Elapsed time: 3.53 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F356W = 23.13
# Starting filter: jwst,F405N   Elapsed time: 4.76 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F405N = 22.69
#       Time taken: 6.06 seconds
# Isochrone generation took 1.784506 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:34:52.497959   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 25.55
# Starting filter: jwst,F182M   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 24.95
# Starting filter: jwst,F200W   Elapsed time: 2.49 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 24.35
# Starting filter: jwst,F356W   Elapsed time: 3.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 22.26
# Starting filter: jwst,F405N   Elapsed time: 4.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 21.84
#       Time taken: 6.23 seconds
# Isochrone generation took 1.726882 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:00.483621   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 25.91
# Starting filter: jwst,F182M   Elapsed time: 1.19 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 25.33
# Starting filter: jwst,F200W   Elapsed time: 2.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 24.72
# Starting filter: jwst,F356W   Elapsed time: 3.49 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 22.59
# Starting filter: jwst,F405N   Elapsed time: 4.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 22.16
#       Time taken: 5.01 seconds
# Isochrone generation took 1.237605 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:06.746512   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 26.16
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 25.62
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 24.99
# Starting filter: jwst,F356W   Elapsed time: 2.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 22.83
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 22.39
#       Time taken: 3.65 seconds
# Isochrone generation took 1.269923 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:11.685076   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 26.37
# Starting filter: jwst,F182M   Elapsed time: 0.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 25.86
# Starting filter: jwst,F200W   Elapsed time: 1.53 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 25.21
# Starting filter: jwst,F356W   Elapsed time: 2.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 23.01
# Starting filter: jwst,F405N   Elapsed time: 3.02 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 22.56
#       Time taken: 3.81 seconds
# Isochrone generation took 1.291814 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:16.806953   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 26.53
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 26.03
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 25.37
# Starting filter: jwst,F356W   Elapsed time: 2.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 23.15
# Starting filter: jwst,F405N   Elapsed time: 2.94 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 22.70
#       Time taken: 3.69 seconds
# Isochrone generation took 1.280600 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:21.796559   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 26.71
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 26.25
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 25.57
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 23.30
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 22.85
#       Time taken: 3.56 seconds
# Isochrone generation took 1.378404 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:26.758229   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 26.86
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 26.39
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 25.70
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 23.39
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 22.94
#       Time taken: 3.59 seconds
# Isochrone generation took 1.278921 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:31.648632   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 26.99
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 26.52
# Starting filter: jwst,F200W   Elapsed time: 1.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 25.81
# Starting filter: jwst,F356W   Elapsed time: 2.07 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 23.48
# Starting filter: jwst,F405N   Elapsed time: 2.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 23.03
#       Time taken: 3.55 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.286193 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:36.502143   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 27.06
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 26.65
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 25.91
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 23.51
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 23.08
#       Time taken: 3.58 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.371295 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:41.468841   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 27.21
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 26.82
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 26.07
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 23.63
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 23.18
#       Time taken: 3.60 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.262750 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:46.346070   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 27.32
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 26.89
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 26.13
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 23.67
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 23.22
#       Time taken: 3.58 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.203709 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:51.145323   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 27.49
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 26.97
# Starting filter: jwst,F200W   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 26.20
# Starting filter: jwst,F356W   Elapsed time: 2.17 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 23.71
# Starting filter: jwst,F405N   Elapsed time: 2.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 23.26
#       Time taken: 3.72 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.292296 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:35:56.173394   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 27.62
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 27.02
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 26.25
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 23.73
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 23.29
#       Time taken: 3.61 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.294158 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:01.101693   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 27.85
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 27.14
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 26.36
# Starting filter: jwst,F356W   Elapsed time: 2.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F356W = 23.77
# Starting filter: jwst,F405N   Elapsed time: 2.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F405N = 23.32
#       Time taken: 3.66 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.255711 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:06.038815   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 28.16
# Starting filter: jwst,F182M   Elapsed time: 0.75 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 27.31
# Starting filter: jwst,F200W   Elapsed time: 1.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 26.51
# Starting filter: jwst,F356W   Elapsed time: 2.15 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F356W = 23.82
# Starting filter: jwst,F405N   Elapsed time: 2.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F405N = 23.36
#       Time taken: 3.65 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.262487 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:10.966679   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 28.32
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 27.41
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 26.61
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F356W = 23.86
# Starting filter: jwst,F405N   Elapsed time: 3.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F405N = 23.38
#       Time taken: 5.05 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 2.205636 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:18.255385   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 28.56
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 27.58
# Starting filter: jwst,F200W   Elapsed time: 2.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 26.78
# Starting filter: jwst,F356W   Elapsed time: 4.34 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F356W = 23.98
# Starting filter: jwst,F405N   Elapsed time: 5.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F405N = 23.49
#       Time taken: 7.43 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 2.209644 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:27.928841   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 28.72
# Starting filter: jwst,F182M   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 27.69
# Starting filter: jwst,F200W   Elapsed time: 2.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 26.92
# Starting filter: jwst,F356W   Elapsed time: 4.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F356W = 24.13
# Starting filter: jwst,F405N   Elapsed time: 5.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F405N = 23.63
#       Time taken: 7.40 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 2.181937 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 2.00  dist = 4500
#      Starting at:  2024-10-29 03:36:37.551143   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 28.76
# Starting filter: jwst,F182M   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 27.77
# Starting filter: jwst,F200W   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 27.00
# Starting filter: jwst,F356W   Elapsed time: 4.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F356W = 24.22
# Starting filter: jwst,F405N   Elapsed time: 5.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F405N = 23.70
#       Time taken: 7.39 seconds
# Isochrone generation took 2.440463 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:36:48.517479   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 29.05
# Starting filter: jwst,F182M   Elapsed time: 1.50 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 27.66
# Starting filter: jwst,F200W   Elapsed time: 2.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 26.57
# Starting filter: jwst,F356W   Elapsed time: 4.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 23.34
# Starting filter: jwst,F405N   Elapsed time: 6.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 22.84
#       Time taken: 7.57 seconds
# Isochrone generation took 2.529991 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:36:58.657287   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 29.41
# Starting filter: jwst,F182M   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 28.05
# Starting filter: jwst,F200W   Elapsed time: 2.95 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 26.93
# Starting filter: jwst,F356W   Elapsed time: 4.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 23.66
# Starting filter: jwst,F405N   Elapsed time: 5.95 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 23.16
#       Time taken: 6.85 seconds
# Isochrone generation took 1.313275 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:06.845144   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 29.66
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 28.34
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 27.19
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 23.90
# Starting filter: jwst,F405N   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 23.39
#       Time taken: 3.63 seconds
# Isochrone generation took 1.301898 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:11.792912   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 29.87
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 28.57
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 27.41
# Starting filter: jwst,F356W   Elapsed time: 2.11 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 24.08
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 23.56
#       Time taken: 3.61 seconds
# Isochrone generation took 1.312525 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:16.736195   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 30.03
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 28.75
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 27.57
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 24.22
# Starting filter: jwst,F405N   Elapsed time: 2.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 23.70
#       Time taken: 3.61 seconds
# Isochrone generation took 1.220320 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:21.588034   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 30.21
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 28.97
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 27.76
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 24.38
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 23.85
#       Time taken: 3.58 seconds
# Isochrone generation took 1.299248 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:26.482257   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 30.36
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 29.11
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 27.88
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 24.47
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 23.94
#       Time taken: 3.63 seconds
# Isochrone generation took 1.302313 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:31.429113   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 30.49
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 29.23
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 28.00
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 24.56
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 24.03
#       Time taken: 3.56 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.303140 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:36.315979   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 30.57
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 29.36
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 28.10
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 24.59
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 24.08
#       Time taken: 3.58 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.309227 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:41.222561   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 30.71
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 29.53
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 28.25
# Starting filter: jwst,F356W   Elapsed time: 2.07 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 24.70
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 24.18
#       Time taken: 3.57 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.306175 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:46.118560   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 30.83
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 29.60
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 28.31
# Starting filter: jwst,F356W   Elapsed time: 2.11 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 24.74
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 24.22
#       Time taken: 3.74 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.302309 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:51.182114   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 30.99
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 29.67
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 28.38
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 24.78
# Starting filter: jwst,F405N   Elapsed time: 2.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 24.26
#       Time taken: 3.55 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.295864 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:37:56.048671   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 31.12
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 29.72
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 28.43
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 24.81
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 24.29
#       Time taken: 3.59 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.254013 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 4.00  dist = 4500
#      Starting at:  2024-10-29 03:38:00.911772   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 31.36
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# ...
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F356W = 27.17
# Starting filter: jwst,F405N   Elapsed time: 2.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F405N = 26.49
#       Time taken: 3.60 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.244776 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 03:43:02.716238   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 39.14
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 35.61
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 33.31
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F356W = 27.32
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F405N = 26.63
#       Time taken: 3.59 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.229135 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 8.00  dist = 4500
#      Starting at:  2024-10-29 03:43:07.553486   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 39.18
# Starting filter: jwst,F182M   Elapsed time: 0.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 35.69
# Starting filter: jwst,F200W   Elapsed time: 1.54 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 33.38
# Starting filter: jwst,F356W   Elapsed time: 2.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F356W = 27.41
# Starting filter: jwst,F405N   Elapsed time: 2.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F405N = 26.70
#       Time taken: 3.74 seconds
# Isochrone generation took 1.359517 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:13.386956   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 39.34
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 35.51
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 32.81
# Starting filter: jwst,F356W   Elapsed time: 2.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 26.51
# Starting filter: jwst,F405N   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 25.84
#       Time taken: 3.65 seconds
# Isochrone generation took 1.307762 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:18.361106   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 39.69
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 35.90
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 33.16
# Starting filter: jwst,F356W   Elapsed time: 2.09 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 26.83
# Starting filter: jwst,F405N   Elapsed time: 2.82 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 26.16
#       Time taken: 3.58 seconds
# Isochrone generation took 1.300196 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:23.257737   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 39.94
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 36.20
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 33.42
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 27.07
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 26.39
#       Time taken: 3.56 seconds
# Isochrone generation took 1.299907 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:28.138319   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 40.15
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 36.43
# Starting filter: jwst,F200W   Elapsed time: 1.39 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 33.62
# Starting filter: jwst,F356W   Elapsed time: 2.08 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 27.25
# Starting filter: jwst,F405N   Elapsed time: 2.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 26.57
#       Time taken: 3.57 seconds
# Isochrone generation took 1.297673 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:33.022970   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 40.30
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 36.61
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 33.78
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 27.39
# Starting filter: jwst,F405N   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 26.70
#       Time taken: 3.62 seconds
# Isochrone generation took 1.300790 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:37.965365   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 40.48
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 36.83
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 33.96
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 27.54
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 26.85
#       Time taken: 3.59 seconds
# Isochrone generation took 1.305225 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:42.884183   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 40.63
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 36.97
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 34.08
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 27.63
# Starting filter: jwst,F405N   Elapsed time: 2.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 26.94
#       Time taken: 3.60 seconds
# Isochrone generation took 1.226383 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:47.732541   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 40.76
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 37.09
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 34.19
# Starting filter: jwst,F356W   Elapsed time: 2.11 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 27.72
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 27.03
#       Time taken: 3.62 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.234901 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:52.609558   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 40.86
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 37.21
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 34.30
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 27.75
# Starting filter: jwst,F405N   Elapsed time: 2.84 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 27.08
#       Time taken: 3.60 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.298731 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:43:57.526940   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 41.01
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 37.38
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 34.45
# Starting filter: jwst,F356W   Elapsed time: 2.10 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 27.86
# Starting filter: jwst,F405N   Elapsed time: 2.83 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 27.19
#       Time taken: 3.61 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.297346 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:44:02.449422   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 41.12
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 37.44
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 34.51
# Starting filter: jwst,F356W   Elapsed time: 2.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 27.90
# Starting filter: jwst,F405N   Elapsed time: 2.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 27.23
#       Time taken: 3.65 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.206084 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:44:07.319604   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 41.28
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 37.51
# Starting filter: jwst,F200W   Elapsed time: 1.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 34.58
# Starting filter: jwst,F356W   Elapsed time: 2.12 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 27.94
# Starting filter: jwst,F405N   Elapsed time: 2.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 27.27
#       Time taken: 3.63 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.215047 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:44:12.185012   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 41.41
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 37.55
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 34.64
# Starting filter: jwst,F356W   Elapsed time: 2.13 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 27.97
# Starting filter: jwst,F405N   Elapsed time: 2.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 27.29
#       Time taken: 3.67 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.289899 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:44:17.160487   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 41.64
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 37.65
# Starting filter: jwst,F200W   Elapsed time: 1.44 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 34.75
# Starting filter: jwst,F356W   Elapsed time: 2.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F356W = 28.01
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F405N = 27.33
#       Time taken: 3.65 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.377624 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 10.00  dist = 4500
#      Starting at:  2024-10-29 03:44:22.202732   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 41.95
# Starting filter: jwst,F182M   Elapsed time: 0.76 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 37.81
# Starting filter: jwst,F200W   Elapsed time: 1.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 34.90
# Starting filter: jwst,F356W   Elapsed time: 3.18 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F356W = 28.06
