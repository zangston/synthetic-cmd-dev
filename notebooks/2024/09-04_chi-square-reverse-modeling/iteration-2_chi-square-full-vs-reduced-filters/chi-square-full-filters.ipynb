# %%
# import packages
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
import math

# import spisea packages
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity

# colormap stuff for plot generation
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %% [markdown]
# # Isochrone parameters

# %%
# define isochrone parameters
AKs = 0
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W', 'jwst,F356W', 'jwst,F405N']
filters = ['m_jwst_F162M', 'm_jwst_F182M', 'm_jwst_F200W', 'm_jwst_F356W', 'm_jwst_F405N']
iso_dir = 'isochrones/'
metallicity = 0

# %%
# define log age array for isochrone grid
level_ages = np.linspace(1, 10, 19)
level_ages = np.multiply(level_ages, 1e6)
print(level_ages)
log_age_arr = np.log10(level_ages)
print(log_age_arr)
# Out:
# [ 1000000.  1500000.  2000000.  2500000.  3000000.  3500000.  4000000.
#   4500000.  5000000.  5500000.  6000000.  6500000.  7000000.  7500000.
#   8000000.  8500000.  9000000.  9500000. 10000000.]
# [6.         6.17609126 6.30103    6.39794001 6.47712125 6.54406804
#  6.60205999 6.65321251 6.69897    6.74036269 6.77815125 6.81291336
#  6.84509804 6.87506126 6.90308999 6.92941893 6.95424251 6.97772361
#  7.        ]

# %% [markdown]
# # Generate isochrone grid

# %%
instances = np.empty(len(log_age_arr), dtype=object)

for i in range(len(log_age_arr)):
    my_iso = synthetic.IsochronePhot(log_age_arr[i], AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
    instances[i] = my_iso
        
print("isochrone generation done")
# Out:
# Isochrone generation took 1.143843 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:27.623986   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
# Starting filter: jwst,F200W   Elapsed time: 1.24 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.04
# Starting filter: jwst,F356W   Elapsed time: 1.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 21.17
# Starting filter: jwst,F405N   Elapsed time: 2.56 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 20.84
#       Time taken: 3.21 seconds
# Isochrone generation took 1.024896 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:31.877397   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
# Starting filter: jwst,F200W   Elapsed time: 1.29 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 22.41
# Starting filter: jwst,F356W   Elapsed time: 1.93 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 21.50
# Starting filter: jwst,F405N   Elapsed time: 2.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 21.16
#       Time taken: 3.30 seconds
# Isochrone generation took 1.110757 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:36.310888   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 22.69
# Starting filter: jwst,F356W   Elapsed time: 1.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 21.74
# Starting filter: jwst,F405N   Elapsed time: 2.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 21.39
#       Time taken: 3.28 seconds
# Isochrone generation took 1.093323 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:40.703186   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
# Starting filter: jwst,F200W   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 22.91
# Starting filter: jwst,F356W   Elapsed time: 1.94 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 21.92
# Starting filter: jwst,F405N   Elapsed time: 2.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 21.56
#       Time taken: 3.32 seconds
# Isochrone generation took 1.113658 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:45.160334   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 23.08
# Starting filter: jwst,F356W   Elapsed time: 1.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 22.06
# Starting filter: jwst,F405N   Elapsed time: 2.57 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 21.70
#       Time taken: 3.26 seconds
# Isochrone generation took 1.105617 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:49.545766   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 23.28
# Starting filter: jwst,F356W   Elapsed time: 1.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 22.21
# Starting filter: jwst,F405N   Elapsed time: 2.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 21.85
#       Time taken: 3.29 seconds
# Isochrone generation took 1.101626 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:53.950060   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
# Starting filter: jwst,F200W   Elapsed time: 1.29 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 23.41
# Starting filter: jwst,F356W   Elapsed time: 1.94 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 22.31
# Starting filter: jwst,F405N   Elapsed time: 2.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 21.94
#       Time taken: 3.31 seconds
# Isochrone generation took 1.181599 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:35:58.463294   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
# Starting filter: jwst,F200W   Elapsed time: 1.30 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 23.53
# Starting filter: jwst,F356W   Elapsed time: 1.95 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 22.39
# Starting filter: jwst,F405N   Elapsed time: 2.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 22.02
#       Time taken: 3.30 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.105672 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:02.890773   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 23.64
# Starting filter: jwst,F356W   Elapsed time: 1.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 22.43
# Starting filter: jwst,F405N   Elapsed time: 2.57 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 22.08
#       Time taken: 3.26 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.108295 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:07.276935   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 23.79
# Starting filter: jwst,F356W   Elapsed time: 1.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 22.54
# Starting filter: jwst,F405N   Elapsed time: 2.56 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 22.18
#       Time taken: 3.24 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.106629 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:11.645693   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
# Starting filter: jwst,F200W   Elapsed time: 1.26 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 23.85
# Starting filter: jwst,F356W   Elapsed time: 1.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 22.58
# Starting filter: jwst,F405N   Elapsed time: 2.55 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 22.22
#       Time taken: 3.23 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.108129 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:16.003941   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 23.93
# Starting filter: jwst,F356W   Elapsed time: 1.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 22.62
# Starting filter: jwst,F405N   Elapsed time: 2.58 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 22.26
#       Time taken: 3.27 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.100038 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:20.387829   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 23.98
# Starting filter: jwst,F356W   Elapsed time: 1.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 22.64
# Starting filter: jwst,F405N   Elapsed time: 2.58 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 22.29
#       Time taken: 3.27 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.102471 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:24.779743   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 24.08
# Starting filter: jwst,F356W   Elapsed time: 1.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F356W = 22.68
# Starting filter: jwst,F405N   Elapsed time: 2.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F405N = 22.32
#       Time taken: 3.29 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.064379 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:29.148297   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 24.24
# Starting filter: jwst,F356W   Elapsed time: 1.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F356W = 22.74
# Starting filter: jwst,F405N   Elapsed time: 2.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F405N = 22.36
#       Time taken: 3.32 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.056110 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:33.546759   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 1.22 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 24.34
# Starting filter: jwst,F356W   Elapsed time: 1.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F356W = 22.77
# Starting filter: jwst,F405N   Elapsed time: 2.50 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F405N = 22.38
#       Time taken: 3.20 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.057595 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:37.819590   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.63 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
# Starting filter: jwst,F200W   Elapsed time: 1.27 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 24.51
# Starting filter: jwst,F356W   Elapsed time: 1.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F356W = 22.90
# Starting filter: jwst,F405N   Elapsed time: 2.56 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F405N = 22.49
#       Time taken: 3.24 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.022872 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:42.101990   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 0.62 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
# Starting filter: jwst,F200W   Elapsed time: 1.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 24.64
# Starting filter: jwst,F356W   Elapsed time: 1.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F356W = 23.04
# Starting filter: jwst,F405N   Elapsed time: 2.53 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F405N = 22.62
#       Time taken: 3.22 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.146410 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-27 23:36:46.481473   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 0.64 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
# Starting filter: jwst,F200W   Elapsed time: 1.28 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 24.71
# Starting filter: jwst,F356W   Elapsed time: 1.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F356W = 23.13
# Starting filter: jwst,F405N   Elapsed time: 2.59 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F405N = 22.69
#       Time taken: 3.28 seconds
# isochrone generation done

# %% [markdown]
# # Function for calculating chi-square value based on photometric magnitudes

# %%
def chi_square_reverse_model(iso_grid, sample_mags):
    results = []
    
    for i in range(len(iso_grid)):
        for j in range(len(iso_grid[i].points)):
            arr = []
            chi_square = 0
            for k in range(len(sample_mags)):
                mag_obs = sample_mags[k]
                mag_exp = iso_grid[i].points[j][filters[k]]
                chi_square = chi_square + (((mag_obs - mag_exp) ** 2) / mag_exp)

            arr.append(chi_square)
            arr.append(iso_grid[i].points[j]['mass'])
            arr.append(10 ** log_age_arr[i])
            
            results.append(arr)
    
    sorted_results = sorted(results, key=sort_by_chi_square)
    
    report(sorted_results[:10])
    
def sort_by_chi_square(sub_list):
    return sub_list[0]

def report(output_arr):
    for i in range(len(output_arr)):
        print("Chi-square: " + str(output_arr[i][0]))
        print("Mass (Msun): " + str(output_arr[i][1]))
        print("Age (Myr): " + str(output_arr[i][2]))
        print()

# %% [markdown]
# # Define S284 sample magnitudes and run function

# %%
sample_mags = []

import csv
with open('../s284-no-errors.csv', mode ='r')as file:
  csvFile = csv.reader(file)
  for lines in csvFile:
        sample_mags.append(lines)

sample_mags.pop(0)
# Out:
# ['\ufeffF162M', 'F182M', 'F200W', 'F356W', 'F405N']

# %%
# convert value array to numbers
for i in range(len(sample_mags)):
    for j in range(len(sample_mags[i])):
        sample_mags[i][j] = float(sample_mags[i][j])
print(sample_mags)
# Out:
# [[18.0957, 17.8409, 17.6518, 16.3455, 9.834], [23.4467, 22.4409, 21.9598, 20.1415, 13.552], [17.7037, 17.4619, 17.4048, 17.0675, 10.811], [16.6887, 16.5989, 16.2548, 15.8125, 9.426], [17.7007, 17.4209, 17.2758, 16.0555, 9.797], [19.4097, 19.0389, 18.7708, 18.0965, 11.888], [20.7147, 20.1869, 19.9608, 18.9855, 12.766], [19.4917, 19.2589, 19.1038, 18.5365, 12.19]]

# %%
for i in range(len(sample_mags)):
    chi_square_reverse_model(instances, sample_mags[i])
    print("==========================================")
# Out:
# Chi-square: 2.786301092104013
# Mass (Msun): 0.3
# Age (Myr): 1000000.0
#
# Chi-square: 2.8166535342084797
# Mass (Msun): 0.2
# Age (Myr): 1000000.0
#
# Chi-square: 2.838161709104631
# Mass (Msun): 0.4
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.83989340697708
# Mass (Msun): 0.4
# Age (Myr): 1000000.0
#
# Chi-square: 2.8422603883694775
# Mass (Msun): 0.17
# Age (Myr): 1000000.0
#
# Chi-square: 2.864720672860426
# Mass (Msun): 0.3
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.8654795250136367
# Mass (Msun): 0.5
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.8681580299135625
# Mass (Msun): 0.5
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.878639637050748
# Mass (Msun): 0.4
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.8835649340064418
# Mass (Msun): 0.5
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 2.48601115940943
# Mass (Msun): 0.02
# Age (Myr): 1000000.0
#
# Chi-square: 2.5150350259297327
# Mass (Msun): 0.015
# Age (Myr): 1000000.0
#
# Chi-square: 2.5199818314480305
# Mass (Msun): 0.02
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.5225195111134107
# Mass (Msun): 0.03
# Age (Myr): 4000000.000000001
#
# Chi-square: 2.5225636944951497
# Mass (Msun): 0.03
# Age (Myr): 3500000.0000000005
#
# Chi-square: 2.5226293167084677
# Mass (Msun): 0.03
# Age (Myr): 4500000.000000003
#
# Chi-square: 2.522922468199107
# Mass (Msun): 0.03
# Age (Myr): 4999999.999999999
#
# Chi-square: 2.523153729393881
# Mass (Msun): 0.03
# Age (Myr): 3000000.000000001
#
# Chi-square: 2.52326691012559
# Mass (Msun): 0.03
# Age (Myr): 5500000.000000004
#
# Chi-square: 2.5236419469934104
# Mass (Msun): 0.03
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 1.9748989172311127
# Mass (Msun): 0.3
# Age (Myr): 1000000.0
#
# Chi-square: 2.0051511317458823
# Mass (Msun): 0.2
# Age (Myr): 1000000.0
#
# Chi-square: 2.017214994571899
# Mass (Msun): 0.4
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.0278505349190166
# Mass (Msun): 0.4
# Age (Myr): 1000000.0
#
# Chi-square: 2.0327214159771905
# Mass (Msun): 0.17
# Age (Myr): 1000000.0
#
# Chi-square: 2.0398545693483525
# Mass (Msun): 0.5
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.042971715405205
# Mass (Msun): 0.3
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.0484571619291634
# Mass (Msun): 0.5
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.051783322449565
# Mass (Msun): 0.4
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.05406791734511
# Mass (Msun): 0.5
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 2.491898381103111
# Mass (Msun): 0.8
# Age (Myr): 1000000.0
#
# Chi-square: 2.4930641287965205
# Mass (Msun): 0.9
# Age (Myr): 1000000.0
#
# Chi-square: 2.4986545205957347
# Mass (Msun): 1.1
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.5011583274314013
# Mass (Msun): 1.0
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.5030847170936146
# Mass (Msun): 0.7
# Age (Myr): 1000000.0
#
# Chi-square: 2.503339463530415
# Mass (Msun): 1.3
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.5035577221869927
# Mass (Msun): 1.2
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.5045955826219646
# Mass (Msun): 1.0
# Age (Myr): 1000000.0
#
# Chi-square: 2.5062620655954837
# Mass (Msun): 1.2
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.507033965941714
# Mass (Msun): 1.4
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 2.6474817545201215
# Mass (Msun): 0.4
# Age (Myr): 1000000.0
#
# Chi-square: 2.6630644025502814
# Mass (Msun): 0.3
# Age (Myr): 1000000.0
#
# Chi-square: 2.6782812698905767
# Mass (Msun): 0.5
# Age (Myr): 1000000.0
#
# Chi-square: 2.684965389557572
# Mass (Msun): 0.5
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.694376476807591
# Mass (Msun): 0.6
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.7079191871729047
# Mass (Msun): 0.6
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.708642930486945
# Mass (Msun): 0.7
# Age (Myr): 2000000.0000000002
#
# Chi-square: 2.712651037995561
# Mass (Msun): 0.4
# Age (Myr): 1500000.0000000005
#
# Chi-square: 2.7188202627096896
# Mass (Msun): 0.7
# Age (Myr): 2499999.9999999995
#
# Chi-square: 2.7200858776607055
# Mass (Msun): 0.8
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 1.8993198617064924
# Mass (Msun): 0.13
# Age (Myr): 1000000.0
#
# Chi-square: 1.8993924289030193
# Mass (Msun): 0.11
# Age (Myr): 1000000.0
#
# Chi-square: 1.9039190835848905
# Mass (Msun): 0.13
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.9148953871500487
# Mass (Msun): 0.15
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.9210684082641785
# Mass (Msun): 0.11
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.9301991029876404
# Mass (Msun): 0.1
# Age (Myr): 1000000.0
#
# Chi-square: 1.9309402811129805
# Mass (Msun): 0.17
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.9419534808276377
# Mass (Msun): 0.15
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.949576828932892
# Mass (Msun): 0.2
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.9514192449165633
# Mass (Msun): 0.17
# Age (Myr): 1500000.0000000005
#
# ==========================================
# Chi-square: 1.9022788957681787
# Mass (Msun): 0.07
# Age (Myr): 1000000.0
#
# Chi-square: 1.903529539766418
# Mass (Msun): 0.07
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.9036175768804788
# Mass (Msun): 0.072
# Age (Myr): 1000000.0
#
# Chi-square: 1.9047931560964533
# Mass (Msun): 0.072
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.9054979601492226
# Mass (Msun): 0.07
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.9057122302305953
# Mass (Msun): 0.072
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.90817496146967
# Mass (Msun): 0.072
# Age (Myr): 2499999.9999999995
#
# Chi-square: 1.9087041207579327
# Mass (Msun): 0.075
# Age (Myr): 1000000.0
#
# Chi-square: 1.9088412091683016
# Mass (Msun): 0.075
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.9089646239312976
# Mass (Msun): 0.075
# Age (Myr): 2499999.9999999995
#
# ==========================================
# Chi-square: 1.8130345532439514
# Mass (Msun): 0.11
# Age (Myr): 1000000.0
#
# Chi-square: 1.816789743000725
# Mass (Msun): 0.1
# Age (Myr): 1000000.0
#
# Chi-square: 1.8205804031131898
# Mass (Msun): 0.11
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.8267119613170486
# Mass (Msun): 0.09
# Age (Myr): 1000000.0
#
# Chi-square: 1.830970461904842
# Mass (Msun): 0.1
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.8388680114361708
# Mass (Msun): 0.09
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.8397229216123643
# Mass (Msun): 0.13
# Age (Myr): 1500000.0000000005
#
# Chi-square: 1.8439508987689255
# Mass (Msun): 0.13
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.8459426681667652
# Mass (Msun): 0.15
# Age (Myr): 2000000.0000000002
#
# Chi-square: 1.8520566584994673
# Mass (Msun): 0.11
# Age (Myr): 2000000.0000000002
#
# ==========================================

# %%
# Plot of estimated points from first trial run for first star
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[0]] - instances[i].points[filters[1]], 
        instances[i].points[filters[1]], color=color, label='')

py.xlabel('F162M - F182M')
py.ylabel('F182M')
py.gca().invert_yaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.plot(sample_mags[0][0] - sample_mags[0][1], sample_mags[0][1], '*')

# 1ST ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.3) == min(abs(instances[0].points['mass'] - 0.3)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'] - instances[0].points[idx[0]]['m_jwst_F182M'], 
        instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 2ND ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.2) == min(abs(instances[0].points['mass'] - 0.2)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'] - instances[0].points[idx[0]]['m_jwst_F182M'], 
        instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 3RD ESTIMATE
idx = np.where( abs(instances[1].points['mass'] - 0.4) == min(abs(instances[1].points['mass'] - 0.4)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'] - instances[1].points[idx[0]]['m_jwst_F182M'], 
        instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 4TH ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.4) == min(abs(instances[0].points['mass'] - 0.4)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'] - instances[0].points[idx[0]]['m_jwst_F182M'], 
        instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 5TH ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.17) == min(abs(instances[0].points['mass'] - 0.17)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'] - instances[0].points[idx[0]]['m_jwst_F182M'], 
        instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 6TH ESTIMATE
idx = np.where( abs(instances[1].points['mass'] - 0.3) == min(abs(instances[1].points['mass'] - 0.3)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'] - instances[1].points[idx[0]]['m_jwst_F182M'], 
        instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 7TH ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.5) == min(abs(instances[0].points['mass'] - 0.5)) )[0]
py.plot(instances[2].points[idx[0]]['m_jwst_F162M'] - instances[2].points[idx[0]]['m_jwst_F182M'], 
        instances[2].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 8TH ESTIMATE
idx = np.where( abs(instances[0].points['mass'] - 0.5) == min(abs(instances[0].points['mass'] - 0.5)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'] - instances[1].points[idx[0]]['m_jwst_F182M'], 
        instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 9TH ESTIMATE
idx = np.where( abs(instances[2].points['mass'] - 0.4) == min(abs(instances[2].points['mass'] - 0.4)) )[0]
py.plot(instances[2].points[idx[0]]['m_jwst_F162M'] - instances[2].points[idx[0]]['m_jwst_F182M'], 
        instances[2].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
# 10TH ESTIMATE
idx = np.where( abs(instances[3].points['mass'] - 0.5) == min(abs(instances[3].points['mass'] - 0.5)) )[0]
py.plot(instances[3].points[idx[0]]['m_jwst_F162M'] - instances[3].points[idx[0]]['m_jwst_F182M'], 
        instances[3].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

# %%
# Plot of estimated points from first trial run for first star
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[0]], instances[i].points[filters[1]], color=color, label='')

py.xlabel('F162M')
py.ylabel('F182M')
py.gca().invert_yaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.plot(sample_mags[0][0], sample_mags[0][1], '*')


idx = np.where( abs(instances[0].points['mass'] - 0.3) == min(abs(instances[0].points['mass'] - 0.3)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'], instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[0].points['mass'] - 0.2) == min(abs(instances[0].points['mass'] - 0.2)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'], instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[1].points['mass'] - 0.4) == min(abs(instances[1].points['mass'] - 0.4)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'], instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[0].points['mass'] - 0.4) == min(abs(instances[0].points['mass'] - 0.4)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'], instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[0].points['mass'] - 0.17) == min(abs(instances[0].points['mass'] - 0.17)) )[0]
py.plot(instances[0].points[idx[0]]['m_jwst_F162M'], instances[0].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[1].points['mass'] - 0.3) == min(abs(instances[1].points['mass'] - 0.3)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'], instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[0].points['mass'] - 0.5) == min(abs(instances[0].points['mass'] - 0.5)) )[0]
py.plot(instances[2].points[idx[0]]['m_jwst_F162M'], instances[2].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[0].points['mass'] - 0.5) == min(abs(instances[0].points['mass'] - 0.5)) )[0]
py.plot(instances[1].points[idx[0]]['m_jwst_F162M'], instances[1].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[2].points['mass'] - 0.4) == min(abs(instances[2].points['mass'] - 0.4)) )[0]
py.plot(instances[2].points[idx[0]]['m_jwst_F162M'], instances[2].points[idx[0]]['m_jwst_F182M'], 'o', color='red')

idx = np.where( abs(instances[3].points['mass'] - 0.5) == min(abs(instances[3].points['mass'] - 0.5)) )[0]
py.plot(instances[3].points[idx[0]]['m_jwst_F162M'], instances[3].points[idx[0]]['m_jwst_F182M'], 'o', color='red')
