# %%
# Import necessary packages
import os
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import csv

# Paths for isochrones and output
iso_dir = 'isochrones/'
output_dir = 'output_diagrams/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Estimation variables
star_index = 3      # Set which star in the CSV to analyze
num_top_predictions = 10  # Control how many top predictions to plot

# AKs values from 0 to 1 in increments of 0.1
extinction_values = np.arange(0, 1, 0.1)

# Define static isochrone parameters
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M']
filters = ['m_jwst_F162M', 'm_jwst_F182M']
metallicity = 0
level_ages = np.linspace(1, 10, 19) * 1e6  # Define age array
log_age_arr = np.log10(level_ages)

# Load sample magnitudes, skipping the header row
sample_mags = []
with open('../../../../s284-162-182.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header row
    for lines in csvFile:
        sample_mags.append([float(x) for x in lines])

# Chi-square minimization function
def chi_square_reverse_model(iso_grid, sample_mags):
    results = []
    for i, iso in enumerate(iso_grid):
        for star in iso.points:
            chi_square = sum(((sample_mags[k] - star[filters[k]]) ** 2) / star[filters[k]] for k in range(len(sample_mags)))
            results.append([chi_square, star['mass'], 10 ** log_age_arr[i]])
    
    return sorted(results, key=lambda x: x[0])

# Ensure both isochrone and output directories exist before the loop
os.makedirs(iso_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)


# Loop through each extinction value, delete old isochrones, and generate diagrams
for AKs in extinction_values:
    # Clear previous isochrones
    for file in os.listdir(iso_dir):
        os.remove(os.path.join(iso_dir, file))
    
    # Generate isochrone grid
    instances = np.array([
        synthetic.IsochronePhot(log_age, AKs, dist, metallicity=metallicity,
                                evo_model=evo_model, atm_func=atm_func,
                                red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
        for log_age in log_age_arr
    ])

    # Run chi-square minimization and get top results
    sorted_results = chi_square_reverse_model(instances, sample_mags[star_index])
    top_results = sorted_results[:num_top_predictions]

    # Create figure with two subplots side-by-side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    cmap = plt.get_cmap('coolwarm')

    # Color-magnitude diagram (CMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax1.plot(instance.points[filters[0]] - instance.points[filters[1]], 
                 instance.points[filters[1]], color=color)
    ax1.set_xlabel('F162M - F182M')
    ax1.set_ylabel('F182M')
    ax1.invert_yaxis()
    ax1.grid(True)  # Add grid lines to CMD

    # Magnitude-magnitude diagram (MMD)
    for i, instance in enumerate(instances):
        color = cmap(i / (len(instances) - 1))
        ax2.plot(instance.points[filters[0]], instance.points[filters[1]], color=color)
    ax2.set_xlabel('F162M')
    ax2.set_ylabel('F182M')
    ax2.invert_xaxis()
    ax2.invert_yaxis()
    ax2.grid(True)  # Add grid lines to MMD

    # Create colorbar for both diagrams
    norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
    sm = ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=[ax1, ax2])
    cbar.set_label('Age (millions of years)')
    cbar.set_ticks(level_ages)
    cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

    # Plot top results on CMD with color gradient and labels
    for j, (chi_square, mass, age) in enumerate(top_results):
        closest_age_idx = np.argmin(abs(level_ages - age))
        iso_instance = instances[closest_age_idx]
        mass_idx = np.argmin(abs(iso_instance.points['mass'] - mass))
        color = cmap(j / (num_top_predictions - 1))
        ax1.plot(iso_instance.points[mass_idx][filters[0]] - iso_instance.points[mass_idx][filters[1]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")
        ax2.plot(iso_instance.points[mass_idx][filters[0]],
                 iso_instance.points[mass_idx][filters[1]], 'o', color=color, label=f"Mass: {mass:.2f}, Age: {age/1e6:.1f} Myr")

    # Plot reference star in both diagrams
    ref_star_color = 'gold'  # Optional: distinguish reference star color
    ref_star_marker = '*'  # Optional: distinguish reference star marker

    ax1.plot(sample_mags[star_index][0] - sample_mags[star_index][1], sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

    ax2.plot(sample_mags[star_index][0], 
         sample_mags[star_index][1], 
         ref_star_marker, markersize=10, color=ref_star_color, label="Reference Star")

    # Legends and saving
    ax1.legend()
    ax2.legend()
    fig.suptitle(f"AKs = {AKs}")
    plt.savefig(os.path.join(output_dir, f'CMD_MMD_AKs_{AKs}.png'))
    plt.close()
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# Isochrone generation took 1.358878 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:27.262492   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
#       Time taken: 1.35 seconds
# Isochrone generation took 1.207377 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:29.845119   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
#       Time taken: 1.35 seconds
# Isochrone generation took 1.246722 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:32.461973   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
#       Time taken: 1.35 seconds
# Isochrone generation took 1.264727 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:35.104029   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
#       Time taken: 1.36 seconds
# Isochrone generation took 1.235515 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:37.716187   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
#       Time taken: 1.36 seconds
# Isochrone generation took 1.243147 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:40.332734   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
#       Time taken: 1.34 seconds
# Isochrone generation took 1.257339 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:42.949942   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
#       Time taken: 1.35 seconds
# Isochrone generation took 1.331129 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:45.644700   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.264032 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:48.289265   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
#       Time taken: 1.36 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.222777 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:50.888505   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.252290 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:53.529860   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.236083 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:56.117507   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
#       Time taken: 1.42 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.271037 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:29:58.820785   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
#       Time taken: 1.36 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.242177 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:01.438050   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
#       Time taken: 1.35 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.154300 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:03.962409   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
#       Time taken: 1.35 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.214896 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:06.542919   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.204992 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:09.130853   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.198461 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:11.739627   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
#       Time taken: 1.36 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.204719 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-12-10 04:30:14.320005   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 0.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
#       Time taken: 1.51 seconds
# Isochrone generation took 1.359863 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:18.060162   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.17
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.32
#       Time taken: 1.38 seconds
# Isochrone generation took 1.194639 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:20.653496   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.53
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.70
#       Time taken: 1.38 seconds
# Isochrone generation took 1.199054 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:23.248779   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.79
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.99
#       Time taken: 1.38 seconds
# Isochrone generation took 1.278106 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:25.920806   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.00
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.22
#       Time taken: 1.37 seconds
# Isochrone generation took 1.234358 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:28.547650   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.16
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.40
#       Time taken: 1.38 seconds
# Isochrone generation took 1.223848 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:31.170018   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.35
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.62
#       Time taken: 1.34 seconds
# Isochrone generation took 1.264552 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:33.785802   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.50
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.75
#       Time taken: 1.39 seconds
# Isochrone generation took 1.256089 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:36.445131   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.63
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.88
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.241474 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:39.078548   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.69
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.02
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.322141 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:41.747505   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.83
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.19
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.314196 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:44.463323   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.95
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.26
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.229765 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:47.039218   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.11
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.35
#       Time taken: 1.36 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.262857 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:49.675296   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.24
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.40
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.215932 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:52.233514   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.47
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.53
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.177938 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:54.765136   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.78
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.70
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.174500 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:57.285237   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.94
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.81
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.153200 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:30:59.790183   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.18
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.98
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.114073 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:31:02.251631   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.33
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.09
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.234048 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.10  dist = 4500
#      Starting at:  2024-12-10 04:31:04.831141   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.37
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.17
#       Time taken: 1.36 seconds
# Isochrone generation took 1.323868 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:08.394784   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.35
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.46
#       Time taken: 1.44 seconds
# Isochrone generation took 1.271580 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:11.123670   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.71
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.84
#       Time taken: 1.40 seconds
# Isochrone generation took 1.427785 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:13.968796   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.97
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.13
#       Time taken: 1.39 seconds
# Isochrone generation took 1.312473 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:16.685273   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.18
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.36
#       Time taken: 1.39 seconds
# Isochrone generation took 1.278670 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:19.368833   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.34
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.54
#       Time taken: 1.38 seconds
# Isochrone generation took 1.303072 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:22.068771   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.52
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.76
#       Time taken: 1.42 seconds
# Isochrone generation took 1.303083 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:24.814020   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.67
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.89
#       Time taken: 1.38 seconds
# Isochrone generation took 1.298369 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:27.509321   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.81
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.02
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.297949 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:30.210998   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.86
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.16
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.255458 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:32.874232   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.01
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.33
#       Time taken: 1.41 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.292069 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:35.591355   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.13
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.40
#       Time taken: 1.36 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.291235 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:38.263211   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.49
#       Time taken: 1.38 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.295783 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:40.955022   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.42
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.54
#       Time taken: 1.44 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.252574 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:43.667448   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.65
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.67
#       Time taken: 1.38 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.237405 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:46.302653   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.96
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.84
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.173272 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:48.834196   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.12
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.95
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.199445 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:51.389477   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.36
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.11
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.291476 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:54.067202   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.51
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.23
#       Time taken: 1.33 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.205157 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.20  dist = 4500
#      Starting at:  2024-12-10 04:31:56.620092   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.55
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.31
#       Time taken: 1.34 seconds
# Isochrone generation took 1.317120 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:00.124200   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.53
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.60
#       Time taken: 1.37 seconds
# Isochrone generation took 1.222376 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:02.740611   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.89
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.98
#       Time taken: 1.39 seconds
# Isochrone generation took 1.256457 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:05.402887   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.15
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.27
#       Time taken: 1.35 seconds
# Isochrone generation took 1.253113 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:08.019187   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.36
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.50
#       Time taken: 1.38 seconds
# Isochrone generation took 1.254711 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:10.673749   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.52
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.68
#       Time taken: 1.31 seconds
# Isochrone generation took 1.279041 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:13.278210   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.70
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.90
#       Time taken: 1.33 seconds
# Isochrone generation took 1.237171 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:15.863609   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.85
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.03
#       Time taken: 1.38 seconds
# Isochrone generation took 1.235855 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:18.497040   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.99
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.16
#       Time taken: 1.28 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.221324 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:21.017530   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.04
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.30
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.232248 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:23.632722   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.19
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.47
#       Time taken: 1.32 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.256392 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:26.227014   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.31
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.54
#       Time taken: 1.34 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.424189 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:29.005475   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.47
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.63
#       Time taken: 1.60 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.262925 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:31.887943   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.68
#       Time taken: 1.73 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.270151 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:34.907586   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.83
# Starting filter: jwst,F182M   Elapsed time: 0.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.81
#       Time taken: 1.73 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.206240 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:37.857580   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.14
# Starting filter: jwst,F182M   Elapsed time: 0.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.98
#       Time taken: 1.73 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.192888 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:40.797642   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.30
# Starting filter: jwst,F182M   Elapsed time: 0.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.08
#       Time taken: 1.75 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.247050 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:43.811967   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.54
# Starting filter: jwst,F182M   Elapsed time: 0.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.25
#       Time taken: 1.72 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.208979 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:46.760757   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.69
# Starting filter: jwst,F182M   Elapsed time: 0.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.37
#       Time taken: 1.76 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.277126 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.30  dist = 4500
#      Starting at:  2024-12-10 04:32:49.812599   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.73
# Starting filter: jwst,F182M   Elapsed time: 0.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.44
#       Time taken: 1.79 seconds
# Isochrone generation took 1.268401 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:32:53.692563   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 22.71
# Starting filter: jwst,F182M   Elapsed time: 0.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.73
#       Time taken: 1.86 seconds
# Isochrone generation took 1.315706 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:32:56.890010   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.07
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.12
#       Time taken: 1.81 seconds
# Isochrone generation took 1.301807 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:00.015228   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.41
#       Time taken: 1.78 seconds
# Isochrone generation took 1.325487 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:03.134891   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 23.54
# Starting filter: jwst,F182M   Elapsed time: 0.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.64
#       Time taken: 1.80 seconds
# Isochrone generation took 1.270655 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:06.217812   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 23.70
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.82
#       Time taken: 1.82 seconds
# Isochrone generation took 1.462473 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:09.512568   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.88
# Starting filter: jwst,F182M   Elapsed time: 0.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.04
#       Time taken: 1.82 seconds
# Isochrone generation took 1.314718 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:12.663693   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.03
# Starting filter: jwst,F182M   Elapsed time: 0.96 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.17
#       Time taken: 1.87 seconds
# Isochrone generation took 1.308294 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:15.858857   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.16
# Starting filter: jwst,F182M   Elapsed time: 0.92 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.30
#       Time taken: 1.82 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.321853 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:19.014557   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.22
# Starting filter: jwst,F182M   Elapsed time: 0.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.44
#       Time taken: 1.87 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.303827 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:22.206456   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.37
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.61
#       Time taken: 1.76 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.294936 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:25.275416   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 24.49
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.68
#       Time taken: 1.77 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.280707 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:28.345143   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 24.65
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.76
#       Time taken: 1.77 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.290325 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:31.423471   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.78
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.82
#       Time taken: 1.79 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.310526 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:34.535933   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.01
# Starting filter: jwst,F182M   Elapsed time: 0.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.94
#       Time taken: 1.80 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.277278 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:37.631209   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.32
# Starting filter: jwst,F182M   Elapsed time: 0.89 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.12
#       Time taken: 1.78 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.250859 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.40  dist = 4500
#      Starting at:  2024-12-10 04:33:40.679036   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 25.48
# Starting filter: jwst,F182M   Elapsed time: 0.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.22
#       Time taken: 1.87 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.236524 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.40  dist = 4500
# ...
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.22
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.78
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.269598 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.60  dist = 4500
#      Starting at:  2024-12-10 04:35:45.094831   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.26
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.86
#       Time taken: 1.39 seconds
# Isochrone generation took 1.355521 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:35:48.710016   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.24
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.15
#       Time taken: 1.39 seconds
# Isochrone generation took 1.309083 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:35:51.422061   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.60
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.54
#       Time taken: 1.39 seconds
# Isochrone generation took 1.313101 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:35:54.146347   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 23.86
# Starting filter: jwst,F182M   Elapsed time: 0.73 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.83
#       Time taken: 1.46 seconds
# Isochrone generation took 1.299518 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:35:56.918178   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 24.07
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.06
#       Time taken: 1.39 seconds
# Isochrone generation took 1.285649 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:35:59.609004   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.23
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.24
#       Time taken: 1.37 seconds
# Isochrone generation took 1.301198 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:02.291612   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.41
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.45
#       Time taken: 1.37 seconds
# Isochrone generation took 1.285022 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:04.964249   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.56
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.59
#       Time taken: 1.41 seconds
# Isochrone generation took 1.254891 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:07.648543   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.70
# Starting filter: jwst,F182M   Elapsed time: 0.85 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.72
#       Time taken: 1.70 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.297069 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:10.666406   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.88 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.86
#       Time taken: 1.77 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.336857 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:13.788092   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 24.90
# Starting filter: jwst,F182M   Elapsed time: 0.91 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 25.03
#       Time taken: 1.88 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.337330 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:17.026393   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 25.02
# Starting filter: jwst,F182M   Elapsed time: 0.90 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 25.10
#       Time taken: 1.69 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.224453 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:19.955342   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 25.18
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 25.18
#       Time taken: 1.42 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.226950 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:22.616198   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 25.31
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 25.24
#       Time taken: 1.43 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.409855 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:25.467043   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 25.54
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 25.36
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.193460 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:28.081939   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 25.85
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 25.53
#       Time taken: 1.42 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.275557 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:30.796326   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 26.02
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 25.63
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.164862 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:33.343071   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 26.25
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 25.80
#       Time taken: 1.42 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.214460 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:35.991003   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 26.40
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 25.92
#       Time taken: 1.37 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.217005 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.70  dist = 4500
#      Starting at:  2024-12-10 04:36:38.591061   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 26.44
# Starting filter: jwst,F182M   Elapsed time: 0.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 26.00
#       Time taken: 1.43 seconds
# Isochrone generation took 1.361401 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:42.289943   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 23.42
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 23.29
#       Time taken: 1.37 seconds
# Isochrone generation took 1.284210 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:44.962862   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 23.78
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 23.68
#       Time taken: 1.38 seconds
# Isochrone generation took 1.354170 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:47.708698   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 24.04
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 23.96
#       Time taken: 1.44 seconds
# Isochrone generation took 1.291153 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:50.457566   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 24.25
# Starting filter: jwst,F182M   Elapsed time: 0.71 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 24.20
#       Time taken: 1.43 seconds
# Isochrone generation took 1.225547 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:53.128767   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 24.41
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 24.37
#       Time taken: 1.39 seconds
# Isochrone generation took 1.253236 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:55.787613   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 24.59
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 24.59
#       Time taken: 1.40 seconds
# Isochrone generation took 1.267594 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:36:58.469878   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 24.74
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 24.73
#       Time taken: 1.39 seconds
# Isochrone generation took 1.284061 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:37:01.156892   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 24.87
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 24.86
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.278961 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:37:03.845629   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 24.93
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 24.99
#       Time taken: 1.39 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.297271 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:37:06.562437   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 25.08
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 25.17
#       Time taken: 1.40 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.227364 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.80  dist = 4500
#      Starting at:  2024-12-10 04:37:09.205069   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 25.20
