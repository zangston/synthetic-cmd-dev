# %%
# import packages
import numpy as np
import pylab as py
import matplotlib.pyplot as plt
import math

# import spisea packages
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity

# colormap stuff for plot generation
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
# Out:
# /home/wyz5rge/.local/lib/python3.9/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
# define isochrone parameters
AKs = 0
dist = 4500
evo_model = evolution.Baraffe15()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W', 'jwst,F356W', 'jwst,F405N', 'jwst,F115W']
filters = ['m_jwst_F162M', 'm_jwst_F182M', 'm_jwst_F200W', 'm_jwst_F356W', 'm_jwst_F405N', 'm_jwst_F115W']
iso_dir = 'isochrones/'
metallicity = 0

# %%
# define log age array for isochrone grid
level_ages = np.linspace(0.5, 10, 20)
level_ages = np.multiply(level_ages, 1e6)
print(level_ages)
log_age_arr = np.log10(level_ages)
print(log_age_arr)
# Out:
# [  500000.  1000000.  1500000.  2000000.  2500000.  3000000.  3500000.
#   4000000.  4500000.  5000000.  5500000.  6000000.  6500000.  7000000.
#   7500000.  8000000.  8500000.  9000000.  9500000. 10000000.]
# [5.69897    6.         6.17609126 6.30103    6.39794001 6.47712125
#  6.54406804 6.60205999 6.65321251 6.69897    6.74036269 6.77815125
#  6.81291336 6.84509804 6.87506126 6.90308999 6.92941893 6.95424251
#  6.97772361 7.        ]

# %%
instances = np.empty(len(log_age_arr), dtype=object)

for i in range(len(log_age_arr)):
    my_iso = synthetic.IsochronePhot(log_age_arr[i], AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
    instances[i] = my_iso
        
print("isochrone generation done")
# Out:
# Isochrone generation took 1.234885 s.
# Making photometry for isochrone: log(t) = 5.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 06:59:45.873610   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F162M = 21.45
# Starting filter: jwst,F182M   Elapsed time: 0.60 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F182M = 21.61
# Starting filter: jwst,F200W   Elapsed time: 1.20 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F200W = 21.48
# Starting filter: jwst,F356W   Elapsed time: 1.81 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F356W = 20.63
# Starting filter: jwst,F405N   Elapsed time: 2.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F405N = 20.31
# Starting filter: jwst,F115W   Elapsed time: 3.07 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2387 K  m_jwst_F115W = 22.34
#       Time taken: 3.65 seconds
# Isochrone generation took 1.311833 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 06:59:50.853560   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F162M = 21.99
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F182M = 22.18
# Starting filter: jwst,F200W   Elapsed time: 1.34 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F200W = 22.04
# Starting filter: jwst,F356W   Elapsed time: 2.01 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F356W = 21.17
# Starting filter: jwst,F405N   Elapsed time: 2.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F405N = 20.84
# Starting filter: jwst,F115W   Elapsed time: 3.41 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2344 K  m_jwst_F115W = 22.92
#       Time taken: 4.08 seconds
# Isochrone generation took 1.216552 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 06:59:56.168658   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F162M = 22.36
# Starting filter: jwst,F182M   Elapsed time: 0.69 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F182M = 22.56
# Starting filter: jwst,F200W   Elapsed time: 1.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F200W = 22.41
# Starting filter: jwst,F356W   Elapsed time: 2.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F356W = 21.50
# Starting filter: jwst,F405N   Elapsed time: 3.14 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F405N = 21.16
# Starting filter: jwst,F115W   Elapsed time: 3.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2292 K  m_jwst_F115W = 23.32
#       Time taken: 4.55 seconds
# Isochrone generation took 1.296538 s.
# Making photometry for isochrone: log(t) = 6.30  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:02.047164   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F162M = 22.61
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F182M = 22.85
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F200W = 22.69
# Starting filter: jwst,F356W   Elapsed time: 2.11 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F356W = 21.74
# Starting filter: jwst,F405N   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F405N = 21.39
# Starting filter: jwst,F115W   Elapsed time: 3.61 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2235 K  m_jwst_F115W = 23.61
#       Time taken: 4.31 seconds
# Isochrone generation took 1.327927 s.
# Making photometry for isochrone: log(t) = 6.40  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:07.715971   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F162M = 22.83
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F182M = 23.08
# Starting filter: jwst,F200W   Elapsed time: 1.48 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F200W = 22.91
# Starting filter: jwst,F356W   Elapsed time: 2.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F356W = 21.92
# Starting filter: jwst,F405N   Elapsed time: 3.07 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F405N = 21.56
# Starting filter: jwst,F115W   Elapsed time: 3.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2189 K  m_jwst_F115W = 23.87
#       Time taken: 4.42 seconds
# Isochrone generation took 1.202260 s.
# Making photometry for isochrone: log(t) = 6.48  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:13.361185   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F162M = 22.98
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F182M = 23.26
# Starting filter: jwst,F200W   Elapsed time: 1.33 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F200W = 23.08
# Starting filter: jwst,F356W   Elapsed time: 1.99 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F356W = 22.06
# Starting filter: jwst,F405N   Elapsed time: 2.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F405N = 21.70
# Starting filter: jwst,F115W   Elapsed time: 3.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2143 K  m_jwst_F115W = 24.06
#       Time taken: 4.15 seconds
# Isochrone generation took 1.217795 s.
# Making photometry for isochrone: log(t) = 6.54  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:18.747594   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F162M = 23.17
# Starting filter: jwst,F182M   Elapsed time: 0.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F182M = 23.48
# Starting filter: jwst,F200W   Elapsed time: 1.34 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F200W = 23.28
# Starting filter: jwst,F356W   Elapsed time: 2.02 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F356W = 22.21
# Starting filter: jwst,F405N   Elapsed time: 2.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F405N = 21.85
# Starting filter: jwst,F115W   Elapsed time: 3.46 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2099 K  m_jwst_F115W = 24.28
#       Time taken: 4.13 seconds
# Isochrone generation took 1.210781 s.
# Making photometry for isochrone: log(t) = 6.60  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:24.107182   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F162M = 23.32
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F182M = 23.61
# Starting filter: jwst,F200W   Elapsed time: 1.33 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F200W = 23.41
# Starting filter: jwst,F356W   Elapsed time: 2.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F356W = 22.31
# Starting filter: jwst,F405N   Elapsed time: 2.77 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F405N = 21.94
# Starting filter: jwst,F115W   Elapsed time: 3.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2052 K  m_jwst_F115W = 24.53
#       Time taken: 4.13 seconds
# Isochrone generation took 1.334319 s.
# Making photometry for isochrone: log(t) = 6.65  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:29.585250   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F162M = 23.45
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F182M = 23.74
# Starting filter: jwst,F200W   Elapsed time: 1.32 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F200W = 23.53
# Starting filter: jwst,F356W   Elapsed time: 1.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F356W = 22.39
# Starting filter: jwst,F405N   Elapsed time: 2.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F405N = 22.02
# Starting filter: jwst,F115W   Elapsed time: 3.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  2011 K  m_jwst_F115W = 24.68
#       Time taken: 4.02 seconds
# Changing to logg=5.00 for T=  1960 logg=3.95
# Isochrone generation took 1.190503 s.
# Making photometry for isochrone: log(t) = 6.70  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:34.815826   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F162M = 23.51
# Starting filter: jwst,F182M   Elapsed time: 0.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F182M = 23.88
# Starting filter: jwst,F200W   Elapsed time: 1.40 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F200W = 23.64
# Starting filter: jwst,F356W   Elapsed time: 2.45 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F356W = 22.43
# Starting filter: jwst,F405N   Elapsed time: 3.23 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F405N = 22.08
# Starting filter: jwst,F115W   Elapsed time: 3.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1960 K  m_jwst_F115W = 25.02
#       Time taken: 4.64 seconds
# Changing to logg=5.00 for T=  1893 logg=3.97
# Isochrone generation took 1.326775 s.
# Making photometry for isochrone: log(t) = 6.74  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:40.802775   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F162M = 23.66
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F182M = 24.05
# Starting filter: jwst,F200W   Elapsed time: 1.32 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F200W = 23.79
# Starting filter: jwst,F356W   Elapsed time: 1.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F356W = 22.54
# Starting filter: jwst,F405N   Elapsed time: 2.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F405N = 22.18
# Starting filter: jwst,F115W   Elapsed time: 3.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1893 K  m_jwst_F115W = 25.20
#       Time taken: 4.04 seconds
# Changing to logg=5.00 for T=  1870 logg=3.98
# Isochrone generation took 1.211707 s.
# Making photometry for isochrone: log(t) = 6.78  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:46.074290   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F162M = 23.77
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F182M = 24.12
# Starting filter: jwst,F200W   Elapsed time: 1.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F200W = 23.85
# Starting filter: jwst,F356W   Elapsed time: 2.04 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F356W = 22.58
# Starting filter: jwst,F405N   Elapsed time: 2.72 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F405N = 22.22
# Starting filter: jwst,F115W   Elapsed time: 3.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1870 K  m_jwst_F115W = 25.37
#       Time taken: 4.09 seconds
# Changing to logg=5.00 for T=  1838 logg=3.99
# Isochrone generation took 1.206487 s.
# Making photometry for isochrone: log(t) = 6.81  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:51.394947   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F162M = 23.94
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F182M = 24.21
# Starting filter: jwst,F200W   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F200W = 23.93
# Starting filter: jwst,F356W   Elapsed time: 1.97 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F356W = 22.62
# Starting filter: jwst,F405N   Elapsed time: 2.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F405N = 22.26
# Starting filter: jwst,F115W   Elapsed time: 3.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1838 K  m_jwst_F115W = 25.60
#       Time taken: 4.03 seconds
# Changing to logg=5.00 for T=  1814 logg=4.00
# Isochrone generation took 1.198611 s.
# Making photometry for isochrone: log(t) = 6.85  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:00:56.644854   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F162M = 24.06
# Starting filter: jwst,F182M   Elapsed time: 0.65 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F182M = 24.27
# Starting filter: jwst,F200W   Elapsed time: 1.31 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F200W = 23.98
# Starting filter: jwst,F356W   Elapsed time: 1.98 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F356W = 22.64
# Starting filter: jwst,F405N   Elapsed time: 2.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F405N = 22.29
# Starting filter: jwst,F115W   Elapsed time: 3.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1814 K  m_jwst_F115W = 25.75
#       Time taken: 4.03 seconds
# Changing to logg=5.00 for T=  1773 logg=4.01
# Isochrone generation took 1.197597 s.
# Making photometry for isochrone: log(t) = 6.88  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:01.890325   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F162M = 24.29
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F182M = 24.39
# Starting filter: jwst,F200W   Elapsed time: 1.32 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F200W = 24.08
# Starting filter: jwst,F356W   Elapsed time: 1.99 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F356W = 22.68
# Starting filter: jwst,F405N   Elapsed time: 2.67 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F405N = 22.32
# Starting filter: jwst,F115W   Elapsed time: 3.38 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1773 K  m_jwst_F115W = 26.03
#       Time taken: 4.03 seconds
# Changing to logg=5.00 for T=  1711 logg=4.02
# Isochrone generation took 1.150945 s.
# Making photometry for isochrone: log(t) = 6.90  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:07.086344   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F162M = 24.60
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F182M = 24.56
# Starting filter: jwst,F200W   Elapsed time: 1.32 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F200W = 24.24
# Starting filter: jwst,F356W   Elapsed time: 1.97 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F356W = 22.74
# Starting filter: jwst,F405N   Elapsed time: 2.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F405N = 22.36
# Starting filter: jwst,F115W   Elapsed time: 3.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1711 K  m_jwst_F115W = 26.40
#       Time taken: 4.03 seconds
# Changing to logg=5.00 for T=  1677 logg=4.03
# Isochrone generation took 1.153607 s.
# Making photometry for isochrone: log(t) = 6.93  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:12.288669   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F162M = 24.76
# Starting filter: jwst,F182M   Elapsed time: 0.70 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F182M = 24.67
# Starting filter: jwst,F200W   Elapsed time: 1.37 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F200W = 24.34
# Starting filter: jwst,F356W   Elapsed time: 2.04 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F356W = 22.77
# Starting filter: jwst,F405N   Elapsed time: 2.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F405N = 22.38
# Starting filter: jwst,F115W   Elapsed time: 3.47 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1677 K  m_jwst_F115W = 26.57
#       Time taken: 4.13 seconds
# Changing to logg=5.00 for T=  1631 logg=4.04
# Isochrone generation took 1.199244 s.
# Making photometry for isochrone: log(t) = 6.95  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:17.641492   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F162M = 25.00
# Starting filter: jwst,F182M   Elapsed time: 0.76 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F182M = 24.84
# Starting filter: jwst,F200W   Elapsed time: 1.43 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F200W = 24.51
# Starting filter: jwst,F356W   Elapsed time: 2.16 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F356W = 22.90
# Starting filter: jwst,F405N   Elapsed time: 2.86 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F405N = 22.49
# Starting filter: jwst,F115W   Elapsed time: 3.55 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1631 K  m_jwst_F115W = 26.80
#       Time taken: 4.22 seconds
# Changing to logg=5.00 for T=  1602 logg=4.04
# Isochrone generation took 1.178725 s.
# Making photometry for isochrone: log(t) = 6.98  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:23.061662   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F162M = 25.15
# Starting filter: jwst,F182M   Elapsed time: 0.68 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F182M = 24.96
# Starting filter: jwst,F200W   Elapsed time: 1.35 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F200W = 24.64
# Starting filter: jwst,F356W   Elapsed time: 2.01 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F356W = 23.04
# Starting filter: jwst,F405N   Elapsed time: 2.74 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F405N = 22.62
# Starting filter: jwst,F115W   Elapsed time: 3.48 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1602 K  m_jwst_F115W = 26.93
#       Time taken: 4.14 seconds
# Changing to logg=5.00 for T=  1571 logg=4.05
# Isochrone generation took 1.149407 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.00  dist = 4500
#      Starting at:  2024-10-07 07:01:28.368877   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F162M = 25.19
# Starting filter: jwst,F182M   Elapsed time: 0.66 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F182M = 25.03
# Starting filter: jwst,F200W   Elapsed time: 1.42 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F200W = 24.71
# Starting filter: jwst,F356W   Elapsed time: 2.11 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F356W = 23.13
# Starting filter: jwst,F405N   Elapsed time: 2.80 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F405N = 22.69
# Starting filter: jwst,F115W   Elapsed time: 3.51 seconds
# Starting synthetic photometry
# M =   0.010 Msun  T =  1571 K  m_jwst_F115W = 26.97
#       Time taken: 4.16 seconds
# isochrone generation done

# %%
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[0]], 
        instances[i].points[filters[1]], color=color, label='')

py.xlabel('F162M')
py.ylabel('F182M')
py.gca().invert_yaxis()
py.gca().invert_xaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.grid()

# %%
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[0]], 
        instances[i].points[filters[2]], color=color, label='')

py.xlabel('F162M')
py.ylabel('F200W')
py.gca().invert_yaxis()
py.gca().invert_xaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.grid()

# %%
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[1]], 
        instances[i].points[filters[2]], color=color, label='')

py.xlabel('F182M')
py.ylabel('F200W')
py.gca().invert_yaxis()
py.gca().invert_xaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.grid()

# %%
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[3]], 
        instances[i].points[filters[4]], color=color, label='')

py.xlabel('F356W')
py.ylabel('F405N')
py.gca().invert_yaxis()
py.gca().invert_xaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.grid()

# %%
cmap = plt.get_cmap('coolwarm')

py.figure(figsize=(10, 10))

for i in range(len(log_age_arr)):
    color = cmap(i / (len(log_age_arr) - 1))  # Assign color based on index and colormap
    py.plot(instances[i].points[filters[5]], 
        instances[i].points[filters[2]], color=color, label='')

py.xlabel('F115W')
py.ylabel('F200W')
py.gca().invert_yaxis()
py.gca().invert_xaxis()

# Create colorbar legend
norm = Normalize(vmin=min(level_ages), vmax=max(level_ages))
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Age (millions of years)')
cbar.set_ticks(level_ages)
cbar.set_ticklabels([f'{age/1e6:.1f}' for age in level_ages])

py.grid()
