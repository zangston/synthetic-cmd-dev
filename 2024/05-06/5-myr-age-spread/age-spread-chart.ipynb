# %%
import numpy as np
import pylab as py
import matplotlib.pyplot as plt

# %%
e_ff = [0.01, 0.03, 0.1, 0.3, 1.0]
spread_sigma1p0 = []
spread_sigma0p1 = []

# %%
plt.scatter(e_ff, spread_sigma1p0, color='blue', marker='o', label='sigma = 1.0')
plt.scatter(e_ff, spread_sigma0p1, color='orange', marker='s', label='sigma = 0.1')
plt.xlabel('Log-e_ff')
plt.xscale('log')
plt.ylabel('Average magnitude spread')
plt.title("Average Spread Across Color Bins, with Binaries")
plt.legend()

# %%
spread_sigma1p0_nb = []
spread_sigma0p1_nb = []

# %%
plt.scatter(e_ff, spread_sigma1p0_nb, color='blue', marker='o', label='sigma = 1.0')
plt.scatter(e_ff, spread_sigma0p1_nb, color='orange', marker='s', label='sigma = 0.1')
plt.xlabel('Log-e_ff')
plt.xscale('log')
plt.ylabel('Average magnitude spread')
plt.title("Magnitude Spread Across Color Bins, without Binaries")
plt.legend()
