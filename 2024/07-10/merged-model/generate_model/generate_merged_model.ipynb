# %%
import generate_merged_model as model_generator

# %%
# %pwd
# %cd /scratch/wyz5rge/models/evolution/
# Out:
# /scratch/wyz5rge/models/evolution

# %% [markdown]
# # No rotation models first

# %%
baraffe_path = '/scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/'
merged_model_path = '/scratch/wyz5rge/models/evolution/merged/baraffe_pisa_ekstrom_parsec/z015_norot/'
new_model_path = '/scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_norot/'

# %%
model_generator.run_script(baraffe_path, merged_model_path, new_model_path)
# Out:
# Processing age 6.00: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.00.dat
# Generated DAT file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_norot/iso_6.00.dat
# Processing age 6.00: FITS files
# Generated FITS file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_norot/iso_6.00.fits
# Processing age 6.01: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.01.dat
# Generated DAT file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_norot/iso_6.01.dat
# Processing age 6.01: FITS files
# Generated FITS file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_norot/iso_6.01.fits
# Processing age 6.02: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.02.dat
# ...

# %%
baraffe_path = '/scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/'
merged_model_path = '/scratch/wyz5rge/models/evolution/merged/baraffe_pisa_ekstrom_parsec/z015_rot/'
new_model_path = '/scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/'

# %%
model_generator.run_script(baraffe_path, merged_model_path, new_model_path)
# Out:
# Processing age 6.00: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.00.dat
# Generated DAT file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/iso_6.00.dat
# Processing age 6.00: FITS files
# Generated FITS file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/iso_6.00.fits
# Processing age 6.01: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.01.dat
# Generated DAT file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/iso_6.01.dat
# Processing age 6.01: FITS files
# Generated FITS file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/iso_6.01.fits
# Processing age 6.02: DAT files
# Generated DAT file: /scratch/wyz5rge/models/evolution/Baraffe15/iso/z015/iso_6.02.dat
# Generated DAT file: /scratch/wyz5rge/synthetic-hr/2024/07-10/merged-model/generate_model/z015_rot/iso_6.02.dat
# ...
