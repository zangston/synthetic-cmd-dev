# %%
# import packages
import numpy as np
import pylab as py
import pdb
import matplotlib.pyplot as plt
import math

# %%
temperature_bins = np.arange(3000, 3700, 100)

mag_0p03 = [0.3148997601532895, 0.2571123179305337, 0.3207136826196441, 0.34384071598714483, 0.369339918397907, 0.36773656690240664, 0.3249030904636382]
mag_0p10 = [0.25347483241963265, 0.20896977918545245, 0.2364668081320547, 0.24434299794928738, 0.22754240120789526, 0.22145645962696628, 0.2204464417879005]
mag_0p30 = [0.24289010223155086, 0.2655384205056909, 0.203092022663225, 0.214447806235613, 0.24988155457505215, 0.2335917836580561, 0.25548741767014266]
mag_1p00 = [0.2531666210854783, 0.20478861095779277, 0.22307701220733198, 0.24801736925781614, 0.2080033930344232, 0.19343754849248485, 0.2154558364187402]

lum_0p03 = [0.04950268364843896, 0.049790333900780435,0.0856856988848658, 0.12542288548584846, 0.16376452316465087, 0.19020593005085284, 0.1911838503371174]
lum_0p10 = [0.032372047418015464, 0.03578744465323702, 0.051572179632082334, 0.06870341576037768, 0.07847819937997273, 0.08801613423963987, 0.10967023946747123]
lum_0p30 = [0.030555446860126345, 0.07093930360139912, 0.04095546528496791, 0.05579821615293112, 0.11894626439930409, 0.09122162509961015, 0.22035679779283515]
lum_1p00 = [0.03013927694683001, 0.031896392035698155, 0.04312121797910358, 0.06175553307723701, 0.06417947415791063, 0.06998108617695535, 0.09880777121094438]

# %%
plt.scatter(temperature_bins, mag_0p03, color='blue', label='e_ff = 0.03')
plt.scatter(temperature_bins, mag_0p10, color='green', label='e_ff = 0.10')
plt.scatter(temperature_bins, mag_0p30, color='orange', label='e_ff = 0.30')
plt.scatter(temperature_bins, mag_1p00, color='red', label='e_ff = 1.00')
plt.xlabel('Temperature (K)')
plt.ylabel('Standard Deviation of Magnitude (F200W)')
plt.legend()

# %%
plt.scatter(temperature_bins, lum_0p03, color='blue', label='e_ff = 0.03')
plt.scatter(temperature_bins, lum_0p10, color='green', label='e_ff = 0.10')
plt.scatter(temperature_bins, lum_0p30, color='orange', label='e_ff = 0.30')
plt.scatter(temperature_bins, lum_1p00, color='red', label='e_ff = 1.00')
plt.xlabel('Temperature (K)')
plt.ylabel('Standard Deviation of Luminosity (Lsun)')
plt.legend()
