# %%
# import packages
import numpy as np
import pylab as py
import pdb
import matplotlib.pyplot as plt
import math

# import spisea packages
from spisea import synthetic, evolution, atmospheres, reddening, ifmr
from spisea.imf import imf, multiplicity

# import nbody6tools reader to read data
from nbody6tools import Reader

# import nbody62spisea to retrieve star ages
from nbody62spisea import converter
# Out:
# /home/wyz5rge/.local/lib/python3.6/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /scratch/wyz5rge/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %% [markdown]
# ## Set up parameters, create isochrone grid

# %%
# define isochrone parameters
AKs = 0
dist = 410
evo_model = evolution.MISTv1()
atm_func = atmospheres.get_merged_atmosphere
red_law = reddening.RedLawHosek18b()
filt_list = ['jwst,F162M', 'jwst,F182M', 'jwst,F200W', 'jwst,F212N']
iso_dir = 'isochrones/'
metallicity = 0

# %%
# read nbody data
path_to_data = '../../../../../storage/jfarias/Data/Orion/massive_clusters/M3000new/sigma1p0/fiducial/sfe_ff003/00'
snapshot = Reader.read_snapshot(path_to_data, snapshot=1)

# convert snapshot values from nbody units to astrophysical, extract masses
snapshot.to_physical()

# read ages for simulated stars
cluster_table = converter.to_spicea_table(snapshot)

masses = cluster_table['mass']
log_ages = cluster_table['age']

level_ages = np.power(10, log_ages) * 1e6

# convert log ages from log(Myr) to log(yr)
log_ages = np.log10(level_ages)

print(cluster_table)

# print(log_ages)
print("Min log age = " + str(min(log_ages)))
print("Max log age = " + str(max(log_ages)))

# print(level_ages)
print("Min level age = " + str(min(level_ages)))
print("Max level age = " + str(max(level_ages)))
# Out:
#         mass         isMultiple ...       log_a                 age
# -------------------- ---------- ... ------------------ ---------------------
#    0.354544991716123        0.0 ...                nan  0.031122999392827807
#  0.18492738272531623        0.0 ...                nan  0.030985096510415477
#  0.48428826471041747        0.0 ...                nan  0.030624287117013906
#  0.09816665041084773        0.0 ...                nan   0.03055095780652481
# 0.035944275060452696        0.0 ...                nan  0.030523960945946733
#   0.4494689106941223        0.0 ...                nan  0.044471852481365204
#   0.0225516464561224        0.0 ...                nan  0.044471852481365204
#   0.1685144305229187        0.0 ...                nan  0.044471852481365204
#    0.293556272983551        0.0 ...                nan  0.044471852481365204
#  0.09719057816607123        0.0 ...                nan   0.02961701235949951
#                  ...        ... ...                ...                   ...
#   0.2651488808733826        1.0 ...  2.423178542926232  0.044471852481365204
#   0.2397414594888687        1.0 ... 2.9000048742820015  0.044471852481365204
#  0.15507431066852567        1.0 ... 3.0709342526497907  0.044471852481365204
# 0.017210986465215683        1.0 ... 3.3612537191190155  0.044471852481365204
#  0.39308680399434714        1.0 ... 3.3965637424354824  0.039328585718801656
#   0.1123742088675499        1.0 ...  2.232615222486381  0.044471852481365204
#  0.06280404992954465        1.0 ...  2.865862023113816  0.015081756695287787
#    0.441230833530426        1.0 ... 1.9371263758701263  0.044471852481365204
#   1.5429306669012162        1.0 ... 2.4603992900407703  0.044471852481365204
#  0.13804451818538777        1.0 ... 3.2882638169369898  0.038960115054154955
#  0.14060210010503638        1.0 ... 3.1409547673122433 0.0019733215948713537
# Length = 232 rows
# Min log age = 6.0000627464753125
# Max log age = 6.044471852481365
# Min level age = 1000144.4895362994
# Max level age = 1107826.762516397
# /scratch/wyz5rge/TurbulentClusterModel/nbody62spisea/converter.py:231: RuntimeWarning: invalid value encountered in log10
#   log_a = numpy.concatenate( [numpy.full(len(singles),numpy.nan), numpy.log10(bdict['semi']) ] )

# %%
# TODO: programmatically find min and max age to define age range for isochrone grid
# possible strategy: convert logs to levels, find next highest half megayear that brackets maximum age

start = (min(level_ages) // 0.5e6) * 0.5e6
end = (max(level_ages) // 0.5e6) * 0.5e6 + 2 * 0.5e6
increment = 0.5e6  # 500,000

# Create age arrays
level_age_arr = np.arange(start, end, increment)
log_age_arr = np.log10(level_age_arr)

print(log_age_arr)
print(level_age_arr)
# Out:
# [6.         6.17609126]
# [1000000. 1500000.]

# %%
# create isochrone grid - if this is the first time, then this is going to take an hour lmfao
instances = np.empty(len(log_age_arr), dtype=object)

for i in range(len(log_age_arr)):
    my_iso = synthetic.IsochronePhot(log_age_arr[i], AKs, dist, metallicity=metallicity,
                            evo_model=evo_model, atm_func=atm_func,
                            red_law=red_law, filters=filt_list,
                                iso_dir=iso_dir)
    instances[i] = my_iso
        
print("isochrone generation done")
# Out:
# Changing to logg=4.50 for T= 39023 logg=4.15
# Changing to logg=4.50 for T= 39414 logg=4.14
# Changing to logg=4.50 for T= 40077 logg=4.14
# Changing to logg=4.50 for T= 40481 logg=4.13
# Changing to logg=4.50 for T= 41038 logg=4.13
# Changing to logg=4.50 for T= 41391 logg=4.13
# Changing to logg=4.50 for T= 41709 logg=4.12
# Changing to logg=4.50 for T= 42053 logg=4.12
# Changing to logg=4.50 for T= 42409 logg=4.12
# Changing to logg=4.50 for T= 42725 logg=4.12
# Changing to logg=4.50 for T= 43048 logg=4.11
# Changing to logg=4.50 for T= 43380 logg=4.11
# Changing to logg=4.50 for T= 43755 logg=4.11
# Changing to logg=4.50 for T= 44345 logg=4.10
# Changing to logg=4.50 for T= 44940 logg=4.10
# Changing to logg=4.50 for T= 45533 logg=4.09
# Changing to logg=4.50 for T= 46164 logg=4.09
# Changing to logg=4.50 for T= 47104 logg=4.09
# Changing to logg=4.50 for T= 47885 logg=4.08
# Changing to logg=4.50 for T= 48285 logg=4.08
# Changing to T= 50000 for T= 50969 logg=4.10
# Changing to logg=5.00 for T= 50969 logg=4.10
# Changing to T= 50000 for T= 51571 logg=4.10
# Changing to logg=5.00 for T= 51571 logg=4.10
# Changing to T= 50000 for T= 52138 logg=4.10
# Changing to logg=5.00 for T= 52138 logg=4.10
# Changing to T= 50000 for T= 52514 logg=4.10
# Changing to logg=5.00 for T= 52514 logg=4.10
# Changing to T= 50000 for T= 53676 logg=4.10
# Changing to logg=5.00 for T= 53676 logg=4.10
# Changing to T= 50000 for T= 54301 logg=4.10
# Changing to logg=5.00 for T= 54301 logg=4.10
# Changing to T= 50000 for T= 54636 logg=4.10
# Changing to logg=5.00 for T= 54636 logg=4.10
# Changing to T= 50000 for T= 54939 logg=4.10
# Changing to logg=5.00 for T= 54939 logg=4.10
# Changing to T= 50000 for T= 55158 logg=4.09
# Changing to logg=5.00 for T= 55158 logg=4.09
# Changing to T= 50000 for T= 55269 logg=4.08
# Changing to logg=5.00 for T= 55269 logg=4.08
# Changing to T= 50000 for T= 55880 logg=4.08
# Changing to logg=5.00 for T= 55880 logg=4.08
# Changing to T= 50000 for T= 56749 logg=4.08
# Changing to logg=5.00 for T= 56749 logg=4.08
# Changing to T= 50000 for T= 57582 logg=4.09
# Changing to logg=5.00 for T= 57582 logg=4.09
# Changing to T= 50000 for T= 58273 logg=4.09
# Changing to logg=5.00 for T= 58273 logg=4.09
# Changing to T= 50000 for T= 58899 logg=4.09
# Changing to logg=5.00 for T= 58899 logg=4.09
# Changing to T= 50000 for T= 59847 logg=4.09
# Changing to logg=5.00 for T= 59847 logg=4.09
# Isochrone generation took 19.952596 s.
# Making photometry for isochrone: log(t) = 6.00  AKs = 0.00  dist = 410
#      Starting at:  2023-11-10 21:45:16.507697   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.104 Msun  T =  2980 K  m_jwst_F162M = 13.01
# M =   3.763 Msun  T =  7713 K  m_jwst_F162M = 6.99
# M =   8.872 Msun  T = 23693 K  m_jwst_F162M = 6.90
# Starting filter: jwst,F182M   Elapsed time: 6.65 seconds
# Starting synthetic photometry
# M =   0.104 Msun  T =  2980 K  m_jwst_F182M = 13.11
# M =   3.763 Msun  T =  7713 K  m_jwst_F182M = 6.99
# M =   8.872 Msun  T = 23693 K  m_jwst_F182M = 6.95
# Starting filter: jwst,F200W   Elapsed time: 13.43 seconds
# Starting synthetic photometry
# M =   0.104 Msun  T =  2980 K  m_jwst_F200W = 13.06
# M =   3.763 Msun  T =  7713 K  m_jwst_F200W = 6.98
# M =   8.872 Msun  T = 23693 K  m_jwst_F200W = 6.97
# Starting filter: jwst,F212N   Elapsed time: 20.10 seconds
# Starting synthetic photometry
# M =   0.104 Msun  T =  2980 K  m_jwst_F212N = 12.92
# M =   3.763 Msun  T =  7713 K  m_jwst_F212N = 6.98
# M =   8.872 Msun  T = 23693 K  m_jwst_F212N = 6.99
#       Time taken: 26.65 seconds
# Changing to logg=4.50 for T= 39332 logg=4.11
# Changing to logg=4.50 for T= 39753 logg=4.10
# Changing to logg=4.50 for T= 40200 logg=4.10
# Changing to logg=4.50 for T= 40556 logg=4.09
# Changing to logg=4.50 for T= 40927 logg=4.09
# Changing to logg=4.50 for T= 41423 logg=4.08
# Changing to logg=4.50 for T= 41799 logg=4.08
# Changing to logg=4.50 for T= 42130 logg=4.08
# Changing to logg=4.50 for T= 42470 logg=4.07
# Changing to logg=4.50 for T= 42850 logg=4.07
# Changing to logg=4.50 for T= 43298 logg=4.06
# Changing to logg=4.50 for T= 43751 logg=4.06
# Changing to logg=4.50 for T= 44217 logg=4.05
# Changing to logg=4.50 for T= 44819 logg=4.04
# Changing to logg=4.50 for T= 45650 logg=4.04
# Changing to logg=4.50 for T= 46321 logg=4.03
# Changing to logg=4.50 for T= 46832 logg=4.03
# Changing to logg=4.50 for T= 48596 logg=4.04
# Changing to T= 50000 for T= 50008 logg=4.05
# Changing to logg=5.00 for T= 50008 logg=4.05
# Changing to T= 50000 for T= 50497 logg=4.05
# Changing to logg=5.00 for T= 50497 logg=4.05
# Changing to T= 50000 for T= 50178 logg=4.02
# Changing to logg=5.00 for T= 50178 logg=4.02
# Changing to T= 50000 for T= 54122 logg=4.10
# Changing to logg=5.00 for T= 54122 logg=4.10
# Changing to T= 50000 for T= 54801 logg=4.10
# Changing to logg=5.00 for T= 54801 logg=4.10
# Changing to T= 50000 for T= 55244 logg=4.10
# Changing to logg=5.00 for T= 55244 logg=4.10
# Changing to T= 50000 for T= 55592 logg=4.09
# Changing to logg=5.00 for T= 55592 logg=4.09
# Changing to T= 50000 for T= 56011 logg=4.09
# Changing to logg=5.00 for T= 56011 logg=4.09
# Changing to T= 50000 for T= 55977 logg=4.07
# Changing to logg=5.00 for T= 55977 logg=4.07
# Changing to T= 50000 for T= 56375 logg=4.06
# Changing to logg=5.00 for T= 56375 logg=4.06
# Changing to T= 50000 for T= 56892 logg=4.06
# Changing to logg=5.00 for T= 56892 logg=4.06
# Changing to T= 50000 for T= 56820 logg=4.04
# Changing to logg=5.00 for T= 56820 logg=4.04
# Changing to T= 50000 for T= 57386 logg=4.04
# Changing to logg=5.00 for T= 57386 logg=4.04
# Changing to T= 50000 for T= 58516 logg=4.04
# Changing to logg=5.00 for T= 58516 logg=4.04
# Changing to T= 50000 for T= 60015 logg=4.06
# Changing to logg=5.00 for T= 60015 logg=4.06
# Isochrone generation took 20.233987 s.
# Making photometry for isochrone: log(t) = 6.18  AKs = 0.00  dist = 410
#      Starting at:  2023-11-10 21:46:03.410051   Usually takes ~5 minutes
# Starting filter: jwst,F162M   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.103 Msun  T =  2980 K  m_jwst_F162M = 13.17
# M =   3.318 Msun  T =  8128 K  m_jwst_F162M = 7.41
# M =   8.253 Msun  T = 22688 K  m_jwst_F162M = 7.04
# Starting filter: jwst,F182M   Elapsed time: 6.67 seconds
# Starting synthetic photometry
# M =   0.103 Msun  T =  2980 K  m_jwst_F182M = 13.27
# M =   3.318 Msun  T =  8128 K  m_jwst_F182M = 7.41
# M =   8.253 Msun  T = 22688 K  m_jwst_F182M = 7.09
# Starting filter: jwst,F200W   Elapsed time: 13.53 seconds
# Starting synthetic photometry
# M =   0.103 Msun  T =  2980 K  m_jwst_F200W = 13.21
# M =   3.318 Msun  T =  8128 K  m_jwst_F200W = 7.41
# M =   8.253 Msun  T = 22688 K  m_jwst_F200W = 7.10
# Starting filter: jwst,F212N   Elapsed time: 20.28 seconds
# Starting synthetic photometry
# M =   0.103 Msun  T =  2980 K  m_jwst_F212N = 13.08
# M =   3.318 Msun  T =  8128 K  m_jwst_F212N = 7.41
# M =   8.253 Msun  T = 22688 K  m_jwst_F212N = 7.13
#       Time taken: 27.16 seconds
# isochrone generation done

# %%
# identify array indeces, create array for labels and colors
idx_arr = range(0, len(log_age_arr))
if len(idx_arr) > 2:
    idx_arr = idx_arr[::2]

'''
label_arr = np.empty(len(idx_arr))
for i in range(len(idx_arr)):
    label_arr[i] = (idx_arr[i] / 2) + 1
    
color_arr = ["lightcoral", "indianred", "firebrick", "maroon", "darkred"]
'''
   
# Plot CMD
fig, axes = py.subplots(figsize=(15, 10))
py.subplot(1, 2, 1)
for i in range(len(idx_arr)):
    idx = idx_arr[i]
    if i == 0:
        py.plot(instances[idx].points['m_jwst_F162M'] - instances[idx].points['m_jwst_F200W'], 
           instances[idx].points['m_jwst_F200W'], 'lightcoral', label=level_age_arr[i])
    elif i == len(idx_arr) - 1:
        py.plot(instances[idx].points['m_jwst_F162M'] - instances[idx].points['m_jwst_F200W'], 
           instances[idx].points['m_jwst_F200W'], 'darkred', label=level_age_arr[i])
    else:
        py.plot(instances[idx].points['m_jwst_F162M'] - instances[idx].points['m_jwst_F200W'], 
           instances[idx].points['m_jwst_F200W'], 'red', label='')
    
py.xlabel('F162M - F200W')
py.ylabel('F200W')
py.gca().invert_yaxis()
py.legend()

# Plot HR
py.subplot(1, 2, 2)
watts_to_lsun = 1.0 / (3.846e26) # conversion factor for watts to Lsun
for i in range(len(idx_arr)):
    idx = idx_arr[i]
    data_iso_Lsun = instances[idx].points['L'] * watts_to_lsun
    if i == 0:
        py.plot(instances[idx].points['Teff'], data_iso_Lsun, 'lightcoral', label=level_age_arr[i])
    elif i == len(idx_arr) - 1:
        py.plot(instances[idx].points['Teff'], data_iso_Lsun, 'darkred', label=level_age_arr[i])
    else:    
        py.plot(instances[idx].points['Teff'], data_iso_Lsun, 'red', label='')
    
py.yscale('log')
py.xlabel('Effective Temperature, $T$ (K)')
py.ylabel('Luminosity, $L$ ($L_{\odot}$)')
py.gca().invert_xaxis()
py.legend()
